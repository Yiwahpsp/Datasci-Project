# %%
import pandas as pd
import numpy as np
import json
import glob
import os
from pathlib import Path
from pyspark.sql import SparkSession
from pyspark.sql.functions import explode

# %% [markdown]
# ## Code

# %%
def get_array_or_dict_values(data, path, key):
    """Extract values from deeply nested arrays/dictionaries."""
    try:
        value = data
        for p in path:
            if isinstance(value, dict):
                value = value.get(p, None)
            elif isinstance(value, list):
                # Handle list of dicts or list of lists
                temp_values = []
                for item in value:
                    if isinstance(item, dict):
                        item_value = item.get(p, None)
                        if isinstance(item_value, list):
                            temp_values.extend(item_value)
                        elif item_value is not None:
                            temp_values.append(item_value)
                    elif isinstance(item, list):
                        temp_values.extend(item)
                value = temp_values if temp_values else None
            else:
                return [None]

        # Handle final value
        if value is None:
            return [None]
        elif isinstance(value, dict):
            # Handle dictionary case
            if key in value:
                return [value[key]]
            elif '$' in value:  # Special case for $ key
                return [value['$']]
            return [None]
        elif isinstance(value, list):
            # Handle list case
            results = []
            for item in value:
                if isinstance(item, dict):
                    if key in item:
                        results.append(item[key])
                    elif '$' in item:  # Special case for $ key
                        results.append(item['$'])
                    else:
                        results.append(None)
                else:
                    results.append(item if item is not None else None)
            return results
        else:
            return [value]
    except Exception as e:
        print(f"Error extracting from path {path}: {e}")
        return [None]

# %%
def extract_features(json_file):
    with open(json_file, 'r', encoding='utf-8') as f:
        data = json.load(f)

    abs_resp = data.get('abstracts-retrieval-response', {})
    
    # Special handling for organizations
    def get_organizations(data):
        orgs = []
        author_groups = data.get('item', {}).get('bibrecord', {}).get('head', {}).get('author-group', [])
        
        if isinstance(author_groups, dict):
            author_groups = [author_groups]
            
        for group in author_groups:
            if isinstance(group, dict):
                affiliation = group.get('affiliation', {})
                if isinstance(affiliation, dict):
                    org = affiliation.get('organization', [])
                    if isinstance(org, dict):
                        org = [org]
                    if isinstance(org, list):
                        for o in org:
                            if isinstance(o, dict):
                                orgs.append(o.get('$', None))
                            else:
                                orgs.append(o)
        
        return orgs if orgs else [None]

    features = {
        'organizations': {
            'custom': get_organizations
        },
        'classifications': {
            'path': ['item', 'bibrecord', 'head', 'enhancement', 
                    'classificationgroup', 'classifications'],
            'key': '@type'
        },
        'affiliations': {
            'path': ['affiliation'],
            'key': 'affilname'
        },
        'auth-keywords': {
            'path': ['authkeywords', 'author-keyword'],
            'key': '$'
        },
        'subjects': {
            'path': ['subject-areas', 'subject-area'],
            'key': '$'
        },
        'authors': {
            'path': ['authors', 'author'],
            'key': 'ce:indexed-name'
        }
    }

    record = {'file': Path(json_file).name}

    for feature_name, config in features.items():
        if 'custom' in config:
            # Use custom extraction function for organizations
            record[feature_name] = config['custom'](abs_resp)
        elif 'subpath' in config:
            values = []
            main_array = get_array_or_dict_values(abs_resp, config['path'], None)
            for item in main_array:
                if isinstance(item, dict):
                    sub_values = get_array_or_dict_values(item, config['subpath'], config['key'])
                    values.extend(sub_values)
            record[feature_name] = values
        else:
            record[feature_name] = get_array_or_dict_values(abs_resp, config['path'], config['key'])

    return record

# %%
# Process all JSON files and merge features into a DataFrame
def process_json_files(root_folder_path):
    """Process all JSON files and extract features."""
    all_records = []
    root_path = Path(root_folder_path)

    # Define expected columns
    expected_columns = [
        'file', 'organizations', 'classifications', 
        'affiliations', 'auth-keywords',
        'subjects', 'authors'
    ]

    for json_file in root_path.rglob('*.json'):
        try:
            record = extract_features(json_file)
            # Ensure all expected columns exist with NaN as default
            for col in expected_columns:
                if col not in record:
                    record[col] = np.nan
                elif isinstance(record[col], list) and not record[col]:
                    record[col] = np.nan
            all_records.append(record)
        except Exception as e:
            print(f"Error processing {json_file}: {e}")
            # Add empty record with NaN values if file processing fails
            empty_record = {
                'file': Path(json_file).name,
                **{col: np.nan for col in expected_columns if col != 'file'}
            }
            all_records.append(empty_record)

    if all_records:
        df = pd.DataFrame(all_records)
        # Combine features into single rows by grouping
        grouped_df = (
            df.groupby('file').agg(
                {col: lambda x: ', '.join(filter(None, x.dropna().astype(str))) for col in df.columns if col != 'file'}
            ).reset_index()
        )
        output_file = 'data/features_separate.csv'
        grouped_df.to_csv(output_file, index=False, encoding='utf-8')
        print(f"Processed {len(all_records)} files to {output_file}")
        return grouped_df
    else:
        print("No records found")
        return pd.DataFrame(columns=expected_columns)

# %%
root_folder = 'raw-data'  # Replace with your JSON root folder
df = process_json_files(root_folder)
df.head()
# Out:
# Processed 20216 files to data/features_separate.csv
#              file                                      organizations  \
# 0  201800000.json  ['Department of Preventive and Social Medicine...
# 1  201800001.json  ['Department of Electrical Engineering', 'Wire...
# 2  201800002.json  ['Center of Excellence in Catalysis and Cataly...
# 3  201800003.json  ['Department of Chemistry', 'Faculty of Scienc...
# 4  201800004.json  ['Program in Petrochemistry', 'Faculty of Scie...
#
#                                      classifications  \
# 0                               ['ASJC', 'SUBJABBR']
# 1       ['ASJC', 'CPXCLASS', 'FLXCLASS', 'SUBJABBR']
# 2  ['CPXCLASS', 'ENCOMPASSCLASS', 'FLXCLASS', 'AS...
# 3       ['CPXCLASS', 'FLXCLASS', 'ASJC', 'SUBJABBR']
# 4                    ['EMCLASS', 'ASJC', 'SUBJABBR']
#
#                                         affiliations  \
# 0  ['Stanford University School of Medicine', 'Ch...
# 1                       ['Chulalongkorn University']
# 2                       ['Chulalongkorn University']
# 3  ['Hirosaki University', 'Chulalongkorn Univers...
# 4  ['Chulalongkorn University', 'Thailand Nationa...
#
#                                        auth-keywords  \
# 0                                             [None]
# 1                                             [None]
# 2  ['Circulating fluidized bed', 'Computational f...
# 3  ['Encapsulation', 'Fluoroalkylsilane', 'Natura...
# 4  ['acpcPNA', 'Electrochemical impedance spectro...
#
#                                             subjects  \
# 0                                 ['Medicine (all)']
# 1  ['Electrical and Electronic Engineering', 'Ele...
# 2  ['Chemistry (all)', 'Chemical Engineering (all...
# 3  ['Chemistry (all)', 'Condensed Matter Physics'...
# 4  ['Analytical Chemistry', 'Biochemistry', 'Envi...
#
#                                              authors
# 0                   ['Pongpirul K.', 'Lungren M.P.']
# 1                  ['Pratumsiri T.', 'Janpugdee P.']
# 2  ['Phuakpunk K.', 'Chalermsinsuwan B.', 'Putivi...
# 3  ['Saengkaew J.', 'Le D.', 'Samart C.', 'Sawada...
# 4  ['Teengam P.', 'Siangproh W.', 'Tuantranont A....

# %%
df.describe(include='all')
# Out:
#                   file                 organizations       classifications  \
# count            20216                         20216                 20216
# unique           20216                         17209                    38
# top     201800000.json  ['Chulalongkorn University']  ['ASJC', 'SUBJABBR']
# freq                 1                           180                  7769
#
#                         affiliations auth-keywords               subjects  \
# count                          20216         20216                  20216
# unique                         10528         16304                   3105
# top     ['Chulalongkorn University']        [None]  ['Multidisciplinary']
# freq                            4225          3762                   1049
#
#                                      authors
# count                                  20216
# unique                                 18689
# top     ['Ukritchon B.', 'Keawsawasvong S.']
# freq                                      17

# %%
df.info
# Out:
# <bound method DataFrame.info of                  file                                      organizations  \
# 0      201800000.json  ['Department of Preventive and Social Medicine...
# 1      201800001.json  ['Department of Electrical Engineering', 'Wire...
# 2      201800002.json  ['Center of Excellence in Catalysis and Cataly...
# 3      201800003.json  ['Department of Chemistry', 'Faculty of Scienc...
# 4      201800004.json  ['Program in Petrochemistry', 'Faculty of Scie...
# ...               ...                                                ...
# 20211  202302885.json  ['Department of Chemical Technology', 'Faculty...
# 20212  202302886.json  ['Department of Chemistry', 'Faculty of Scienc...
# 20213  202302887.json  ['Centre for Education and International Devel...
# 20214  202302888.json  ['Program of Fisheries Science', 'Faculty of I...
# 20215  202302889.json  ['Faculty of Applied Science and Center for Pr...
#
#                                          classifications  \
# 0                                   ['ASJC', 'SUBJABBR']
# 1           ['ASJC', 'CPXCLASS', 'FLXCLASS', 'SUBJABBR']
# 2      ['CPXCLASS', 'ENCOMPASSCLASS', 'FLXCLASS', 'AS...
# 3           ['CPXCLASS', 'FLXCLASS', 'ASJC', 'SUBJABBR']
# 4                        ['EMCLASS', 'ASJC', 'SUBJABBR']
# ...                                                  ...
# 20211  ['CPXCLASS', 'ENCOMPASSCLASS', 'FLXCLASS', 'AS...
# 20212  ['CPXCLASS', 'FLXCLASS', 'GEOCLASS', 'ASJC', '...
# 20213                               ['ASJC', 'SUBJABBR']
# 20214                   ['GEOCLASS', 'ASJC', 'SUBJABBR']
# 20215                   ['GEOCLASS', 'ASJC', 'SUBJABBR']
#
#                                             affiliations  \
# 0      ['Stanford University School of Medicine', 'Ch...
# 1                           ['Chulalongkorn University']
# 2                           ['Chulalongkorn University']
# 3      ['Hirosaki University', 'Chulalongkorn Univers...
# 4      ['Chulalongkorn University', 'Thailand Nationa...
# ...                                                  ...
# 20211  ['Chulalongkorn University', 'Center of Excell...
# 20212                       ['Chulalongkorn University']
# 20213  ['Chulalongkorn University', 'UCL Institute of...
# 20214  ['Chulalongkorn University', 'Khon Kaen Univer...
# 20215  ['Chulalongkorn University', 'Cambodia Univers...
#
#                                            auth-keywords  \
# 0                                                 [None]
# 1                                                 [None]
# 2      ['Circulating fluidized bed', 'Computational f...
# 3      ['Encapsulation', 'Fluoroalkylsilane', 'Natura...
# 4      ['acpcPNA', 'Electrochemical impedance spectro...
# ...                                                  ...
# 20211  ['Long-chain olefins', 'Mesoporous KIT-6', 'Ol...
# 20212  ['Biological hazards', 'chemical hazards', 'fo...
# 20213  ['conflict', 'Education', 'peacebuilding', 'so...
# 20214  ['Anabas testudineus', 'Black soldier fly', 'f...
# 20215  ['Cambodia', 'consumption', 'expenditure', 'Im...
#
#                                                 subjects  \
# 0                                     ['Medicine (all)']
# 1      ['Electrical and Electronic Engineering', 'Ele...
# 2      ['Chemistry (all)', 'Chemical Engineering (all...
# 3      ['Chemistry (all)', 'Condensed Matter Physics'...
# 4      ['Analytical Chemistry', 'Biochemistry', 'Envi...
# ...                                                  ...
# 20211                   ['Catalysis', 'Chemistry (all)']
# 20212                           ['Analytical Chemistry']
# 20213                                      ['Education']
# 20214                     ['Ecology', 'Aquatic Science']
# 20215  ['Geography, Planning and Development', 'Devel...
#
#                                                  authors
# 0                       ['Pongpirul K.', 'Lungren M.P.']
# 1                      ['Pratumsiri T.', 'Janpugdee P.']
# 2      ['Phuakpunk K.', 'Chalermsinsuwan B.', 'Putivi...
# 3      ['Saengkaew J.', 'Le D.', 'Samart C.', 'Sawada...
# 4      ['Teengam P.', 'Siangproh W.', 'Tuantranont A....
# ...                                                  ...
# 20211  ['Le D.', 'Chaidherasuwet N.', 'Rueangthaweep ...
# 20212  ['Alahmad W.', 'Varanusupakul P.', 'Varanusupa...
# 20213                                     ['Pherali T.']
# 20214  ['Mapanao R.', 'Jiwyam W.', 'Nithikulworawong ...
# 20215                                        ['Chea V.']
#
# [20216 rows x 7 columns]>

# %%
df.shape
# Out:
# (20216, 7)

# %% [markdown]
# ## Join table between features and references

# %% [markdown]
# ### Create data frame of reference pivot

# %%
df_references = pd.read_csv('references/references_pivot.csv')
df_references.describe(include='all')
# Out:
#                   file reference
# count            20204     20204
# unique           20204     19788
# top     201800000.json        []
# freq                 1       411

# %%
shape_df_references = df_references.shape
print("Shape df references: ",shape_df_references)
df_references.head(5)
# Out:
# Shape df references:  (20204, 2)
#              file                                          reference
# 0  201800000.json  ['Science.', 'The future of public health', 'I...
# 1  201800001.json  ['Proc. CAMA 2015', 'Proc. 2015 Thailand-Japan...
# 2  201800002.json  ['AICHE J.', 'Int. J. Hydrog. Energy', 'Chem. ...
# 3  201800003.json  ['Desalination', 'J. Membr. Sci.', 'Appl. Cata...
# 4  201800004.json  ['Int. J. Tubercul. Lung Dis.', 'Lancet Infect...

# %%
df_references.info
# Out:
# <bound method DataFrame.info of                  file                                          reference
# 0      201800000.json  ['Science.', 'The future of public health', 'I...
# 1      201800001.json  ['Proc. CAMA 2015', 'Proc. 2015 Thailand-Japan...
# 2      201800002.json  ['AICHE J.', 'Int. J. Hydrog. Energy', 'Chem. ...
# 3      201800003.json  ['Desalination', 'J. Membr. Sci.', 'Appl. Cata...
# 4      201800004.json  ['Int. J. Tubercul. Lung Dis.', 'Lancet Infect...
# ...               ...                                                ...
# 20199  202302885.json  ['ChemSusChem', 'Chemical Economics Handbook. ...
# 20200  202302886.json  ['Imported and Manufactured Food Program Inspe...
# 20201  202302887.json  ['Leaving Terrorism Behind: Individual and Col...
# 20202  202302888.json  ['International Journal of Fisheries and Aquac...
# 20203  202302889.json  ['World Development', 'International Migration...
#
# [20204 rows x 2 columns]>

# %% [markdown]
# ### Create data frame of features

# %%
df_features = pd.read_csv('data/features_separate.csv')
df_features.describe(include='all')
# Out:
#                   file                 organizations       classifications  \
# count            20216                         20216                 20216
# unique           20216                         17209                    38
# top     201800000.json  ['Chulalongkorn University']  ['ASJC', 'SUBJABBR']
# freq                 1                           180                  7769
#
#                         affiliations auth-keywords               subjects  \
# count                          20216         20216                  20216
# unique                         10528         16304                   3105
# top     ['Chulalongkorn University']        [None]  ['Multidisciplinary']
# freq                            4225          3762                   1049
#
#                                      authors
# count                                  20216
# unique                                 18689
# top     ['Ukritchon B.', 'Keawsawasvong S.']
# freq                                      17

# %%
shape_df_features = df_features.shape
print("Shape df features: ",shape_df_features)
df_features.head(10)
# Out:
# Shape df features:  (20216, 7)
#              file                                      organizations  \
# 0  201800000.json  ['Department of Preventive and Social Medicine...
# 1  201800001.json  ['Department of Electrical Engineering', 'Wire...
# 2  201800002.json  ['Center of Excellence in Catalysis and Cataly...
# 3  201800003.json  ['Department of Chemistry', 'Faculty of Scienc...
# 4  201800004.json  ['Program in Petrochemistry', 'Faculty of Scie...
# 5  201800005.json  ['Chulalongkorn Business School', 'Chulalongko...
# 6  201800006.json  ['Department of Pediatrics', 'Faculty of Medic...
# 7  201800007.json  ['Department of Radiation Oncology', 'Medical ...
# 8  201800008.json  ['Department of Computer Engineering', 'Facult...
# 9  201800009.json  ['Petroleum and Petrochemical College', 'Chula...
#
#                                      classifications  \
# 0                               ['ASJC', 'SUBJABBR']
# 1       ['ASJC', 'CPXCLASS', 'FLXCLASS', 'SUBJABBR']
# 2  ['CPXCLASS', 'ENCOMPASSCLASS', 'FLXCLASS', 'AS...
# 3       ['CPXCLASS', 'FLXCLASS', 'ASJC', 'SUBJABBR']
# 4                    ['EMCLASS', 'ASJC', 'SUBJABBR']
# 5                               ['ASJC', 'SUBJABBR']
# 6       ['CABSCLASS', 'EMCLASS', 'ASJC', 'SUBJABBR']
# 7                               ['ASJC', 'SUBJABBR']
# 8       ['ASJC', 'CPXCLASS', 'FLXCLASS', 'SUBJABBR']
# 9                               ['ASJC', 'SUBJABBR']
#
#                                         affiliations  \
# 0  ['Stanford University School of Medicine', 'Ch...
# 1                       ['Chulalongkorn University']
# 2                       ['Chulalongkorn University']
# 3  ['Hirosaki University', 'Chulalongkorn Univers...
# 4  ['Chulalongkorn University', 'Thailand Nationa...
# 5                  ['Chulalongkorn Business School']
# 6  ['Chulalongkorn University', 'King Chulalongko...
# 7  ['Chulalongkorn University', 'The University o...
# 8  ['Chulalongkorn University', 'Thailand Nationa...
# 9                       ['Chulalongkorn University']
#
#                                        auth-keywords  \
# 0                                             [None]
# 1                                             [None]
# 2  ['Circulating fluidized bed', 'Computational f...
# 3  ['Encapsulation', 'Fluoroalkylsilane', 'Natura...
# 4  ['acpcPNA', 'Electrochemical impedance spectro...
# 5  ['Design of experiment', 'Optimal fleet size',...
# 6  ['Female', 'Hyperammonemia', 'Novel mutations'...
# 7                                             [None]
# 8  ['Attention mechanism', 'Bi-directional GRU', ...
# 9                                             [None]
#
#                                             subjects  \
# 0                                 ['Medicine (all)']
# 1  ['Electrical and Electronic Engineering', 'Ele...
# 2  ['Chemistry (all)', 'Chemical Engineering (all...
# 3  ['Chemistry (all)', 'Condensed Matter Physics'...
# 4  ['Analytical Chemistry', 'Biochemistry', 'Envi...
# 5  ['Business and International Management', 'Str...
# 6                                       ['Genetics']
# 7                                 ['Medicine (all)']
# 8  ['Decision Sciences (miscellaneous)', 'Informa...
# 9  ['Materials Science (all)', 'Condensed Matter ...
#
#                                              authors
# 0                   ['Pongpirul K.', 'Lungren M.P.']
# 1                  ['Pratumsiri T.', 'Janpugdee P.']
# 2  ['Phuakpunk K.', 'Chalermsinsuwan B.', 'Putivi...
# 3  ['Saengkaew J.', 'Le D.', 'Samart C.', 'Sawada...
# 4  ['Teengam P.', 'Siangproh W.', 'Tuantranont A....
# 5                                ['Setamanit S.-O.']
# 6  ['Chongsrisawat V.', 'Damrongphol P.', 'Ittiwu...
# 7     ['Johnstone C.', 'Ghia A.J.', 'Prayongrat A.']
# 8   ['Kowsrihawat K.', 'Vateekul P.', 'Boonkwan P.']
# 9           ['Pitakchatwong C.', 'Chirachanchai S.']

# %% [markdown]
# ### Create data frame of titles and publish names

# %%
df_titles = pd.read_csv('title_publish/title_publish_name_separate.csv')
df_titles.describe(include='all')
# Out:
#                   file    title        publish_name
# count            20216    20215               20216
# unique           20216    20140                5501
# top     201800000.json  Preface  Scientific Reports
# freq                 1       18                 438

# %%
shape_df_titles = df_titles.shape
print("Shape df titles: ",shape_df_titles)
df_titles.head(10)
# Out:
# Shape df titles:  (20216, 3)
#              file                                              title  \
# 0  201800000.json  Public health and international epidemiology f...
# 1  201800001.json  Flexible Printed Active Antenna for Digital Te...
# 2  201800002.json  Parametric study of hydrogen production via so...
# 3  201800003.json  Superhydrophobic coating from fluoroalkylsilan...
# 4  201800004.json  Electrochemical impedance-based DNA sensor usi...
# 5  201800005.json  Evaluation of outsourcing transportation contr...
# 6  201800006.json  The phenotypic and mutational spectrum of Thai...
# 7  201800007.json  External beam radiotherapy in the treatment of...
# 8  201800008.json  Predicting judicial decisions of criminal case...
# 9  201800009.json  PH Variation as a Simple and Selective Pathway...
#
#                                         publish_name
# 0  Radiology in Global Health: Strategies, Implem...
# 1    Progress in Electromagnetics Research Symposium
# 2                       Chemical Engineering Science
# 3                            Applied Surface Science
# 4                             Analytica Chimica Acta
# 5               Polish Journal of Management Studies
# 6                                               Gene
# 7  Essentials of Interventional Cancer Pain Manag...
# 8  Proceedings of the 5th Asian Conference on Def...
# 9                                           Langmuir

# %% [markdown]
# ### Join data frame

# %%
df_join_features_ref = pd.merge(df_features, df_references, on='file', how='left')
df_join_features_ref.head(5)
# Out:
#              file                                      organizations  \
# 0  201800000.json  ['Department of Preventive and Social Medicine...
# 1  201800001.json  ['Department of Electrical Engineering', 'Wire...
# 2  201800002.json  ['Center of Excellence in Catalysis and Cataly...
# 3  201800003.json  ['Department of Chemistry', 'Faculty of Scienc...
# 4  201800004.json  ['Program in Petrochemistry', 'Faculty of Scie...
#
#                                      classifications  \
# 0                               ['ASJC', 'SUBJABBR']
# 1       ['ASJC', 'CPXCLASS', 'FLXCLASS', 'SUBJABBR']
# 2  ['CPXCLASS', 'ENCOMPASSCLASS', 'FLXCLASS', 'AS...
# 3       ['CPXCLASS', 'FLXCLASS', 'ASJC', 'SUBJABBR']
# 4                    ['EMCLASS', 'ASJC', 'SUBJABBR']
#
#                                         affiliations  \
# 0  ['Stanford University School of Medicine', 'Ch...
# 1                       ['Chulalongkorn University']
# 2                       ['Chulalongkorn University']
# 3  ['Hirosaki University', 'Chulalongkorn Univers...
# 4  ['Chulalongkorn University', 'Thailand Nationa...
#
#                                        auth-keywords  \
# 0                                             [None]
# 1                                             [None]
# 2  ['Circulating fluidized bed', 'Computational f...
# 3  ['Encapsulation', 'Fluoroalkylsilane', 'Natura...
# 4  ['acpcPNA', 'Electrochemical impedance spectro...
#
#                                             subjects  \
# 0                                 ['Medicine (all)']
# 1  ['Electrical and Electronic Engineering', 'Ele...
# 2  ['Chemistry (all)', 'Chemical Engineering (all...
# 3  ['Chemistry (all)', 'Condensed Matter Physics'...
# 4  ['Analytical Chemistry', 'Biochemistry', 'Envi...
#
#                                              authors  \
# 0                   ['Pongpirul K.', 'Lungren M.P.']
# 1                  ['Pratumsiri T.', 'Janpugdee P.']
# 2  ['Phuakpunk K.', 'Chalermsinsuwan B.', 'Putivi...
# 3  ['Saengkaew J.', 'Le D.', 'Samart C.', 'Sawada...
# 4  ['Teengam P.', 'Siangproh W.', 'Tuantranont A....
#
#                                            reference
# 0  ['Science.', 'The future of public health', 'I...
# 1  ['Proc. CAMA 2015', 'Proc. 2015 Thailand-Japan...
# 2  ['AICHE J.', 'Int. J. Hydrog. Energy', 'Chem. ...
# 3  ['Desalination', 'J. Membr. Sci.', 'Appl. Cata...
# 4  ['Int. J. Tubercul. Lung Dis.', 'Lancet Infect...

# %%
df_join_features_ref.info
# Out:
# <bound method DataFrame.info of                  file                                      organizations  \
# 0      201800000.json  ['Department of Preventive and Social Medicine...
# 1      201800001.json  ['Department of Electrical Engineering', 'Wire...
# 2      201800002.json  ['Center of Excellence in Catalysis and Cataly...
# 3      201800003.json  ['Department of Chemistry', 'Faculty of Scienc...
# 4      201800004.json  ['Program in Petrochemistry', 'Faculty of Scie...
# ...               ...                                                ...
# 20211  202302885.json  ['Department of Chemical Technology', 'Faculty...
# 20212  202302886.json  ['Department of Chemistry', 'Faculty of Scienc...
# 20213  202302887.json  ['Centre for Education and International Devel...
# 20214  202302888.json  ['Program of Fisheries Science', 'Faculty of I...
# 20215  202302889.json  ['Faculty of Applied Science and Center for Pr...
#
#                                          classifications  \
# 0                                   ['ASJC', 'SUBJABBR']
# 1           ['ASJC', 'CPXCLASS', 'FLXCLASS', 'SUBJABBR']
# 2      ['CPXCLASS', 'ENCOMPASSCLASS', 'FLXCLASS', 'AS...
# 3           ['CPXCLASS', 'FLXCLASS', 'ASJC', 'SUBJABBR']
# 4                        ['EMCLASS', 'ASJC', 'SUBJABBR']
# ...                                                  ...
# 20211  ['CPXCLASS', 'ENCOMPASSCLASS', 'FLXCLASS', 'AS...
# 20212  ['CPXCLASS', 'FLXCLASS', 'GEOCLASS', 'ASJC', '...
# 20213                               ['ASJC', 'SUBJABBR']
# 20214                   ['GEOCLASS', 'ASJC', 'SUBJABBR']
# 20215                   ['GEOCLASS', 'ASJC', 'SUBJABBR']
#
#                                             affiliations  \
# 0      ['Stanford University School of Medicine', 'Ch...
# 1                           ['Chulalongkorn University']
# 2                           ['Chulalongkorn University']
# 3      ['Hirosaki University', 'Chulalongkorn Univers...
# 4      ['Chulalongkorn University', 'Thailand Nationa...
# ...                                                  ...
# 20211  ['Chulalongkorn University', 'Center of Excell...
# 20212                       ['Chulalongkorn University']
# 20213  ['Chulalongkorn University', 'UCL Institute of...
# 20214  ['Chulalongkorn University', 'Khon Kaen Univer...
# 20215  ['Chulalongkorn University', 'Cambodia Univers...
#
#                                            auth-keywords  \
# 0                                                 [None]
# 1                                                 [None]
# 2      ['Circulating fluidized bed', 'Computational f...
# 3      ['Encapsulation', 'Fluoroalkylsilane', 'Natura...
# 4      ['acpcPNA', 'Electrochemical impedance spectro...
# ...                                                  ...
# 20211  ['Long-chain olefins', 'Mesoporous KIT-6', 'Ol...
# 20212  ['Biological hazards', 'chemical hazards', 'fo...
# 20213  ['conflict', 'Education', 'peacebuilding', 'so...
# 20214  ['Anabas testudineus', 'Black soldier fly', 'f...
# 20215  ['Cambodia', 'consumption', 'expenditure', 'Im...
#
#                                                 subjects  \
# 0                                     ['Medicine (all)']
# 1      ['Electrical and Electronic Engineering', 'Ele...
# 2      ['Chemistry (all)', 'Chemical Engineering (all...
# 3      ['Chemistry (all)', 'Condensed Matter Physics'...
# 4      ['Analytical Chemistry', 'Biochemistry', 'Envi...
# ...                                                  ...
# 20211                   ['Catalysis', 'Chemistry (all)']
# 20212                           ['Analytical Chemistry']
# 20213                                      ['Education']
# 20214                     ['Ecology', 'Aquatic Science']
# 20215  ['Geography, Planning and Development', 'Devel...
#
#                                                  authors  \
# 0                       ['Pongpirul K.', 'Lungren M.P.']
# 1                      ['Pratumsiri T.', 'Janpugdee P.']
# 2      ['Phuakpunk K.', 'Chalermsinsuwan B.', 'Putivi...
# 3      ['Saengkaew J.', 'Le D.', 'Samart C.', 'Sawada...
# 4      ['Teengam P.', 'Siangproh W.', 'Tuantranont A....
# ...                                                  ...
# 20211  ['Le D.', 'Chaidherasuwet N.', 'Rueangthaweep ...
# 20212  ['Alahmad W.', 'Varanusupakul P.', 'Varanusupa...
# 20213                                     ['Pherali T.']
# 20214  ['Mapanao R.', 'Jiwyam W.', 'Nithikulworawong ...
# 20215                                        ['Chea V.']
#
#                                                reference
# 0      ['Science.', 'The future of public health', 'I...
# 1      ['Proc. CAMA 2015', 'Proc. 2015 Thailand-Japan...
# 2      ['AICHE J.', 'Int. J. Hydrog. Energy', 'Chem. ...
# 3      ['Desalination', 'J. Membr. Sci.', 'Appl. Cata...
# 4      ['Int. J. Tubercul. Lung Dis.', 'Lancet Infect...
# ...                                                  ...
# 20211  ['ChemSusChem', 'Chemical Economics Handbook. ...
# 20212  ['Imported and Manufactured Food Program Inspe...
# 20213  ['Leaving Terrorism Behind: Individual and Col...
# 20214  ['International Journal of Fisheries and Aquac...
# 20215  ['World Development', 'International Migration...
#
# [20216 rows x 8 columns]>

# %%
df_join_features_ref.describe(include='all')
# Out:
#                   file                 organizations       classifications  \
# count            20216                         20216                 20216
# unique           20216                         17209                    38
# top     201800000.json  ['Chulalongkorn University']  ['ASJC', 'SUBJABBR']
# freq                 1                           180                  7769
#
#                         affiliations auth-keywords               subjects  \
# count                          20216         20216                  20216
# unique                         10528         16304                   3105
# top     ['Chulalongkorn University']        [None]  ['Multidisciplinary']
# freq                            4225          3762                   1049
#
#                                      authors reference
# count                                  20216     20204
# unique                                 18689     19788
# top     ['Ukritchon B.', 'Keawsawasvong S.']        []
# freq                                      17       411

# %%
df_join_features_titles = pd.merge(df_join_features_ref, df_titles, on='file', how='left')
df_join_features_titles.head(5)
# Out:
#              file                                      organizations  \
# 0  201800000.json  ['Department of Preventive and Social Medicine...
# 1  201800001.json  ['Department of Electrical Engineering', 'Wire...
# 2  201800002.json  ['Center of Excellence in Catalysis and Cataly...
# 3  201800003.json  ['Department of Chemistry', 'Faculty of Scienc...
# 4  201800004.json  ['Program in Petrochemistry', 'Faculty of Scie...
#
#                                      classifications  \
# 0                               ['ASJC', 'SUBJABBR']
# 1       ['ASJC', 'CPXCLASS', 'FLXCLASS', 'SUBJABBR']
# 2  ['CPXCLASS', 'ENCOMPASSCLASS', 'FLXCLASS', 'AS...
# 3       ['CPXCLASS', 'FLXCLASS', 'ASJC', 'SUBJABBR']
# 4                    ['EMCLASS', 'ASJC', 'SUBJABBR']
#
#                                         affiliations  \
# 0  ['Stanford University School of Medicine', 'Ch...
# 1                       ['Chulalongkorn University']
# 2                       ['Chulalongkorn University']
# 3  ['Hirosaki University', 'Chulalongkorn Univers...
# 4  ['Chulalongkorn University', 'Thailand Nationa...
#
#                                        auth-keywords  \
# 0                                             [None]
# 1                                             [None]
# 2  ['Circulating fluidized bed', 'Computational f...
# 3  ['Encapsulation', 'Fluoroalkylsilane', 'Natura...
# 4  ['acpcPNA', 'Electrochemical impedance spectro...
#
#                                             subjects  \
# 0                                 ['Medicine (all)']
# 1  ['Electrical and Electronic Engineering', 'Ele...
# 2  ['Chemistry (all)', 'Chemical Engineering (all...
# 3  ['Chemistry (all)', 'Condensed Matter Physics'...
# 4  ['Analytical Chemistry', 'Biochemistry', 'Envi...
#
#                                              authors  \
# 0                   ['Pongpirul K.', 'Lungren M.P.']
# 1                  ['Pratumsiri T.', 'Janpugdee P.']
# 2  ['Phuakpunk K.', 'Chalermsinsuwan B.', 'Putivi...
# 3  ['Saengkaew J.', 'Le D.', 'Samart C.', 'Sawada...
# 4  ['Teengam P.', 'Siangproh W.', 'Tuantranont A....
#
#                                            reference  \
# 0  ['Science.', 'The future of public health', 'I...
# 1  ['Proc. CAMA 2015', 'Proc. 2015 Thailand-Japan...
# 2  ['AICHE J.', 'Int. J. Hydrog. Energy', 'Chem. ...
# 3  ['Desalination', 'J. Membr. Sci.', 'Appl. Cata...
# 4  ['Int. J. Tubercul. Lung Dis.', 'Lancet Infect...
#
#                                                title  \
# 0  Public health and international epidemiology f...
# 1  Flexible Printed Active Antenna for Digital Te...
# 2  Parametric study of hydrogen production via so...
# 3  Superhydrophobic coating from fluoroalkylsilan...
# 4  Electrochemical impedance-based DNA sensor usi...
#
#                                         publish_name
# 0  Radiology in Global Health: Strategies, Implem...
# 1    Progress in Electromagnetics Research Symposium
# 2                       Chemical Engineering Science
# 3                            Applied Surface Science
# 4                             Analytica Chimica Acta

# %%
df_join_features_titles.info
# Out:
# <bound method DataFrame.info of                  file                                      organizations  \
# 0      201800000.json  ['Department of Preventive and Social Medicine...
# 1      201800001.json  ['Department of Electrical Engineering', 'Wire...
# 2      201800002.json  ['Center of Excellence in Catalysis and Cataly...
# 3      201800003.json  ['Department of Chemistry', 'Faculty of Scienc...
# 4      201800004.json  ['Program in Petrochemistry', 'Faculty of Scie...
# ...               ...                                                ...
# 20211  202302885.json  ['Department of Chemical Technology', 'Faculty...
# 20212  202302886.json  ['Department of Chemistry', 'Faculty of Scienc...
# 20213  202302887.json  ['Centre for Education and International Devel...
# 20214  202302888.json  ['Program of Fisheries Science', 'Faculty of I...
# 20215  202302889.json  ['Faculty of Applied Science and Center for Pr...
#
#                                          classifications  \
# 0                                   ['ASJC', 'SUBJABBR']
# 1           ['ASJC', 'CPXCLASS', 'FLXCLASS', 'SUBJABBR']
# 2      ['CPXCLASS', 'ENCOMPASSCLASS', 'FLXCLASS', 'AS...
# 3           ['CPXCLASS', 'FLXCLASS', 'ASJC', 'SUBJABBR']
# 4                        ['EMCLASS', 'ASJC', 'SUBJABBR']
# ...                                                  ...
# 20211  ['CPXCLASS', 'ENCOMPASSCLASS', 'FLXCLASS', 'AS...
# 20212  ['CPXCLASS', 'FLXCLASS', 'GEOCLASS', 'ASJC', '...
# 20213                               ['ASJC', 'SUBJABBR']
# 20214                   ['GEOCLASS', 'ASJC', 'SUBJABBR']
# 20215                   ['GEOCLASS', 'ASJC', 'SUBJABBR']
#
#                                             affiliations  \
# 0      ['Stanford University School of Medicine', 'Ch...
# 1                           ['Chulalongkorn University']
# 2                           ['Chulalongkorn University']
# 3      ['Hirosaki University', 'Chulalongkorn Univers...
# 4      ['Chulalongkorn University', 'Thailand Nationa...
# ...                                                  ...
# 20211  ['Chulalongkorn University', 'Center of Excell...
# 20212                       ['Chulalongkorn University']
# 20213  ['Chulalongkorn University', 'UCL Institute of...
# 20214  ['Chulalongkorn University', 'Khon Kaen Univer...
# 20215  ['Chulalongkorn University', 'Cambodia Univers...
#
#                                            auth-keywords  \
# 0                                                 [None]
# 1                                                 [None]
# 2      ['Circulating fluidized bed', 'Computational f...
# 3      ['Encapsulation', 'Fluoroalkylsilane', 'Natura...
# 4      ['acpcPNA', 'Electrochemical impedance spectro...
# ...                                                  ...
# 20211  ['Long-chain olefins', 'Mesoporous KIT-6', 'Ol...
# 20212  ['Biological hazards', 'chemical hazards', 'fo...
# 20213  ['conflict', 'Education', 'peacebuilding', 'so...
# 20214  ['Anabas testudineus', 'Black soldier fly', 'f...
# 20215  ['Cambodia', 'consumption', 'expenditure', 'Im...
#
#                                                 subjects  \
# 0                                     ['Medicine (all)']
# 1      ['Electrical and Electronic Engineering', 'Ele...
# 2      ['Chemistry (all)', 'Chemical Engineering (all...
# 3      ['Chemistry (all)', 'Condensed Matter Physics'...
# 4      ['Analytical Chemistry', 'Biochemistry', 'Envi...
# ...                                                  ...
# 20211                   ['Catalysis', 'Chemistry (all)']
# 20212                           ['Analytical Chemistry']
# 20213                                      ['Education']
# 20214                     ['Ecology', 'Aquatic Science']
# 20215  ['Geography, Planning and Development', 'Devel...
#
#                                                  authors  \
# 0                       ['Pongpirul K.', 'Lungren M.P.']
# 1                      ['Pratumsiri T.', 'Janpugdee P.']
# 2      ['Phuakpunk K.', 'Chalermsinsuwan B.', 'Putivi...
# 3      ['Saengkaew J.', 'Le D.', 'Samart C.', 'Sawada...
# 4      ['Teengam P.', 'Siangproh W.', 'Tuantranont A....
# ...                                                  ...
# 20211  ['Le D.', 'Chaidherasuwet N.', 'Rueangthaweep ...
# 20212  ['Alahmad W.', 'Varanusupakul P.', 'Varanusupa...
# 20213                                     ['Pherali T.']
# 20214  ['Mapanao R.', 'Jiwyam W.', 'Nithikulworawong ...
# 20215                                        ['Chea V.']
#
#                                                reference  \
# 0      ['Science.', 'The future of public health', 'I...
# 1      ['Proc. CAMA 2015', 'Proc. 2015 Thailand-Japan...
# 2      ['AICHE J.', 'Int. J. Hydrog. Energy', 'Chem. ...
# 3      ['Desalination', 'J. Membr. Sci.', 'Appl. Cata...
# 4      ['Int. J. Tubercul. Lung Dis.', 'Lancet Infect...
# ...                                                  ...
# 20211  ['ChemSusChem', 'Chemical Economics Handbook. ...
# 20212  ['Imported and Manufactured Food Program Inspe...
# 20213  ['Leaving Terrorism Behind: Individual and Col...
# 20214  ['International Journal of Fisheries and Aquac...
# 20215  ['World Development', 'International Migration...
#
#                                                    title  \
# 0      Public health and international epidemiology f...
# 1      Flexible Printed Active Antenna for Digital Te...
# 2      Parametric study of hydrogen production via so...
# 3      Superhydrophobic coating from fluoroalkylsilan...
# 4      Electrochemical impedance-based DNA sensor usi...
# ...                                                  ...
# 20211  Long-chain bio-olefins production via oxidativ...
# 20212  Recent Developments and Applications of Microf...
# 20213  Social justice, education and peacebuilding: c...
# 20214  Effects of black soldier fly (Hermetia illucen...
# 20215  Effects of remittances on household poverty an...
#
#                                             publish_name
# 0      Radiology in Global Health: Strategies, Implem...
# 1        Progress in Electromagnetics Research Symposium
# 2                           Chemical Engineering Science
# 3                                Applied Surface Science
# 4                                 Analytica Chimica Acta
# ...                                                  ...
# 20211                                    Catalysis Today
# 20212           Critical Reviews in Analytical Chemistry
# 20213                                            Compare
# 20214                     Journal of Applied Aquaculture
# 20215                Journal of the Asia Pacific Economy
#
# [20216 rows x 10 columns]>

# %%
shape_df_join_features = df_join_features_titles.shape
column_df_join_features = df_join_features_titles.columns
print("Shape df join features: ",shape_df_join_features)
print("Columns df join features: ",column_df_join_features)
# Out:
# Shape df join features:  (20216, 10)
# Columns df join features:  Index(['file', 'organizations', 'classifications', 'affiliations',
#        'auth-keywords', 'subjects', 'authors', 'reference', 'title',
#        'publish_name'],
#       dtype='object')

# %%
df_join_features_titles.to_csv('data/features_summation.csv', index=False, encoding='utf-8')
