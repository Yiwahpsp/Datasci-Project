# %%
import pandas as pd
import numpy as np
import json
import glob
import os
import logging
import ast
from pathlib import Path
from pyspark.sql import SparkSession
from pyspark.sql.functions import explode

# %%
df = pd.read_csv('data/features_summation.csv')
df.describe(include='all')
# Out:
#                   file                 organizations       classifications  \
# count            20216                         20216                 20216
# unique           20216                         17209                    38
# top     201800000.json  ['Chulalongkorn University']  ['ASJC', 'SUBJABBR']
# freq                 1                           180                  7769
#
#                         affiliations auth-keywords               subjects  \
# count                          20216         20216                  20216
# unique                         10528         16304                   3105
# top     ['Chulalongkorn University']        [None]  ['Multidisciplinary']
# freq                            4225          3762                   1049
#
#                                      authors reference    title  \
# count                                  20216     20204    20215
# unique                                 18689     19788    20140
# top     ['Ukritchon B.', 'Keawsawasvong S.']        []  Preface
# freq                                      17       411       18
#
#               publish_name
# count                20216
# unique                5501
# top     Scientific Reports
# freq                   438

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20216 entries, 0 to 20215
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   file             20216 non-null  object
#  1   organizations    20216 non-null  object
#  2   classifications  20216 non-null  object
#  3   affiliations     20216 non-null  object
#  4   auth-keywords    20216 non-null  object
#  5   subjects         20216 non-null  object
#  6   authors          20216 non-null  object
#  7   reference        20204 non-null  object
#  8   title            20215 non-null  object
#  9   publish_name     20216 non-null  object
# dtypes: object(10)
# memory usage: 1.5+ MB

# %%
shape_df = df.shape
columns_df = df.columns
print("Shape of features_summation.csv: ", shape_df)
print("Columns of features_summation.csv: ", columns_df)
# Out:
# Shape of features_summation.csv:  (20216, 10)
# Columns of features_summation.csv:  Index(['file', 'organizations', 'classifications', 'affiliations',
#        'auth-keywords', 'subjects', 'authors', 'reference', 'title',
#        'publish_name'],
#       dtype='object')

# %%
df.head(5)
# Out:
#              file                                      organizations  \
# 0  201800000.json  ['Department of Preventive and Social Medicine...
# 1  201800001.json  ['Department of Electrical Engineering', 'Wire...
# 2  201800002.json  ['Center of Excellence in Catalysis and Cataly...
# 3  201800003.json  ['Department of Chemistry', 'Faculty of Scienc...
# 4  201800004.json  ['Program in Petrochemistry', 'Faculty of Scie...
#
#                                      classifications  \
# 0                               ['ASJC', 'SUBJABBR']
# 1       ['ASJC', 'CPXCLASS', 'FLXCLASS', 'SUBJABBR']
# 2  ['CPXCLASS', 'ENCOMPASSCLASS', 'FLXCLASS', 'AS...
# 3       ['CPXCLASS', 'FLXCLASS', 'ASJC', 'SUBJABBR']
# 4                    ['EMCLASS', 'ASJC', 'SUBJABBR']
#
#                                         affiliations  \
# 0  ['Stanford University School of Medicine', 'Ch...
# 1                       ['Chulalongkorn University']
# 2                       ['Chulalongkorn University']
# 3  ['Hirosaki University', 'Chulalongkorn Univers...
# 4  ['Chulalongkorn University', 'Thailand Nationa...
#
#                                        auth-keywords  \
# 0                                             [None]
# 1                                             [None]
# 2  ['Circulating fluidized bed', 'Computational f...
# 3  ['Encapsulation', 'Fluoroalkylsilane', 'Natura...
# 4  ['acpcPNA', 'Electrochemical impedance spectro...
#
#                                             subjects  \
# 0                                 ['Medicine (all)']
# 1  ['Electrical and Electronic Engineering', 'Ele...
# 2  ['Chemistry (all)', 'Chemical Engineering (all...
# 3  ['Chemistry (all)', 'Condensed Matter Physics'...
# 4  ['Analytical Chemistry', 'Biochemistry', 'Envi...
#
#                                              authors  \
# 0                   ['Pongpirul K.', 'Lungren M.P.']
# 1                  ['Pratumsiri T.', 'Janpugdee P.']
# 2  ['Phuakpunk K.', 'Chalermsinsuwan B.', 'Putivi...
# 3  ['Saengkaew J.', 'Le D.', 'Samart C.', 'Sawada...
# 4  ['Teengam P.', 'Siangproh W.', 'Tuantranont A....
#
#                                            reference  \
# 0  ['Science.', 'The future of public health', 'I...
# 1  ['Proc. CAMA 2015', 'Proc. 2015 Thailand-Japan...
# 2  ['AICHE J.', 'Int. J. Hydrog. Energy', 'Chem. ...
# 3  ['Desalination', 'J. Membr. Sci.', 'Appl. Cata...
# 4  ['Int. J. Tubercul. Lung Dis.', 'Lancet Infect...
#
#                                                title  \
# 0  Public health and international epidemiology f...
# 1  Flexible Printed Active Antenna for Digital Te...
# 2  Parametric study of hydrogen production via so...
# 3  Superhydrophobic coating from fluoroalkylsilan...
# 4  Electrochemical impedance-based DNA sensor usi...
#
#                                         publish_name
# 0  Radiology in Global Health: Strategies, Implem...
# 1    Progress in Electromagnetics Research Symposium
# 2                       Chemical Engineering Science
# 3                            Applied Surface Science
# 4                             Analytica Chimica Acta

# %%
df.isnull().sum()
# Out:
# file                0
# organizations       0
# classifications     0
# affiliations        0
# auth-keywords       0
# subjects            0
# authors             0
# reference          12
# title               1
# publish_name        0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
for column in columns_df:
  print(f"Value counts for column: {column}")
  print(df[column].value_counts())
  print("\n")
# Out:
# Value counts for column: file
# file
# 201800000.json    1
# 202200396.json    1
# 202200403.json    1
# 202200402.json    1
# 202200401.json    1
#                  ..
# 202000867.json    1
# 202000866.json    1
# 202000865.json    1
# 202000864.json    1
# 202302889.json    1
# Name: count, Length: 20203, dtype: int64
#
#
# Value counts for column: organizations
# organizations
# ['Chulalongkorn University']                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  180
# ['Department of Mathematics and Computer Science', 'Faculty of Science', 'Chulalongkorn University']                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           83
# ['Department of Computer Engineering', 'Faculty of Engineering', 'Chulalongkorn University']                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   76
# ['Department of Computer Engineering', 'Chulalongkorn University']                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             71
# ['College of Public Health Sciences', 'Chulalongkorn University']                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              68
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              ...
# ['Center of Excellence on Catalysis and Catalytic Reaction Engineering', 'Department of Chemical Engineering', 'Faculty of Engineering', 'Chulalongkorn University', 'SCG Chemicals Company', 'Ltd.']                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           1
# ['Department of Basic', 'Developmental and Educational Psychology', 'Autonomous University of Barcelona', 'Department of Medicine', 'International University of Catalunya', 'Parc Sanitari Sant Joan de Deu', 'Sant Boi de Llobregat', 'Network Centre for Biomedical Research in Mental Health (CIBERSAM)', 'Institute of Health Carlos III', 'Department of Basic and Clinical Psychology and Psychobiology', 'Universitat Jaume i', 'Biomedical Research Centre in Physiopathology of Obesity and Nutrition (CIBERobn)', 'Institute of Health Carlos III', 'Consorci Parc de Salut MAR de Barcelona', 'Barcelona', 'Psychology Department', 'Uppsala University', 'Personal Social Services Research Unit', 'London School of Economics and Political Science', 'Department of Biochemistry and Molecular Biomedicine', 'University of Barcelona', 'Institute of Biomedicine (IBUB)', 'University of Barcelona', 'Department of Evolutionary Biology', 'Ecology and Environmental Sciences', 'University of Barcelona', 'Faculty of Health', 'Queensland University of Technology', 'Department of Physiotherapy', 'University of Malaga and Biomedical Research Institute of Malaga (IBIMA)', 'Department of Psychiatry', 'Chulalongkorn University']      1
# ['Electrochemistry and Optical Spectroscopy Center of Excellence (EOSCE)', 'Department of Chemistry', 'Chulalongkorn University', 'Institute of Biotechnology and Genetic Engineering', 'Chulalongkorn University', 'Department of Microbiology', 'Faculty of Science', 'Chulalongkorn University', 'Department of Chemistry', 'Faculty of Science', 'Srinakharinwirot University', 'Center of Excellence on Petrochemical and Materials Technology', 'Chulalongkorn University']                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               1
# ['Department of Chemistry', 'Faculty of Science', 'Chulalongkorn University', 'Department of Pathology', 'Faculty of Veterinary Science', 'Chulalongkorn University', 'Mineed Technology', 'Department of Anatomy', 'Faculty of Veterinary Science', 'Chulalongkorn University', 'Center of Excellence in Advanced Materials and Bio-Interfaces', 'Chulalongkorn University', 'Nanotec-CU Center of Excellence on Food and Agriculture', 'Department of Chemistry', 'Faculty of Science', 'Chulalongkorn University', 'Department of Microbiology', 'Faculty of Medicine', 'Chulalongkorn University', 'Department of Medicine', 'Faculty of Medicine', 'Chulalongkorn University', 'Department of Microbiology', 'Faculty of Science', 'Chulalongkorn University']                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             1
# ['Faculty of Applied Science and Center for Professional Development and Training', 'Cambodia University of Technology and Science (CamTech)', 'Formerly College of Population Studies', 'Chulalongkorn University']                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            1
# Name: count, Length: 17200, dtype: int64
#
#
# Value counts for column: classifications
# classifications
# ['ASJC', 'SUBJABBR']                                                                                  7766
# ['EMCLASS', 'ASJC', 'SUBJABBR']                                                                       4837
# ['CPXCLASS', 'FLXCLASS', 'ASJC', 'SUBJABBR']                                                          3394
# ['CABSCLASS', 'EMCLASS', 'ASJC', 'SUBJABBR']                                                           988
# ['ASJC', 'CPXCLASS', 'FLXCLASS', 'SUBJABBR']                                                           795
# ['GEOCLASS', 'ASJC', 'SUBJABBR']                                                                       539
# ['CPXCLASS', 'ENCOMPASSCLASS', 'FLXCLASS', 'ASJC', 'SUBJABBR']                                         336
# ['CABSCLASS', 'ASJC', 'SUBJABBR']                                                                      270
# ['CPXCLASS', 'EMCLASS', 'FLXCLASS', 'ASJC', 'SUBJABBR']                                                243
# ['CPXCLASS', 'FLXCLASS', 'GEOCLASS', 'ASJC', 'SUBJABBR']                                               234
# ['CABSCLASS', 'GEOCLASS', 'ASJC', 'SUBJABBR']                                                          111
# ['CABSCLASS', 'CPXCLASS', 'EMCLASS', 'FLXCLASS', 'GEOCLASS', 'ASJC', 'SUBJABBR']                        85
# ['CPXCLASS', 'EMCLASS', 'FLXCLASS', 'GEOCLASS', 'ASJC', 'SUBJABBR']                                     74
# ['CABSCLASS', 'CPXCLASS', 'FLXCLASS', 'ASJC', 'SUBJABBR']                                               68
# ['EMCLASS', 'GEOCLASS', 'ASJC', 'SUBJABBR']                                                             68
# ['CABSCLASS', 'EMCLASS', 'GEOCLASS', 'ASJC', 'SUBJABBR']                                                67
# ['CABSCLASS', 'CPXCLASS', 'EMCLASS', 'FLXCLASS', 'ASJC', 'SUBJABBR']                                    66
# ['CPXCLASS', 'ENCOMPASSCLASS', 'FLXCLASS', 'GEOCLASS', 'ASJC', 'SUBJABBR']                              55
# ['FLXCLASS', 'ASJC', 'SUBJABBR']                                                                        37
# ['CABSCLASS', 'CPXCLASS', 'FLXCLASS', 'GEOCLASS', 'ASJC', 'SUBJABBR']                                   37
# ['ASJC', 'EMCLASS', 'SUBJABBR']                                                                         30
# ['ENCOMPASSCLASS', 'ASJC', 'SUBJABBR']                                                                  30
# ['ASJC', 'FLXCLASS', 'SUBJABBR']                                                                        24
# ['CABSCLASS', 'CPXCLASS', 'EMCLASS', 'ENCOMPASSCLASS', 'FLXCLASS', 'GEOCLASS', 'ASJC', 'SUBJABBR']      17
# ['CPXCLASS', 'EMCLASS', 'ENCOMPASSCLASS', 'FLXCLASS', 'GEOCLASS', 'ASJC', 'SUBJABBR']                    8
# ['CABSCLASS', 'CPXCLASS', 'ENCOMPASSCLASS', 'FLXCLASS', 'ASJC', 'SUBJABBR']                              4
# ['CABSCLASS', 'CPXCLASS', 'ENCOMPASSCLASS', 'FLXCLASS', 'GEOCLASS', 'ASJC', 'SUBJABBR']                  4
# ['EMCLASS', 'CPXCLASS', 'FLXCLASS', 'ASJC', 'SUBJABBR']                                                  3
# ['ENCOMPASSCLASS', 'GEOCLASS', 'ASJC', 'SUBJABBR']                                                       2
# ['CABSCLASS', 'EMCLASS', 'FLXCLASS', 'ASJC', 'SUBJABBR']                                                 2
# ['CPXCLASS', 'EMCLASS', 'ENCOMPASSCLASS', 'FLXCLASS', 'ASJC', 'SUBJABBR']                                2
# ['CABSCLASS', 'EMCLASS', 'ENCOMPASSCLASS', 'ASJC', 'SUBJABBR']                                           1
# ['CABSCLASS', 'CPXCLASS', 'EMCLASS', 'ENCOMPASSCLASS', 'FLXCLASS', 'ASJC', 'SUBJABBR']                   1
# ['ASJC', 'CPXCLASS', 'EMCLASS', 'FLXCLASS', 'SUBJABBR']                                                  1
# ['CABSCLASS', 'ENCOMPASSCLASS', 'GEOCLASS', 'ASJC', 'SUBJABBR']                                          1
# ['EMCLASS', 'FLXCLASS', 'ASJC', 'SUBJABBR']                                                              1
# ['EMCLASS', 'ENCOMPASSCLASS', 'GEOCLASS', 'ASJC', 'SUBJABBR']                                            1
# ['ASJC', 'CPXCLASS', 'FLXCLASS', 'GEOCLASS', 'SUBJABBR']                                                 1
# Name: count, dtype: int64
#
#
# Value counts for column: affiliations
# affiliations
# ['Chulalongkorn University']                                                                                                                                                                                                            4220
# ['Faculty of Medicine, Chulalongkorn University']                                                                                                                                                                                        201
# ['Chulalongkorn University', 'King Chulalongkorn Memorial Hospital']                                                                                                                                                                     201
# ['Chulalongkorn University', 'Mahidol University']                                                                                                                                                                                       190
# ['Chulalongkorn University', 'Faculty of Medicine, Chulalongkorn University']                                                                                                                                                            108
#                                                                                                                                                                                                                                         ...
# ['Faculty of Medicine Ramathibodi Hospital, Mahidol University', 'University of Illinois at Chicago', 'Chulalongkorn University', 'Faculty of Medicine, Khon Kaen University', 'King Chulalongkorn Memorial Hospital']                     1
# ['University of Bonab', 'Chulalongkorn University', 'Azarbaijan Shahid Madani University', 'East China Jiaotong University']                                                                                                               1
# ['Thai Red Cross Agency', 'Chulalongkorn University', 'University of California, San Francisco', 'Department of Psychological Sciences', 'HJF', 'Yale University', 'Universiteit van Amsterdam', 'US Military HIV Research Program']       1
# ['Chulalongkorn University', 'Southern Cross University']                                                                                                                                                                                  1
# ['Chulalongkorn University', 'Cambodia University of Technology and Science']                                                                                                                                                              1
# Name: count, Length: 10523, dtype: int64
#
#
# Value counts for column: auth-keywords
# auth-keywords
# [None]                                                                                                                                                                       3756
# ['Beyond Standard Model', 'Hadron-Hadron scattering (experiments)']                                                                                                            18
# ['Hadron-Hadron scattering (experiments)', 'Top physics']                                                                                                                      15
# ['Hadron-Hadron scattering (experiments)', 'Supersymmetry']                                                                                                                    14
# ['Hadron-Hadron scattering (experiments)', 'Higgs physics']                                                                                                                    13
#                                                                                                                                                                              ...
# ['biosurfactants', 'drilling waste', 'polyolefin biodegradation', 'sequential treatment', 'soil washing']                                                                       1
# ['Extracellular vesicles', 'Malaria', 'microRNAs', 'Patients', 'Plasmodium falciparum', 'Plasmodium vivax']                                                                     1
# ['Genetic susceptibility', 'Genome-wide association study', 'Polygenic risk score', 'Single nucleotide polymorphisms', 'Systemic lupus erythematosus', 'Thai population']       1
# ['Chelation therapy', 'Chronic Lead poisoning', 'Hepatic fibrosis', 'Hepatic Steatosis', 'Hepatotoxicity', 'Oxidative stress']                                                  1
# ['Cambodia', 'consumption', 'expenditure', 'Impact', 'inequality', 'remittances']                                                                                               1
# Name: count, Length: 16297, dtype: int64
#
#
# Value counts for column: subjects
# subjects
# ['Multidisciplinary']                                                                                                                                                           1048
# ['Medicine (all)']                                                                                                                                                               638
# ['Nuclear and High Energy Physics']                                                                                                                                              411
# ['Veterinary (all)']                                                                                                                                                             313
# ['Physics and Astronomy (all)']                                                                                                                                                  230
#                                                                                                                                                                                 ...
# ['Social Psychology', 'Archeology', 'Sociology and Political Science', 'Social Sciences (miscellaneous)', 'Geriatrics and Gerontology', 'Life-span and Life-course Studies']       1
# ['Agricultural and Biological Sciences (all)', 'Environmental Science (all)', 'Engineering (all)', 'Immunology and Microbiology (all)']                                            1
# ['Physical Therapy, Sports Therapy and Rehabilitation', 'Orthopedics and Sports Medicine', 'Rehabilitation']                                                                       1
# ['Civil and Structural Engineering', 'Automotive Engineering', 'Transportation', 'Computer Science Applications']                                                                  1
# ['Ecology', 'Aquatic Science']                                                                                                                                                     1
# Name: count, Length: 3101, dtype: int64
#
#
# Value counts for column: authors
# authors
# ['Ukritchon B.', 'Keawsawasvong S.']                                                                                           17
# ['Puriwat W.', 'Tripopsakul S.']                                                                                               15
# ['Hongladarom S.']                                                                                                             12
# ['Dechawatanapaisal D.']                                                                                                       12
# ['Aree T.']                                                                                                                    11
#                                                                                                                                ..
# ['Nantaphol S.', 'Moonla C.', 'Promvichai S.', 'Tangkuaram T.', 'Chailapakul O.', 'Siangproh W.']                               1
# ['Ponjan N.', 'Kielar F.', 'Dungkaew W.', 'Kongpatpanich K.', 'Zenno H.', 'Hayami S.', 'Sukwattanasinitt M.', 'Chainok K.']     1
# ['Phansuea P.', 'Tangwongchai S.', 'Rattananupong T.', 'Lohsoonthorn V.', 'Lertmaharit S.']                                     1
# ['Hallinger P.', 'Kulophas D.']                                                                                                 1
# ['Chea V.']                                                                                                                     1
# Name: count, Length: 18679, dtype: int64
#
#
# Value counts for column: reference
# reference
# []                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           411
# ['Medicine (Baltimore)', 'Endocrinol Metab Clin North Am']                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     2
# ['Pain Physician', 'Reg Anesth Pain Med', 'Anaesthesia', 'Acta Anaesthesiol Scand', 'J Clin Anesth', 'Reg Anesth Pain Med', 'J Anesth']                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        2
# ['AISC Shapes Database', 'A Specification for Structural Steel Buildings (ANSI/AISC 360-16)', 'Steel Compos. Struct', 'J. Construct. Steel Res', 'Standard Test Methods for Tension Testing of Metallic Materials (ASTM E8 / E8M-13a)', 'Standard Test Method for Compressive Strength of Cylindrical Concrete Specimens (ASTM C39 / C39M-16)', 'Eng. Struct', 'Steel Compos. Struct', 'Steel Compos. Struct', 'J. Construct. Steel Res', 'J. Construct. Steel Res', 'J. Struct. Eng', 'J. Struct. Eng', 'J. Struct. Eng', 'Adv. Struct. Eng', 'J. Construct. Steel Res', 'Institution Civil Eng. Proceedings Pt', 'Giornale del Genio Civile', 'J. Struct. Eng', 'Proceedings of the Institution Civil Eng. Struct. Build', 'Eng. Struct', 'J. Struct. Eng', 'J. Construct. Steel Res', 'Construct. Building Mater', 'J. Struct. Eng', 'J. Struct. Eng', 'J. Struct. Eng', 'J. Struct. Eng', 'J. Struct. Eng', 'J. Struct. Eng', 'Reinforced concrete structures', 'Steel Compos. Struct', 'Steel Compos. Struct', 'Behaviour of partially encased composite columns made with high performance concrete', 'J. Struct. Eng', 'J. Struct. Division', 'Thin-Wall. Struct', 'Eng. J., Fourth Quarter', 'Hot Rolled Structural Steel Industrial Standard', 'Compos. Construct. Steel Concrete', '1998 SSRC Annual Technical Meeting', 'Steel Compos. Struct', 'Int. J. Steel Struct', 'J. Construct. Steel Res', 'Steel Compos. Struct', 'Mater. Res. Innov', 'J. Build. Struct', 'Eng. Struct', 'Struct. Build']                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 2
# ['Eur. Heart J.', 'J. Hypertens', 'Science', 'IEEE Transactions on Biomedical Engineering', 'IEEE Trans. Biomed. Eng.', 'IEEE Access', 'ACM Trans. Graph.', 'Proc. IS&T CIC23: Twenty-Third Color and Imaging Conf.', 'J. Artif. Life Robot.', 'IEEE Trans. Biomed. Eng.', 'IEEE Conf. Robotics Biomimetics', 'Expert Syst. Appl.', 'Proc. IS&T CIC25: Twenty-Fifth Color and Imaging Conf.', 'J. Artif. Life Robot.', 'Biomed. Opt. Express']                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 2
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             ...
# ['JAMA', 'Int J Infect Dis', 'N Engl J Med', 'Lancet Infect Dis', 'Acta Paediatr', 'Lancet Child Adolesc Health', 'J Clin Virol', 'Eur Respir J', 'PLoS medicine', 'N Engl J Med', 'JAMA pediatrics', 'Pediatrics', 'Nature', 'Science', 'Cell', 'The Journal of clinical investigation', 'Proceedings of the Royal Society B: Biological Sciences', 'JAMA', 'J Pediatr', 'The Lancet', 'The Lancet', 'BMJ', 'Circulation', 'Pediatric Rheumatology', 'Progress in Pediatric Cardiology', 'Immunity', 'Cell', 'JAMA', 'bioRxiv', 'British Journal of Pharmacology', 'International Journal of Molecular Sciences', 'Nature Reviews Immunology', 'Nature Reviews Immunology', 'Trends in immunology', 'Experimental gerontology', 'Frontiers in Immunology', 'Nature medicine', 'The Medical Journal of Australia', 'Cellular & molecular immunology', 'Frontiers in immunology', 'Nature Reviews Immunology', 'The Journal of Immunology', 'Aging cell', 'Clinical Immunology: Principles and Practice', 'Emerging infectious diseases', 'Diabetes', 'Front Immunol', 'Cellular & molecular immunology', 'Clinical Immunology', 'Clinical Immunology']                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         1
# ['18th USENIX Security Symposium (USENIX Security ’09)', 'IEEE Transactions on Dependable and Secure Computing', 'Efficient dynamic taint analysis using multicore machines', '2009 IEEE International Conference on Electro/Information Technology', 'Buffer-overflow Protection using Boundary Bit', 'Proceedings of the 12th conference on USENIX Security Sym-posium', 'Proceedings of the 7th conference on USENIX Security Symposium', 'Proceedings of the Twentieth International Conference on Architectural Support for Programming Languages and Operating Systems, ASPLOS ’15', 'Proceedings of the 28th International Conference on Software Engineering, ICSE ’06', 'Microsoft windows up to 8.1 memory object win32k.sys buffer over-flow', 'Instruction tables', 'SIGARCH Comput. Archit. News', 'The undefined quest for full memory safety', 'Proceedings of the Network and Distributed System Security Sympo-sium', 'Distributed Enterprise Applications. HP Labs Tech Report', 'USENIX Association, ed-itor, Summer USENIX Conference Proceedings', 'CCS’13: Proceedings of the 2013 ACM SIGSAC conference on Computer & communications security', 'Software: Practice and Ex-perience', 'Software: Practice and Experience', '2012 9th International Conference on Ubiquitous Intelligence and Computing and 9th International Conference on Autonomic and Trusted Comput-ing', '2016 13th IEEE Annual Consumer Communications Networking Conference (CCNC)', 'Microsoft windows up to server 2016 smb buffer overflow', 'Proceedings of the 30th ACM SIGPLAN Conference on Programming Language Design and Imple-mentation, PLDI ’09', 'Proceedings of the 2010 International Symposium on Memory Management, ISMM ’10', 'A programmer’s view of the Intel 432 system', 'Software—Practice & Experience', 'IEEE Transactions on Dependable and Secure Computing', 'SECURE BIT: BUFFEROVER-FLOW PROTECTION', '2008 IFIP International Conference on Network and Parallel Com-puting', 'Proceedings of the Third Conference on IASTED International Conference: Advances in Computer Science and Technology, ACST’07', 'Engineering Journal', 'Proceedings of the 11th Annual Network and Distributed System Security Symposium', 'Canary bit: Extending secure bit for data pointer protection from buffer overflow attacks', '2018 Asian Hardware Oriented Security and Trust Symposium (AsianHOST)', 'The what, why, and how of the 1988 internet worm', '19th Annual Computer Security Applications Conference, 2003. Proceedings', 'Proceedings 21st International Conference on Distributed Computing Systems', 'Software: Practice and Experience', 'NETWORK AND DISTRIBUTED SYSTEM SECURITY SYMPOSIUM', 'Proceedings of the 1976 Annual Conference, ACM ’76']      1
# ['React. Chem. Eng.', 'React. Chem. Eng.', 'Environ. Sci.: Nano', 'Chem. Eng. J.', 'Polym. React. Eng.', 'J. Phys. Chem. B', 'J. Non-Cryst. Solids', 'J. Catal.', 'Langmuir', 'ChemNanoMat', 'Microporous Mesoporous Mater.', 'J. Phys. Chem. B', 'J. Mol. Catal. A: Chem.', 'J. Nat. Gas Chem.', 'Appl. Catal., B', 'Appl. Surf. Sci.', 'J. Catal.', 'J. Catal.', 'ChemCatChem', 'ACS Catal.', 'React. Chem. Eng.', 'Chem. Eng. J.', 'Int. J. Hydrogen Energy', 'Int. J. Hydrogen Energy', 'J. Catal.', 'React. Chem. Eng.', 'React. Chem. Eng.', 'React. Chem. Eng.', 'Top. Catal.', 'Microporous Mesoporous Mater.', 'Mater. Lett.', 'ChemNanoMat', 'Appl. Phys. A: Mater. Sci. Process.', 'J. Nanosci. Nanotechnol.', 'J. Mol. Catal. A: Chem.', 'Appl. Catal., A', 'J. Catal.', 'Catal. Sci. Technol.', 'Appl. Catal., A', 'J. Phys. Chem. B', 'Int. J. Greenhouse Gas Control', 'Chem. Mater.', 'ACS Catal.', 'Inorg. Chem. Commun.', 'J. Catal.', 'J. Catal.', 'J. Catal.', 'Zeolites', 'J. Mol. Catal. A: Chem.', 'Catal. Rev.: Sci. Eng.', 'Sci. China, Ser. B: Chem.', 'Russ. Chem. Rev.', 'Theor. Exp. Chem.', 'J. Catal.', 'Appl. Catal., A', 'J. Am. Chem. Soc.', 'ChemPhysChem', 'Chin. J. Catal.', 'Appl. Catal., A']                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           1
# ['Respir Med', 'J Med Res', 'Chest', 'Am J Respir Crit Care Med', 'The Smoking and Drinking Behaviour Survey', 'Tob Control', 'Circulation', 'Can Med Assoc J', 'Ministry of Social Develoment and Human Security', 'AD BI. Working Paper Series', 'Einstein', 'Int J Gen Med', 'BMJ', 'Eur Respir J', 'Prev Med', 'Am J Clin Nutr', 'BMJ', 'Am J Clin Nutr', 'Waist Circumference and WaistHip Ratio: Report of a WHO Expert Consultation', 'Postgrad Med J', 'J Med Assoc Thai', 'Am J Respir Crit Care Med', 'Eur Respir J', 'J Med Assoc Thai', 'Guidelines for Pulmonary Function Tests', 'J Phys Ther Sci', 'Eur Respir J', 'Biomed Pharmacol J', 'Respir Med', 'Am J Respir Crit Care Med', 'Am J Respir Crit Care Med', 'South. Med J', 'Chest', 'BMC Med', 'Obes Surg']                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               1
# ['World Development', 'International Migration, Economic Development and Policy', 'Economic Development and Cultural Change', 'International Migration, Remittances, and the Brain Drain', 'Journal of Development Studies', 'Economic Development and Cultural Change', 'World Development', 'World Development', 'Cambodia: Addressing the Skills Gap', 'Journal of Development Economics', 'The American Economic Review', 'Journal of International Development', 'Handbook of the Economics of International Migration', 'Development and Change', 'Population Research and Policy Review', 'Microeconometrics: Methods and Applications', 'The Age of Migration: International Population Movements in the Modern World', 'Impact of Migration and Remittances on Children’s Human Capital in Cambodia', 'Journal of Population and Social Studies', 'Journal of African Economies', 'Internal Migration in the Countries of Asia: A Cross-National Comparison', 'Emigration and Educational Attainment in Mexico', 'Risks and Rewards: Outcomes of Labor Migration in South-East Asia', 'Econometrica', 'Migrant Workers’ Remittances: Cambodia, Lao PDR, and Myanmar', 'Economic Record', 'Review of Economics and Statistics', 'Review of Income and Wealth', 'Review of Development Economics', 'Journal of Political Economy', 'Population and Development Review', 'Journal of Development Economics', 'Journal of Population Economics', 'Policy on Labor Migration in Cambodia', 'Cambodia Rural Urban Migration Project 2011', 'Poverty in Cambodia - A New Approach', 'General Population Census of Cambodia 1998: Final Census Results', 'General Population Census of Cambodia 2008: National Report on Final Census Results', 'Cambodia Inter-Censal Population Survey 2013: Final Report', 'Economic Development and Cultural Change', 'The Journal of Development Studies', 'The American Economic Review', 'Economic Development and Cultural Change', 'Demography', 'The Economic Journal', 'The Economic Journal', 'Journal of Development Economics', 'Journal of Policy Modeling', 'The American Economic Review', 'Cross-Border Labour Migration in Cambodia: Considerations for the National Employment Policy', 'International Migration Report', 'Demographic Research', 'World Development Indicator', 'Where Have All the Poor Gone? Cambodia Poverty Assessment 2013', 'Cambodia Economic Update: Recent Economic Developments and Outlook', 'International Migration, Remittances, and the Brain Drain', 'Asian Population Studies']                                                                                                                                                                                                                         1
# Name: count, Length: 19787, dtype: int64
#
#
# Value counts for column: title
# title
# Preface                                                                                                                18
# Message from General Chair                                                                                              6
# Introduction                                                                                                            4
# Foreword                                                                                                                4
# What is your diagnosis?                                                                                                 3
#                                                                                                                        ..
# Exact stiffness method for multi-layered saturated soils under moving dynamic loads                                     1
# Dissecting the tectal output channels for orienting and defense responses                                               1
# Treatment Outcomes Using the PAUL Glaucoma Implant to Control Intraocular Pressure in Eyes with Refractory Glaucoma     1
# Thermal adaptation in the honeybee (Apis mellifera) via changes to the structure of malate dehydrogenase                1
# Effects of remittances on household poverty and inequality in Cambodia                                                  1
# Name: count, Length: 20128, dtype: int64
#
#
# Value counts for column: publish_name
# publish_name
# Scientific Reports                                                438
# PLoS ONE                                                          254
# Journal of High Energy Physics                                    235
# Journal of the Medical Association of Thailand                    201
# Engineering Journal                                               182
#                                                                  ...
# Biochar Applications in Agriculture and Environment Management      1
# Journal of Industrial and Production Engineering                    1
# Hypertension in Pregnancy                                           1
# Journal of Intergenerational Relationships                          1
# Journal of Applied Aquaculture                                      1
# Name: count, Length: 5494, dtype: int64

# %%
df['title'].values
# Out:
# array(['Public health and international epidemiology for radiology',
#        'Flexible Printed Active Antenna for Digital Television Reception',
#        'Parametric study of hydrogen production via sorption enhanced steam methane reforming in a circulating fluidized bed riser',
#        ...,
#        'Social justice, education and peacebuilding: conflict transformation in Southern Thailand',
#        'Effects of black soldier fly (Hermetia illucens) larvae as a fish meal replacement on growth performance, feed utilisation, morphological characters and carcass composition of Thai climbing perch (Anabas testudineus)',
#        'Effects of remittances on household poverty and inequality in Cambodia'],
#       dtype=object)

# %%
df_temp = df
columns_df_temp = df_temp.columns

# %%
# Configure logging
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)

# %%
def convert_to_comma_separated(x):
    """
    Convert a list or a string representation of a list into a comma-separated string.
    
    Args:
        x: The cell value to process.
        
    Returns:
        A comma-separated string if input is a list or a parsable string of a list.
        Returns the original value otherwise.
    """
    if isinstance(x, list):
        # If it's already a list, join with commas
        return ', '.join(str(item) for item in x)
    elif isinstance(x, str) and x.startswith('['):
        try:
            # First, try parsing with json.loads()
            parsed = json.loads(x)
            if isinstance(parsed, list):
                return ', '.join(str(item) for item in parsed)
        except json.JSONDecodeError:
            try:
                # Fallback to ast.literal_eval() for Python-like list strings
                parsed = ast.literal_eval(x)
                if isinstance(parsed, list):
                    return ', '.join(str(item) for item in parsed)
            except (ValueError, SyntaxError):
                # If parsing fails, log the error and return the original string
                logger.warning(f"Failed to parse list for value: {x}")
    # Return the original value if it's neither a list nor a parsable string
    return x

# %%
def clean_dataframe_columns(df_temp: pd.DataFrame) -> pd.DataFrame:
    """
    Convert list-like columns or string representations of lists into comma-separated strings.
    
    Args:
        df_temp: The DataFrame to process.
        
    Returns:
        The cleaned DataFrame with specified columns transformed.
    """
    for col in df_temp.columns:
        # Check if any cell in the column is a list or a string that starts with '['
        if df_temp[col].apply(lambda x: isinstance(x, list) or (isinstance(x, str) and x.strip().startswith('['))).any():
            logger.info(f"Cleaning column: {col}")
            df_temp[col] = df_temp[col].apply(convert_to_comma_separated)
    return df_temp

# %%
df_temp = clean_dataframe_columns(df_temp)
# Out:
# INFO:__main__:Cleaning column: organizations
# INFO:__main__:Cleaning column: classifications
# INFO:__main__:Cleaning column: affiliations
# INFO:__main__:Cleaning column: auth-keywords
# INFO:__main__:Cleaning column: subjects
# INFO:__main__:Cleaning column: authors
# INFO:__main__:Cleaning column: reference

# %%
df_temp.head(5)
# Out:
#              file                                      organizations  \
# 0  201800000.json  Department of Preventive and Social Medicine, ...
# 1  201800001.json  Department of Electrical Engineering, Wireless...
# 2  201800002.json  Center of Excellence in Catalysis and Catalyti...
# 3  201800003.json  Department of Chemistry, Faculty of Science an...
# 4  201800004.json  Program in Petrochemistry, Faculty of Science,...
#
#                                      classifications  \
# 0                                     ASJC, SUBJABBR
# 1                 ASJC, CPXCLASS, FLXCLASS, SUBJABBR
# 2  CPXCLASS, ENCOMPASSCLASS, FLXCLASS, ASJC, SUBJ...
# 3                 CPXCLASS, FLXCLASS, ASJC, SUBJABBR
# 4                            EMCLASS, ASJC, SUBJABBR
#
#                                         affiliations  \
# 0  Stanford University School of Medicine, Chulal...
# 1                           Chulalongkorn University
# 2                           Chulalongkorn University
# 3  Hirosaki University, Chulalongkorn University,...
# 4  Chulalongkorn University, Thailand National El...
#
#                                        auth-keywords  \
# 0                                               None
# 1                                               None
# 2  Circulating fluidized bed, Computational fluid...
# 3  Encapsulation, Fluoroalkylsilane, Natural rubb...
# 4  acpcPNA, Electrochemical impedance spectroscop...
#
#                                             subjects  \
# 0                                     Medicine (all)
# 1  Electrical and Electronic Engineering, Electro...
# 2  Chemistry (all), Chemical Engineering (all), I...
# 3  Chemistry (all), Condensed Matter Physics, Phy...
# 4  Analytical Chemistry, Biochemistry, Environmen...
#
#                                              authors  \
# 0                         Pongpirul K., Lungren M.P.
# 1                        Pratumsiri T., Janpugdee P.
# 2  Phuakpunk K., Chalermsinsuwan B., Putivisutisa...
# 3  Saengkaew J., Le D., Samart C., Sawada H., Nis...
# 4  Teengam P., Siangproh W., Tuantranont A., Vila...
#
#                                            reference  \
# 0  Science., The future of public health, Interna...
# 1  Proc. CAMA 2015, Proc. 2015 Thailand-Japan Mic...
# 2  AICHE J., Int. J. Hydrog. Energy, Chem. Eng. J...
# 3  Desalination, J. Membr. Sci., Appl. Catal. B.,...
# 4  Int. J. Tubercul. Lung Dis., Lancet Infect. Di...
#
#                                                title  \
# 0  Public health and international epidemiology f...
# 1  Flexible Printed Active Antenna for Digital Te...
# 2  Parametric study of hydrogen production via so...
# 3  Superhydrophobic coating from fluoroalkylsilan...
# 4  Electrochemical impedance-based DNA sensor usi...
#
#                                         publish_name
# 0  Radiology in Global Health: Strategies, Implem...
# 1    Progress in Electromagnetics Research Symposium
# 2                       Chemical Engineering Science
# 3                            Applied Surface Science
# 4                             Analytica Chimica Acta

# %%
df_temp.to_csv('data/features_summation_not_list.csv', index=False, encoding='utf-8')
