# %%
# %pip install pyspark
# %pip install logger
# Out:
# Requirement already satisfied: pyspark in c:\users\yiwahpsp\anaconda3\lib\site-packages (3.5.3)
# Requirement already satisfied: py4j==0.10.9.7 in c:\users\yiwahpsp\anaconda3\lib\site-packages (from pyspark) (0.10.9.7)
# Note: you may need to restart the kernel to use updated packages.
# Collecting logger
#   Downloading logger-1.4.tar.gz (1.2 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Building wheels for collected packages: logger
#   Building wheel for logger (setup.py): started
#   Building wheel for logger (setup.py): finished with status 'done'
#   Created wheel for logger: filename=logger-1.4-py3-none-any.whl size=1761 sha256=5b19809eddbf7d5e2a4fd4d0716ef470a0888b8cd2a6cef50866bced9bc721c9
#   Stored in directory: c:\users\yiwahpsp\appdata\local\pip\cache\wheels\cc\ef\15\aadfb106e1cc7ac1d668efc189bcd98c444211847f7d91bd02
# Successfully built logger
# Installing collected packages: logger
# Successfully installed logger-1.4
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import json
import glob
import os
from pathlib import Path
from pyspark.sql import SparkSession
from pyspark.sql.functions import explode

# %%
raw_data_root_path = 'raw-data'

# %% [markdown]
# ## Change files in raw data to .json file

# %%
for root, dirs, files in os.walk(raw_data_root_path):
        for file in files:
            file_path = os.path.join(root, file)
            
            if '.' not in file:
                new_path = file_path + '.json'
                os.rename(file_path, new_path)
                file_path = new_path
                print(f"Renamed {file_path} to {new_path}")

# %% [markdown]
# ## Make Flatten file

# %%
def flatten_json(y):
    out = {}

    def flatten(x, name=''):
        if type(x) is dict:
            for a in x:
                flatten(x[a], name + a + '.')
        elif type(x) is list:
            i = 0
            for a in x:
                flatten(a, name + str(i) + '.')
                i += 1
        else:
            out[name[:-1]] = x

    flatten(y)
    return out

# Example usage

spark = SparkSession.builder.appName("jsonFlatten").getOrCreate()
with open('raw-data\\2023\\202300002.json', 'r', encoding='utf-8') as f:
    json_data = json.load(f)

flattened = flatten_json(json_data)
for key, value in flattened.items():
    print(f"{key}: {value}")
# Out:
# abstracts-retrieval-response.item.ait:process-info.ait:status.@state: update
# abstracts-retrieval-response.item.ait:process-info.ait:status.@type: core
# abstracts-retrieval-response.item.ait:process-info.ait:status.@stage: S300
# abstracts-retrieval-response.item.ait:process-info.ait:date-delivered.@day: 07
# abstracts-retrieval-response.item.ait:process-info.ait:date-delivered.@timestamp: 2023-08-07T17:46:05.000005-04:00
# abstracts-retrieval-response.item.ait:process-info.ait:date-delivered.@year: 2023
# abstracts-retrieval-response.item.ait:process-info.ait:date-delivered.@month: 08
# abstracts-retrieval-response.item.ait:process-info.ait:date-sort.@day: 15
# abstracts-retrieval-response.item.ait:process-info.ait:date-sort.@year: 2023
# abstracts-retrieval-response.item.ait:process-info.ait:date-sort.@month: 12
# abstracts-retrieval-response.item.xocs:meta.xocs:funding-list.@pui-match: primary
# abstracts-retrieval-response.item.xocs:meta.xocs:funding-list.@has-funding-info: 1
# abstracts-retrieval-response.item.xocs:meta.xocs:funding-list.xocs:funding.0.xocs:funding-agency-matched-string: Center of Excellence for Marine Biotechnology
# abstracts-retrieval-response.item.xocs:meta.xocs:funding-list.xocs:funding.1.xocs:funding-agency-matched-string: Center of Excellence for Shrimp Molecular Biology and Biotechnology
# abstracts-retrieval-response.item.xocs:meta.xocs:funding-list.xocs:funding.2.xocs:funding-agency-matched-string: Chacheongsao Province
# abstracts-retrieval-response.item.xocs:meta.xocs:funding-list.xocs:funding.3.xocs:funding-agency-matched-string: NSRF
# abstracts-retrieval-response.item.xocs:meta.xocs:funding-list.xocs:funding.3.xocs:funding-id: B05F640137
# abstracts-retrieval-response.item.xocs:meta.xocs:funding-list.xocs:funding.4.xocs:funding-agency-matched-string: Second Century Fund
# abstracts-retrieval-response.item.xocs:meta.xocs:funding-list.xocs:funding.5.xocs:funding-agency-matched-string: Thailand Science Research and Innovation Fund Chulalongkorn University
# abstracts-retrieval-response.item.xocs:meta.xocs:funding-list.xocs:funding.5.xocs:funding-id: _165_21_31
# abstracts-retrieval-response.item.xocs:meta.xocs:funding-list.xocs:funding.6.xocs:funding-agency-matched-string: RDI
# abstracts-retrieval-response.item.xocs:meta.xocs:funding-list.xocs:funding.6.xocs:funding-agency-acronym: RDI
# abstracts-retrieval-response.item.xocs:meta.xocs:funding-list.xocs:funding.6.xocs:funding-agency: Race and Difference Initiative, Emory University
# abstracts-retrieval-response.item.xocs:meta.xocs:funding-list.xocs:funding.6.xocs:funding-id: P19-51879
# abstracts-retrieval-response.item.xocs:meta.xocs:funding-list.xocs:funding
# abstracts-retrieval-response.item.bibrecord.head.author-group.0.affiliation.address-part: Pathum Thani
# abstracts-retrieval-response.item.bibrecord.head.author-group.0.affiliation.@afid: 60011947
# abstracts-retrieval-response.item.bibrecord.head.author-group.0.affiliation.@country: tha
# abstracts-retrieval-response.item.bibrecord.head.author-group.0.affiliation.organization.0.$: National Center for Genetic Engineering and Biotechnology (BIOTEC)
# abstracts-retrieval-response.item.bibrecord.head.author-group.0.affiliation.organization.1.$: National Science and Technology Development Agency (NSTDA)
# abstracts-retrieval-response.item.bibrecord.head.author-group.0.affiliation.affiliation-id.0.@afid: 60011947
# abstracts-retrieval-response.item.bibrecord.head.author-group.0.affiliation.affiliation-id.1.@afid: 60004391
# abstracts-retrieval-response.item.bibrecord.head.author-group.0.affiliation.@affiliation-instance-id: OB2BibRecID-949746532-513ef3107326946ce4307296dc5fdd64-1
# abstracts-retrieval-response.item.bibrecord.head.author-group.0.affiliation.ce:source-text: National Center for Genetic Engineering and Biotechnology (BIOTEC), National Science and Technology Development Agency (NSTDA), Pathum Thani, Thailand.
# abstracts-retrieval-response.item.bibrecord.head.author-group.0.author.0.ce:given-name: Penpicha
# abstracts-retrieval-response.item.bibrecord.head.author-group.0.author.0.preferred-name.ce:given-name: Penpicha
# abstracts-retrieval-response.item.bibrecord.head.author-group.0.author.0.preferred-name.ce:initials: P.
# abstracts-retrieval-response.item.bibrecord.head.author-group.0.author.0.preferred-name.ce:surname: Satanwat
# abstracts-retrieval-response.item.bibrecord.head.author-group.0.author.0.preferred-name.ce:indexed-name: Satanwat P.
# abstracts-retrieval-response.item.bibrecord.head.author-group.0.author.0.@author-instance-id: OB2BibRecID-949746532-f7e25f660f112319f945e0b962c8bbec-1
# abstracts-retrieval-response.item.bibrecord.head.author-group.0.author.0.@seq: 1
# abstracts-retrieval-response.item.bibrecord.head.author-group.0.author.0.ce:initials: P.
# abstracts-retrieval-response.item.bibrecord.head.author-group.0.author.0.@_fa: true
# abstracts-retrieval-response.item.bibrecord.head.author-group.0.author.0.@type: auth
# abstracts-retrieval-response.item.bibrecord.head.author-group.0.author.0.ce:surname: Satanwat
# abstracts-retrieval-response.item.bibrecord.head.author-group.0.author.0.@auid: 57208553550
# abstracts-retrieval-response.item.bibrecord.head.author-group.0.author.0.ce:indexed-name: Satanwat P.
# abstracts-retrieval-response.item.bibrecord.head.author-group.0.author.1.ce:given-name: Paveena
# abstracts-retrieval-response.item.bibrecord.head.author-group.0.author.1.preferred-name.ce:given-name: Paveena
# abstracts-retrieval-response.item.bibrecord.head.author-group.0.author.1.preferred-name.ce:initials: P.
# abstracts-retrieval-response.item.bibrecord.head.author-group.0.author.1.preferred-name.ce:surname: Tapaneeyaworawong
# abstracts-retrieval-response.item.bibrecord.head.author-group.0.author.1.preferred-name.ce:indexed-name: Tapaneeyaworawong P.
# abstracts-retrieval-response.item.bibrecord.head.author-group.0.author.1.@author-instance-id: OB2BibRecID-949746532-cd074cbfca92504eb7cf1dfe5b4d9a67-1
# abstracts-retrieval-response.item.bibrecord.head.author-group.0.author.1.@seq: 2
# abstracts-retrieval-response.item.bibrecord.head.author-group.0.author.1.ce:initials: P.
# abstracts-retrieval-response.item.bibrecord.head.author-group.0.author.1.@_fa: true
# abstracts-retrieval-response.item.bibrecord.head.author-group.0.author.1.@type: auth
# abstracts-retrieval-response.item.bibrecord.head.author-group.0.author.1.ce:surname: Tapaneeyaworawong
# abstracts-retrieval-response.item.bibrecord.head.author-group.0.author.1.@auid: 56374287000
# abstracts-retrieval-response.item.bibrecord.head.author-group.0.author.1.ce:indexed-name: Tapaneeyaworawong P.
# abstracts-retrieval-response.item.bibrecord.head.author-group.0.author.2.ce:given-name: Piyanuch
# abstracts-retrieval-response.item.bibrecord.head.author-group.0.author.2.preferred-name.ce:given-name: Piyanuch
# abstracts-retrieval-response.item.bibrecord.head.author-group.0.author.2.preferred-name.ce:initials: P.
# abstracts-retrieval-response.item.bibrecord.head.author-group.0.author.2.preferred-name.ce:surname: Wechprasit
# abstracts-retrieval-response.item.bibrecord.head.author-group.0.author.2.preferred-name.ce:indexed-name: Wechprasit P.
# abstracts-retrieval-response.item.bibrecord.head.author-group.0.author.2.@author-instance-id: OB2BibRecID-949746532-d6fff5aa5f4c521863d69dfca51ad98e-1
# abstracts-retrieval-response.item.bibrecord.head.author-group.0.author.2.@seq: 3
# abstracts-retrieval-response.item.bibrecord.head.author-group.0.author.2.ce:initials: P.
# abstracts-retrieval-response.item.bibrecord.head.author-group.0.author.2.@_fa: true
# abstracts-retrieval-response.item.bibrecord.head.author-group.0.author.2.@type: auth
# abstracts-retrieval-response.item.bibrecord.head.author-group.0.author.2.ce:surname: Wechprasit
# abstracts-retrieval-response.item.bibrecord.head.author-group.0.author.2.@auid: 57208407732
# abstracts-retrieval-response.item.bibrecord.head.author-group.0.author.2.ce:indexed-name: Wechprasit P.
# abstracts-retrieval-response.item.bibrecord.head.author-group.0.author.3.ce:given-name: Tharin
# abstracts-retrieval-response.item.bibrecord.head.author-group.0.author.3.preferred-name.ce:given-name: Tharin
# abstracts-retrieval-response.item.bibrecord.head.author-group.0.author.3.preferred-name.ce:initials: T.
# abstracts-retrieval-response.item.bibrecord.head.author-group.0.author.3.preferred-name.ce:surname: Boonprasertsakul
# abstracts-retrieval-response.item.bibrecord.head.author-group.0.author.3.preferred-name.ce:indexed-name: Boonprasertsakul T.
# abstracts-retrieval-response.item.bibrecord.head.author-group.0.author.3.@author-instance-id: OB2BibRecID-949746532-859000d6a09532f5a262f4270e571b77-1
# abstracts-retrieval-response.item.bibrecord.head.author-group.0.author.3.@seq: 4
# abstracts-retrieval-response.item.bibrecord.head.author-group.0.author.3.ce:initials: T.
# abstracts-retrieval-response.item.bibrecord.head.author-group.0.author.3.@_fa: true
# abstracts-retrieval-response.item.bibrecord.head.author-group.0.author.3.@type: auth
# abstracts-retrieval-response.item.bibrecord.head.author-group.0.author.3.ce:surname: Boonprasertsakul
# abstracts-retrieval-response.item.bibrecord.head.author-group.0.author.3.@auid: 58307243400
# abstracts-retrieval-response.item.bibrecord.head.author-group.0.author.3.ce:indexed-name: Boonprasertsakul T.
# abstracts-retrieval-response.item.bibrecord.head.author-group.0.author.4.ce:given-name: Kallaya
# abstracts-retrieval-response.item.bibrecord.head.author-group.0.author.4.preferred-name.ce:given-name: Kallaya
# abstracts-retrieval-response.item.bibrecord.head.author-group.0.author.4.preferred-name.ce:initials: K.
# abstracts-retrieval-response.item.bibrecord.head.author-group.0.author.4.preferred-name.ce:surname: Sritunyalucksana
# abstracts-retrieval-response.item.bibrecord.head.author-group.0.author.4.preferred-name.ce:indexed-name: Sritunyalucksana K.
# abstracts-retrieval-response.item.bibrecord.head.author-group.0.author.4.@author-instance-id: OB2BibRecID-949746532-d4a6ef9c18db685803e66c8c2e64f820-1
# abstracts-retrieval-response.item.bibrecord.head.author-group.0.author.4.@seq: 6
# abstracts-retrieval-response.item.bibrecord.head.author-group.0.author.4.ce:initials: K.
# abstracts-retrieval-response.item.bibrecord.head.author-group.0.author.4.@_fa: true
# abstracts-retrieval-response.item.bibrecord.head.author-group.0.author.4.@type: auth
# abstracts-retrieval-response.item.bibrecord.head.author-group.0.author.4.ce:surname: Sritunyalucksana
# abstracts-retrieval-response.item.bibrecord.head.author-group.0.author.4.@auid: 6507431846
# abstracts-retrieval-response.item.bibrecord.head.author-group.0.author.4.ce:indexed-name: Sritunyalucksana K.
# abstracts-retrieval-response.item.bibrecord.head.author-group.0.author.5.ce:given-name: Anuphap
# abstracts-retrieval-response.item.bibrecord.head.author-group.0.author.5.preferred-name.ce:given-name: Anuphap
# abstracts-retrieval-response.item.bibrecord.head.author-group.0.author.5.preferred-name.ce:initials: A.
# abstracts-retrieval-response.item.bibrecord.head.author-group.0.author.5.preferred-name.ce:surname: Prachumwat
# abstracts-retrieval-response.item.bibrecord.head.author-group.0.author.5.preferred-name.ce:indexed-name: Prachumwat A.
# abstracts-retrieval-response.item.bibrecord.head.author-group.0.author.5.@author-instance-id: OB2BibRecID-949746532-fb51904c402e83aad1e63ad77954999b-1
# abstracts-retrieval-response.item.bibrecord.head.author-group.0.author.5.@seq: 7
# abstracts-retrieval-response.item.bibrecord.head.author-group.0.author.5.ce:initials: A.
# abstracts-retrieval-response.item.bibrecord.head.author-group.0.author.5.@_fa: true
# abstracts-retrieval-response.item.bibrecord.head.author-group.0.author.5.@type: auth
# abstracts-retrieval-response.item.bibrecord.head.author-group.0.author.5.ce:surname: Prachumwat
# abstracts-retrieval-response.item.bibrecord.head.author-group.0.author.5.@auid: 9939200600
# abstracts-retrieval-response.item.bibrecord.head.author-group.0.author.5.ce:indexed-name: Prachumwat A.
# abstracts-retrieval-response.item.bibrecord.head.author-group.0.author.6.ce:given-name: Sorawit
# abstracts-retrieval-response.item.bibrecord.head.author-group.0.author.6.preferred-name.ce:given-name: Sorawit
# abstracts-retrieval-response.item.bibrecord.head.author-group.0.author.6.preferred-name.ce:initials: S.
# abstracts-retrieval-response.item.bibrecord.head.author-group.0.author.6.preferred-name.ce:surname: Powtongsook
# abstracts-retrieval-response.item.bibrecord.head.author-group.0.author.6.preferred-name.ce:indexed-name: Powtongsook S.
# abstracts-retrieval-response.item.bibrecord.head.author-group.0.author.6.@author-instance-id: OB2BibRecID-949746532-81e7e55089d1ae8cb7ae45e2e4229f6d-1
# abstracts-retrieval-response.item.bibrecord.head.author-group.0.author.6.@seq: 8
# abstracts-retrieval-response.item.bibrecord.head.author-group.0.author.6.ce:initials: S.
# abstracts-retrieval-response.item.bibrecord.head.author-group.0.author.6.@_fa: true
# abstracts-retrieval-response.item.bibrecord.head.author-group.0.author.6.@type: auth
# abstracts-retrieval-response.item.bibrecord.head.author-group.0.author.6.ce:surname: Powtongsook
# abstracts-retrieval-response.item.bibrecord.head.author-group.0.author.6.@auid: 6507593766
# abstracts-retrieval-response.item.bibrecord.head.author-group.0.author.6.ce:indexed-name: Powtongsook S.
# abstracts-retrieval-response.item.bibrecord.head.author-group.1.affiliation.country: Thailand
# abstracts-retrieval-response.item.bibrecord.head.author-group.1.affiliation.@afid: 60028190
# abstracts-retrieval-response.item.bibrecord.head.author-group.1.affiliation.@country: tha
# abstracts-retrieval-response.item.bibrecord.head.author-group.1.affiliation.city: Bangkok
# abstracts-retrieval-response.item.bibrecord.head.author-group.1.affiliation.organization.0.$: Center of Excellence for Marine Biotechnology
# abstracts-retrieval-response.item.bibrecord.head.author-group.1.affiliation.organization.1.$: Department of Marine Science
# abstracts-retrieval-response.item.bibrecord.head.author-group.1.affiliation.organization.2.$: Faculty of Science
# abstracts-retrieval-response.item.bibrecord.head.author-group.1.affiliation.organization.3.$: Chulalongkorn University
# abstracts-retrieval-response.item.bibrecord.head.author-group.1.affiliation.affiliation-id.@afid: 60028190
# abstracts-retrieval-response.item.bibrecord.head.author-group.1.affiliation.affiliation-id.@dptid: 104425679
# abstracts-retrieval-response.item.bibrecord.head.author-group.1.affiliation.@affiliation-instance-id: OB2BibRecID-949746532-8260f0a00f92608065e8e3e019f10892-1
# abstracts-retrieval-response.item.bibrecord.head.author-group.1.affiliation.ce:source-text: Center of Excellence for Marine Biotechnology, Department of Marine Science, Faculty of Science, Chulalongkorn University, Bangkok, Thailand.
# abstracts-retrieval-response.item.bibrecord.head.author-group.1.affiliation.@dptid: 104425679
# abstracts-retrieval-response.item.bibrecord.head.author-group.1.author.0.ce:given-name: Penpicha
# abstracts-retrieval-response.item.bibrecord.head.author-group.1.author.0.preferred-name.ce:given-name: Penpicha
# abstracts-retrieval-response.item.bibrecord.head.author-group.1.author.0.preferred-name.ce:initials: P.
# abstracts-retrieval-response.item.bibrecord.head.author-group.1.author.0.preferred-name.ce:surname: Satanwat
# abstracts-retrieval-response.item.bibrecord.head.author-group.1.author.0.preferred-name.ce:indexed-name: Satanwat P.
# abstracts-retrieval-response.item.bibrecord.head.author-group.1.author.0.@author-instance-id: OB2BibRecID-949746532-f7e25f660f112319f945e0b962c8bbec-1
# abstracts-retrieval-response.item.bibrecord.head.author-group.1.author.0.@seq: 1
# abstracts-retrieval-response.item.bibrecord.head.author-group.1.author.0.ce:initials: P.
# abstracts-retrieval-response.item.bibrecord.head.author-group.1.author.0.@_fa: true
# abstracts-retrieval-response.item.bibrecord.head.author-group.1.author.0.@type: auth
# abstracts-retrieval-response.item.bibrecord.head.author-group.1.author.0.ce:surname: Satanwat
# abstracts-retrieval-response.item.bibrecord.head.author-group.1.author.0.@auid: 57208553550
# abstracts-retrieval-response.item.bibrecord.head.author-group.1.author.0.ce:indexed-name: Satanwat P.
# abstracts-retrieval-response.item.bibrecord.head.author-group.1.author.1.ce:given-name: Paveena
# abstracts-retrieval-response.item.bibrecord.head.author-group.1.author.1.preferred-name.ce:given-name: Paveena
# abstracts-retrieval-response.item.bibrecord.head.author-group.1.author.1.preferred-name.ce:initials: P.
# abstracts-retrieval-response.item.bibrecord.head.author-group.1.author.1.preferred-name.ce:surname: Tapaneeyaworawong
# abstracts-retrieval-response.item.bibrecord.head.author-group.1.author.1.preferred-name.ce:indexed-name: Tapaneeyaworawong P.
# abstracts-retrieval-response.item.bibrecord.head.author-group.1.author.1.@author-instance-id: OB2BibRecID-949746532-cd074cbfca92504eb7cf1dfe5b4d9a67-1
# abstracts-retrieval-response.item.bibrecord.head.author-group.1.author.1.@seq: 2
# abstracts-retrieval-response.item.bibrecord.head.author-group.1.author.1.ce:initials: P.
# abstracts-retrieval-response.item.bibrecord.head.author-group.1.author.1.@_fa: true
# abstracts-retrieval-response.item.bibrecord.head.author-group.1.author.1.@type: auth
# abstracts-retrieval-response.item.bibrecord.head.author-group.1.author.1.ce:surname: Tapaneeyaworawong
# abstracts-retrieval-response.item.bibrecord.head.author-group.1.author.1.@auid: 56374287000
# abstracts-retrieval-response.item.bibrecord.head.author-group.1.author.1.ce:indexed-name: Tapaneeyaworawong P.
# abstracts-retrieval-response.item.bibrecord.head.author-group.1.author.2.ce:given-name: Tharin
# abstracts-retrieval-response.item.bibrecord.head.author-group.1.author.2.preferred-name.ce:given-name: Tharin
# abstracts-retrieval-response.item.bibrecord.head.author-group.1.author.2.preferred-name.ce:initials: T.
# abstracts-retrieval-response.item.bibrecord.head.author-group.1.author.2.preferred-name.ce:surname: Boonprasertsakul
# abstracts-retrieval-response.item.bibrecord.head.author-group.1.author.2.preferred-name.ce:indexed-name: Boonprasertsakul T.
# abstracts-retrieval-response.item.bibrecord.head.author-group.1.author.2.@author-instance-id: OB2BibRecID-949746532-859000d6a09532f5a262f4270e571b77-1
# abstracts-retrieval-response.item.bibrecord.head.author-group.1.author.2.@seq: 4
# abstracts-retrieval-response.item.bibrecord.head.author-group.1.author.2.ce:initials: T.
# abstracts-retrieval-response.item.bibrecord.head.author-group.1.author.2.@_fa: true
# abstracts-retrieval-response.item.bibrecord.head.author-group.1.author.2.@type: auth
# abstracts-retrieval-response.item.bibrecord.head.author-group.1.author.2.ce:surname: Boonprasertsakul
# abstracts-retrieval-response.item.bibrecord.head.author-group.1.author.2.@auid: 58307243400
# abstracts-retrieval-response.item.bibrecord.head.author-group.1.author.2.ce:indexed-name: Boonprasertsakul T.
# abstracts-retrieval-response.item.bibrecord.head.author-group.1.author.3.ce:given-name: Wiboonluk
# abstracts-retrieval-response.item.bibrecord.head.author-group.1.author.3.preferred-name.ce:given-name: Wiboonluk
# abstracts-retrieval-response.item.bibrecord.head.author-group.1.author.3.preferred-name.ce:initials: W.
# abstracts-retrieval-response.item.bibrecord.head.author-group.1.author.3.preferred-name.ce:surname: Pungrasmi
# abstracts-retrieval-response.item.bibrecord.head.author-group.1.author.3.preferred-name.ce:indexed-name: Pungrasmi W.
# abstracts-retrieval-response.item.bibrecord.head.author-group.1.author.3.@author-instance-id: OB2BibRecID-949746532-8e004e2db6197ef352e150a06042830c-1
# abstracts-retrieval-response.item.bibrecord.head.author-group.1.author.3.@seq: 5
# abstracts-retrieval-response.item.bibrecord.head.author-group.1.author.3.ce:initials: W.
# abstracts-retrieval-response.item.bibrecord.head.author-group.1.author.3.@_fa: true
# abstracts-retrieval-response.item.bibrecord.head.author-group.1.author.3.@type: auth
# abstracts-retrieval-response.item.bibrecord.head.author-group.1.author.3.ce:surname: Pungrasmi
# abstracts-retrieval-response.item.bibrecord.head.author-group.1.author.3.@auid: 23993014300
# abstracts-retrieval-response.item.bibrecord.head.author-group.1.author.3.ce:indexed-name: Pungrasmi W.
# abstracts-retrieval-response.item.bibrecord.head.author-group.1.author.4.ce:given-name: Sorawit
# abstracts-retrieval-response.item.bibrecord.head.author-group.1.author.4.preferred-name.ce:given-name: Sorawit
# abstracts-retrieval-response.item.bibrecord.head.author-group.1.author.4.preferred-name.ce:initials: S.
# abstracts-retrieval-response.item.bibrecord.head.author-group.1.author.4.preferred-name.ce:surname: Powtongsook
# abstracts-retrieval-response.item.bibrecord.head.author-group.1.author.4.preferred-name.ce:indexed-name: Powtongsook S.
# abstracts-retrieval-response.item.bibrecord.head.author-group.1.author.4.@author-instance-id: OB2BibRecID-949746532-81e7e55089d1ae8cb7ae45e2e4229f6d-1
# abstracts-retrieval-response.item.bibrecord.head.author-group.1.author.4.@seq: 8
# abstracts-retrieval-response.item.bibrecord.head.author-group.1.author.4.ce:initials: S.
# abstracts-retrieval-response.item.bibrecord.head.author-group.1.author.4.@_fa: true
# abstracts-retrieval-response.item.bibrecord.head.author-group.1.author.4.@type: auth
# abstracts-retrieval-response.item.bibrecord.head.author-group.1.author.4.ce:surname: Powtongsook
# abstracts-retrieval-response.item.bibrecord.head.author-group.1.author.4.@auid: 6507593766
# abstracts-retrieval-response.item.bibrecord.head.author-group.1.author.4.ce:indexed-name: Powtongsook S.
# abstracts-retrieval-response.item.bibrecord.head.author-group.2.affiliation.country: Thailand
# abstracts-retrieval-response.item.bibrecord.head.author-group.2.affiliation.@afid: 60028190
# abstracts-retrieval-response.item.bibrecord.head.author-group.2.affiliation.@country: tha
# abstracts-retrieval-response.item.bibrecord.head.author-group.2.affiliation.city: Bangkok
# abstracts-retrieval-response.item.bibrecord.head.author-group.2.affiliation.organization.0.$: Department of Environmental Engineering
# abstracts-retrieval-response.item.bibrecord.head.author-group.2.affiliation.organization.1.$: Faculty of Engineering
# abstracts-retrieval-response.item.bibrecord.head.author-group.2.affiliation.organization.2.$: Chulalongkorn University
# abstracts-retrieval-response.item.bibrecord.head.author-group.2.affiliation.affiliation-id.@afid: 60028190
# abstracts-retrieval-response.item.bibrecord.head.author-group.2.affiliation.affiliation-id.@dptid: 109090604
# abstracts-retrieval-response.item.bibrecord.head.author-group.2.affiliation.@affiliation-instance-id: OB2BibRecID-949746532-b4cba2955e3df7d603c453a28cee8bed-1
# abstracts-retrieval-response.item.bibrecord.head.author-group.2.affiliation.ce:source-text: Department of Environmental Engineering, Faculty of Engineering, Chulalongkorn University, Bangkok, Thailand.
# abstracts-retrieval-response.item.bibrecord.head.author-group.2.affiliation.@dptid: 109090604
# abstracts-retrieval-response.item.bibrecord.head.author-group.2.author.0.ce:given-name: Penpicha
# abstracts-retrieval-response.item.bibrecord.head.author-group.2.author.0.preferred-name.ce:given-name: Penpicha
# abstracts-retrieval-response.item.bibrecord.head.author-group.2.author.0.preferred-name.ce:initials: P.
# abstracts-retrieval-response.item.bibrecord.head.author-group.2.author.0.preferred-name.ce:surname: Satanwat
# abstracts-retrieval-response.item.bibrecord.head.author-group.2.author.0.preferred-name.ce:indexed-name: Satanwat P.
# abstracts-retrieval-response.item.bibrecord.head.author-group.2.author.0.@author-instance-id: OB2BibRecID-949746532-f7e25f660f112319f945e0b962c8bbec-1
# abstracts-retrieval-response.item.bibrecord.head.author-group.2.author.0.@seq: 1
# abstracts-retrieval-response.item.bibrecord.head.author-group.2.author.0.ce:initials: P.
# abstracts-retrieval-response.item.bibrecord.head.author-group.2.author.0.@_fa: true
# abstracts-retrieval-response.item.bibrecord.head.author-group.2.author.0.@type: auth
# abstracts-retrieval-response.item.bibrecord.head.author-group.2.author.0.ce:surname: Satanwat
# abstracts-retrieval-response.item.bibrecord.head.author-group.2.author.0.@auid: 57208553550
# abstracts-retrieval-response.item.bibrecord.head.author-group.2.author.0.ce:indexed-name: Satanwat P.
# abstracts-retrieval-response.item.bibrecord.head.author-group.2.author.1.ce:given-name: Wiboonluk
# abstracts-retrieval-response.item.bibrecord.head.author-group.2.author.1.preferred-name.ce:given-name: Wiboonluk
# abstracts-retrieval-response.item.bibrecord.head.author-group.2.author.1.preferred-name.ce:initials: W.
# abstracts-retrieval-response.item.bibrecord.head.author-group.2.author.1.preferred-name.ce:surname: Pungrasmi
# abstracts-retrieval-response.item.bibrecord.head.author-group.2.author.1.preferred-name.ce:indexed-name: Pungrasmi W.
# abstracts-retrieval-response.item.bibrecord.head.author-group.2.author.1.@author-instance-id: OB2BibRecID-949746532-8e004e2db6197ef352e150a06042830c-1
# abstracts-retrieval-response.item.bibrecord.head.author-group.2.author.1.@seq: 5
# abstracts-retrieval-response.item.bibrecord.head.author-group.2.author.1.ce:initials: W.
# abstracts-retrieval-response.item.bibrecord.head.author-group.2.author.1.@_fa: true
# abstracts-retrieval-response.item.bibrecord.head.author-group.2.author.1.@type: auth
# abstracts-retrieval-response.item.bibrecord.head.author-group.2.author.1.ce:surname: Pungrasmi
# abstracts-retrieval-response.item.bibrecord.head.author-group.2.author.1.@auid: 23993014300
# abstracts-retrieval-response.item.bibrecord.head.author-group.2.author.1.ce:indexed-name: Pungrasmi W.
# abstracts-retrieval-response.item.bibrecord.head.author-group.3.affiliation.country: Thailand
# abstracts-retrieval-response.item.bibrecord.head.author-group.3.affiliation.@afid: 60012718
# abstracts-retrieval-response.item.bibrecord.head.author-group.3.affiliation.@country: tha
# abstracts-retrieval-response.item.bibrecord.head.author-group.3.affiliation.city: Bangkok
# abstracts-retrieval-response.item.bibrecord.head.author-group.3.affiliation.organization.0.$: Center of Excellence for Shrimp Molecular Biology and Biotechnology (Centex Shrimp)
# abstracts-retrieval-response.item.bibrecord.head.author-group.3.affiliation.organization.1.$: Faculty of Science
# abstracts-retrieval-response.item.bibrecord.head.author-group.3.affiliation.organization.2.$: Mahidol University
# abstracts-retrieval-response.item.bibrecord.head.author-group.3.affiliation.affiliation-id.@afid: 60012718
# abstracts-retrieval-response.item.bibrecord.head.author-group.3.affiliation.affiliation-id.@dptid: 103674492
# abstracts-retrieval-response.item.bibrecord.head.author-group.3.affiliation.@affiliation-instance-id: OB2BibRecID-949746532-8aa131875df85ade04233d253e94d0c2-1
# abstracts-retrieval-response.item.bibrecord.head.author-group.3.affiliation.ce:source-text: Center of Excellence for Shrimp Molecular Biology and Biotechnology (Centex Shrimp), Faculty of Science, Mahidol University, Bangkok, Thailand.
# abstracts-retrieval-response.item.bibrecord.head.author-group.3.affiliation.@dptid: 103674492
# abstracts-retrieval-response.item.bibrecord.head.author-group.3.author.0.ce:given-name: Piyanuch
# abstracts-retrieval-response.item.bibrecord.head.author-group.3.author.0.preferred-name.ce:given-name: Piyanuch
# abstracts-retrieval-response.item.bibrecord.head.author-group.3.author.0.preferred-name.ce:initials: P.
# abstracts-retrieval-response.item.bibrecord.head.author-group.3.author.0.preferred-name.ce:surname: Wechprasit
# abstracts-retrieval-response.item.bibrecord.head.author-group.3.author.0.preferred-name.ce:indexed-name: Wechprasit P.
# abstracts-retrieval-response.item.bibrecord.head.author-group.3.author.0.@author-instance-id: OB2BibRecID-949746532-d6fff5aa5f4c521863d69dfca51ad98e-1
# abstracts-retrieval-response.item.bibrecord.head.author-group.3.author.0.@seq: 3
# abstracts-retrieval-response.item.bibrecord.head.author-group.3.author.0.ce:initials: P.
# abstracts-retrieval-response.item.bibrecord.head.author-group.3.author.0.@_fa: true
# abstracts-retrieval-response.item.bibrecord.head.author-group.3.author.0.@type: auth
# abstracts-retrieval-response.item.bibrecord.head.author-group.3.author.0.ce:surname: Wechprasit
# abstracts-retrieval-response.item.bibrecord.head.author-group.3.author.0.@auid: 57208407732
# abstracts-retrieval-response.item.bibrecord.head.author-group.3.author.0.ce:indexed-name: Wechprasit P.
# abstracts-retrieval-response.item.bibrecord.head.author-group.3.author.1.ce:given-name: Kallaya
# abstracts-retrieval-response.item.bibrecord.head.author-group.3.author.1.preferred-name.ce:given-name: Kallaya
# abstracts-retrieval-response.item.bibrecord.head.author-group.3.author.1.preferred-name.ce:initials: K.
# abstracts-retrieval-response.item.bibrecord.head.author-group.3.author.1.preferred-name.ce:surname: Sritunyalucksana
# abstracts-retrieval-response.item.bibrecord.head.author-group.3.author.1.preferred-name.ce:indexed-name: Sritunyalucksana K.
# abstracts-retrieval-response.item.bibrecord.head.author-group.3.author.1.@author-instance-id: OB2BibRecID-949746532-d4a6ef9c18db685803e66c8c2e64f820-1
# abstracts-retrieval-response.item.bibrecord.head.author-group.3.author.1.@seq: 6
# abstracts-retrieval-response.item.bibrecord.head.author-group.3.author.1.ce:initials: K.
# abstracts-retrieval-response.item.bibrecord.head.author-group.3.author.1.@_fa: true
# abstracts-retrieval-response.item.bibrecord.head.author-group.3.author.1.@type: auth
# abstracts-retrieval-response.item.bibrecord.head.author-group.3.author.1.ce:surname: Sritunyalucksana
# abstracts-retrieval-response.item.bibrecord.head.author-group.3.author.1.@auid: 6507431846
# abstracts-retrieval-response.item.bibrecord.head.author-group.3.author.1.ce:indexed-name: Sritunyalucksana K.
# abstracts-retrieval-response.item.bibrecord.head.author-group.3.author.2.ce:given-name: Anuphap
# abstracts-retrieval-response.item.bibrecord.head.author-group.3.author.2.preferred-name.ce:given-name: Anuphap
# abstracts-retrieval-response.item.bibrecord.head.author-group.3.author.2.preferred-name.ce:initials: A.
# abstracts-retrieval-response.item.bibrecord.head.author-group.3.author.2.preferred-name.ce:surname: Prachumwat
# abstracts-retrieval-response.item.bibrecord.head.author-group.3.author.2.preferred-name.ce:indexed-name: Prachumwat A.
# abstracts-retrieval-response.item.bibrecord.head.author-group.3.author.2.@author-instance-id: OB2BibRecID-949746532-fb51904c402e83aad1e63ad77954999b-1
# abstracts-retrieval-response.item.bibrecord.head.author-group.3.author.2.@seq: 7
# abstracts-retrieval-response.item.bibrecord.head.author-group.3.author.2.ce:initials: A.
# abstracts-retrieval-response.item.bibrecord.head.author-group.3.author.2.@_fa: true
# abstracts-retrieval-response.item.bibrecord.head.author-group.3.author.2.@type: auth
# abstracts-retrieval-response.item.bibrecord.head.author-group.3.author.2.ce:surname: Prachumwat
# abstracts-retrieval-response.item.bibrecord.head.author-group.3.author.2.@auid: 9939200600
# abstracts-retrieval-response.item.bibrecord.head.author-group.3.author.2.ce:indexed-name: Prachumwat A.
# abstracts-retrieval-response.item.bibrecord.head.citation-title: Total ammonia nitrogen removal and microbial community dynamics in an outdoor HDPE-lined shrimp pond with no water discharge
# abstracts-retrieval-response.item.bibrecord.head.abstracts: © 2023 Elsevier B.V.This study assessed the characteristics of a zero-discharge outdoor high-density polyethylene (HDPE)-lined demonstration aquaculture pond (400 m2) in terms of water quality variables, total ammonia nitrogen (TAN) removal and oxygen net primary production (NPP) indices, and photosynthetic microbiome over a 76-day crop cycle. The shrimp harvest yield was 4.1 t/ha/crop with an average daily gain (ADG) of 0.15 g/day and a feed conversion ratio (FCR) of 1.49. During shrimp cultivation with a semi-intensive stocking density (40 shrimp/m2), there were low levels of TAN (<1.01 mg-N/L), nitrite (<0.21 mg-N/L), and nitrate (<2.79 mg-N/L). Ammonia removal was mainly mediated by photoautotrophic uptake, as evidenced by the consistent estimated TAN uptake rate of 0.05 ± 0.02 g-N/m3 h, which was calculated based on photosynthesis. The overall TAN removal rate of 0.10 ± 0.08 g-N/m3 h was maintained by suspended microorganisms in water, which exceeded that of microorganisms attached to the HDPE liner surface. A positive oxygen NPP of 0.24–1.16 g-O2/m3 h during light availability indicated prevailing autotrophic conditions. The bacterial community in the water was dominated by Phyla Pseudomonadota (Proteobacteria; 16–32%), Bacteroidota (Bacteroidetes; 15–29%), Cyanobacteria (7–35%), and Actinomycetota (Actinobacteria; 3–39%). The chloroplast amplicon sequence variants (ASVs) indicated abundances of Bacillariophyta (27–97%) and Chlorophyta (0.4–67%). High centric diatom populations (Bacillariophyta) were detected throughout cultivation, while the proportion of green algae (Chlorophyta) was positively correlated with increased TAN availability when feeding was increased. The findings enabled estimations of TAN removal and oxygen NPP rates and provided an understanding of correlations between environmental variables and bacterial and phytoplankton populations in the outdoor lined shrimp pond.
# abstracts-retrieval-response.item.bibrecord.head.correspondence.0.affiliation.country: Thailand
# abstracts-retrieval-response.item.bibrecord.head.correspondence.0.affiliation.@country: tha
# abstracts-retrieval-response.item.bibrecord.head.correspondence.0.affiliation.city: Pathum Thani
# abstracts-retrieval-response.item.bibrecord.head.correspondence.0.affiliation.organization.0.$: National Center for Genetic Engineering and Biotechnology (BIOTEC)
# abstracts-retrieval-response.item.bibrecord.head.correspondence.0.affiliation.organization.1.$: National Science and Technology Development Agency (NSTDA)
# abstracts-retrieval-response.item.bibrecord.head.correspondence.0.affiliation.@affiliation-instance-id: OB2BibRecID-949746532-81602e7f829b3e9b6bfbcc9e51c907e1-1
# abstracts-retrieval-response.item.bibrecord.head.correspondence.0.person.ce:given-name: Sorawit
# abstracts-retrieval-response.item.bibrecord.head.correspondence.0.person.@author-instance-id: OB2BibRecID-949746532-b0fb21df424602bd7c8d72b7c48374c2-1
# abstracts-retrieval-response.item.bibrecord.head.correspondence.0.person.ce:initials: S.
# abstracts-retrieval-response.item.bibrecord.head.correspondence.0.person.ce:surname: Powtongsook
# abstracts-retrieval-response.item.bibrecord.head.correspondence.0.person.ce:indexed-name: Powtongsook S.
# abstracts-retrieval-response.item.bibrecord.head.correspondence.1.affiliation.country: Thailand
# abstracts-retrieval-response.item.bibrecord.head.correspondence.1.affiliation.@country: tha
# abstracts-retrieval-response.item.bibrecord.head.correspondence.1.affiliation.city: Bangkok
# abstracts-retrieval-response.item.bibrecord.head.correspondence.1.affiliation.organization.0.$: Center of Excellence for Shrimp Molecular Biology and Biotechnology (Centex Shrimp)
# abstracts-retrieval-response.item.bibrecord.head.correspondence.1.affiliation.organization.1.$: Faculty of Science
# abstracts-retrieval-response.item.bibrecord.head.correspondence.1.affiliation.organization.2.$: Mahidol University
# abstracts-retrieval-response.item.bibrecord.head.correspondence.1.affiliation.@affiliation-instance-id: OB2BibRecID-949746532-e659712f12fbf3b6fb9382421c3429f1-1
# abstracts-retrieval-response.item.bibrecord.head.correspondence.1.person.ce:given-name: Anuphap
# abstracts-retrieval-response.item.bibrecord.head.correspondence.1.person.@author-instance-id: OB2BibRecID-949746532-8e0bd6a7ad3f3bdc01c7053be24c58b2-1
# abstracts-retrieval-response.item.bibrecord.head.correspondence.1.person.ce:initials: A.
# abstracts-retrieval-response.item.bibrecord.head.correspondence.1.person.ce:surname: Prachumwat
# abstracts-retrieval-response.item.bibrecord.head.correspondence.1.person.ce:indexed-name: Prachumwat A.
# abstracts-retrieval-response.item.bibrecord.head.citation-info.author-keywords.author-keyword.0.$: Ammonia removal
# abstracts-retrieval-response.item.bibrecord.head.citation-info.author-keywords.author-keyword.0.@xml:lang: eng
# abstracts-retrieval-response.item.bibrecord.head.citation-info.author-keywords.author-keyword.0.@original: y
# abstracts-retrieval-response.item.bibrecord.head.citation-info.author-keywords.author-keyword.1.$: Carrying capacity
# abstracts-retrieval-response.item.bibrecord.head.citation-info.author-keywords.author-keyword.1.@xml:lang: eng
# abstracts-retrieval-response.item.bibrecord.head.citation-info.author-keywords.author-keyword.1.@original: y
# abstracts-retrieval-response.item.bibrecord.head.citation-info.author-keywords.author-keyword.2.$: Microbiome
# abstracts-retrieval-response.item.bibrecord.head.citation-info.author-keywords.author-keyword.2.@xml:lang: eng
# abstracts-retrieval-response.item.bibrecord.head.citation-info.author-keywords.author-keyword.2.@original: y
# abstracts-retrieval-response.item.bibrecord.head.citation-info.author-keywords.author-keyword.3.$: Outdoor shrimp pond
# ...
# abstracts-retrieval-response.coredata.prism:coverDate: 2023-12-15
# abstracts-retrieval-response.coredata.prism:aggregationType: Journal
# abstracts-retrieval-response.coredata.prism:url: https://api.elsevier.com/content/abstract/scopus_id/85165929707
# abstracts-retrieval-response.coredata.subtypeDescription: Article
# abstracts-retrieval-response.coredata.dc:creator.author.0.ce:given-name: Penpicha
# abstracts-retrieval-response.coredata.dc:creator.author.0.preferred-name.ce:given-name: Penpicha
# abstracts-retrieval-response.coredata.dc:creator.author.0.preferred-name.ce:initials: P.
# abstracts-retrieval-response.coredata.dc:creator.author.0.preferred-name.ce:surname: Satanwat
# abstracts-retrieval-response.coredata.dc:creator.author.0.preferred-name.ce:indexed-name: Satanwat P.
# abstracts-retrieval-response.coredata.dc:creator.author.0.@seq: 1
# abstracts-retrieval-response.coredata.dc:creator.author.0.ce:initials: P.
# abstracts-retrieval-response.coredata.dc:creator.author.0.@_fa: true
# abstracts-retrieval-response.coredata.dc:creator.author.0.affiliation.0.@id: 60011947
# abstracts-retrieval-response.coredata.dc:creator.author.0.affiliation.0.@href: https://api.elsevier.com/content/affiliation/affiliation_id/60011947
# abstracts-retrieval-response.coredata.dc:creator.author.0.affiliation.1.@id: 60028190
# abstracts-retrieval-response.coredata.dc:creator.author.0.affiliation.1.@href: https://api.elsevier.com/content/affiliation/affiliation_id/60028190
# abstracts-retrieval-response.coredata.dc:creator.author.0.affiliation.2.@id: 60028190
# abstracts-retrieval-response.coredata.dc:creator.author.0.affiliation.2.@href: https://api.elsevier.com/content/affiliation/affiliation_id/60028190
# abstracts-retrieval-response.coredata.dc:creator.author.0.ce:surname: Satanwat
# abstracts-retrieval-response.coredata.dc:creator.author.0.@auid: 57208553550
# abstracts-retrieval-response.coredata.dc:creator.author.0.author-url: https://api.elsevier.com/content/author/author_id/57208553550
# abstracts-retrieval-response.coredata.dc:creator.author.0.ce:indexed-name: Satanwat P.
# abstracts-retrieval-response.coredata.link.0.@_fa: true
# abstracts-retrieval-response.coredata.link.0.@rel: self
# abstracts-retrieval-response.coredata.link.0.@href: https://api.elsevier.com/content/abstract/scopus_id/85165929707
# abstracts-retrieval-response.coredata.link.1.@_fa: true
# abstracts-retrieval-response.coredata.link.1.@rel: scopus
# abstracts-retrieval-response.coredata.link.1.@href: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85165929707&origin=inward
# abstracts-retrieval-response.coredata.link.2.@_fa: true
# abstracts-retrieval-response.coredata.link.2.@rel: scopus-citedby
# abstracts-retrieval-response.coredata.link.2.@href: https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85165929707&origin=inward
# abstracts-retrieval-response.coredata.prism:publicationName: Aquaculture
# abstracts-retrieval-response.coredata.source-id: 29419
# abstracts-retrieval-response.coredata.pii: S0044848623006725
# abstracts-retrieval-response.coredata.citedby-count: 0
# abstracts-retrieval-response.coredata.prism:volume: 577
# abstracts-retrieval-response.coredata.subtype: ar
# abstracts-retrieval-response.coredata.dc:title: Total ammonia nitrogen removal and microbial community dynamics in an outdoor HDPE-lined shrimp pond with no water discharge
# abstracts-retrieval-response.coredata.openaccess: 0
# abstracts-retrieval-response.coredata.openaccessFlag: false
# abstracts-retrieval-response.coredata.prism:doi: 10.1016/j.aquaculture.2023.739898
# abstracts-retrieval-response.coredata.prism:issn: 00448486
# abstracts-retrieval-response.coredata.publishercopyright: © 2023 Elsevier B.V.
# abstracts-retrieval-response.coredata.article-number: 739898
# abstracts-retrieval-response.coredata.dc:identifier: SCOPUS_ID:85165929707
# abstracts-retrieval-response.coredata.dc:publisher: Elsevier B.V.
# abstracts-retrieval-response.idxterms: None
# abstracts-retrieval-response.language.@xml:lang: eng
# abstracts-retrieval-response.authkeywords.author-keyword.0.@_fa: true
# abstracts-retrieval-response.authkeywords.author-keyword.0.$: Ammonia removal
# abstracts-retrieval-response.authkeywords.author-keyword.1.@_fa: true
# abstracts-retrieval-response.authkeywords.author-keyword.1.$: Carrying capacity
# abstracts-retrieval-response.authkeywords.author-keyword.2.@_fa: true
# abstracts-retrieval-response.authkeywords.author-keyword.2.$: Microbiome
# abstracts-retrieval-response.authkeywords.author-keyword.3.@_fa: true
# abstracts-retrieval-response.authkeywords.author-keyword.3.$: Outdoor shrimp pond
# abstracts-retrieval-response.authkeywords.author-keyword.4.@_fa: true
# abstracts-retrieval-response.authkeywords.author-keyword.4.$: Phytoplankton
# abstracts-retrieval-response.subject-areas.subject-area.0.@_fa: true
# abstracts-retrieval-response.subject-areas.subject-area.0.$: Aquatic Science
# abstracts-retrieval-response.subject-areas.subject-area.0.@code: 1104
# abstracts-retrieval-response.subject-areas.subject-area.0.@abbrev: AGRI
# abstracts-retrieval-response.authors.author.0.ce:given-name: Penpicha
# abstracts-retrieval-response.authors.author.0.preferred-name.ce:given-name: Penpicha
# abstracts-retrieval-response.authors.author.0.preferred-name.ce:initials: P.
# abstracts-retrieval-response.authors.author.0.preferred-name.ce:surname: Satanwat
# abstracts-retrieval-response.authors.author.0.preferred-name.ce:indexed-name: Satanwat P.
# abstracts-retrieval-response.authors.author.0.@seq: 1
# abstracts-retrieval-response.authors.author.0.ce:initials: P.
# abstracts-retrieval-response.authors.author.0.@_fa: true
# abstracts-retrieval-response.authors.author.0.affiliation.0.@id: 60011947
# abstracts-retrieval-response.authors.author.0.affiliation.0.@href: https://api.elsevier.com/content/affiliation/affiliation_id/60011947
# abstracts-retrieval-response.authors.author.0.affiliation.1.@id: 60028190
# abstracts-retrieval-response.authors.author.0.affiliation.1.@href: https://api.elsevier.com/content/affiliation/affiliation_id/60028190
# abstracts-retrieval-response.authors.author.0.affiliation.2.@id: 60028190
# abstracts-retrieval-response.authors.author.0.affiliation.2.@href: https://api.elsevier.com/content/affiliation/affiliation_id/60028190
# abstracts-retrieval-response.authors.author.0.ce:surname: Satanwat
# abstracts-retrieval-response.authors.author.0.@auid: 57208553550
# abstracts-retrieval-response.authors.author.0.author-url: https://api.elsevier.com/content/author/author_id/57208553550
# abstracts-retrieval-response.authors.author.0.ce:indexed-name: Satanwat P.
# abstracts-retrieval-response.authors.author.1.ce:given-name: Paveena
# abstracts-retrieval-response.authors.author.1.preferred-name.ce:given-name: Paveena
# abstracts-retrieval-response.authors.author.1.preferred-name.ce:initials: P.
# abstracts-retrieval-response.authors.author.1.preferred-name.ce:surname: Tapaneeyaworawong
# abstracts-retrieval-response.authors.author.1.preferred-name.ce:indexed-name: Tapaneeyaworawong P.
# abstracts-retrieval-response.authors.author.1.@seq: 2
# abstracts-retrieval-response.authors.author.1.ce:initials: P.
# abstracts-retrieval-response.authors.author.1.@_fa: true
# abstracts-retrieval-response.authors.author.1.affiliation.0.@id: 60011947
# abstracts-retrieval-response.authors.author.1.affiliation.0.@href: https://api.elsevier.com/content/affiliation/affiliation_id/60011947
# abstracts-retrieval-response.authors.author.1.affiliation.1.@id: 60028190
# abstracts-retrieval-response.authors.author.1.affiliation.1.@href: https://api.elsevier.com/content/affiliation/affiliation_id/60028190
# abstracts-retrieval-response.authors.author.1.ce:surname: Tapaneeyaworawong
# abstracts-retrieval-response.authors.author.1.@auid: 56374287000
# abstracts-retrieval-response.authors.author.1.author-url: https://api.elsevier.com/content/author/author_id/56374287000
# abstracts-retrieval-response.authors.author.1.ce:indexed-name: Tapaneeyaworawong P.
# abstracts-retrieval-response.authors.author.2.ce:given-name: Piyanuch
# abstracts-retrieval-response.authors.author.2.preferred-name.ce:given-name: Piyanuch
# abstracts-retrieval-response.authors.author.2.preferred-name.ce:initials: P.
# abstracts-retrieval-response.authors.author.2.preferred-name.ce:surname: Wechprasit
# abstracts-retrieval-response.authors.author.2.preferred-name.ce:indexed-name: Wechprasit P.
# abstracts-retrieval-response.authors.author.2.@seq: 3
# abstracts-retrieval-response.authors.author.2.ce:initials: P.
# abstracts-retrieval-response.authors.author.2.@_fa: true
# abstracts-retrieval-response.authors.author.2.affiliation.0.@id: 60011947
# abstracts-retrieval-response.authors.author.2.affiliation.0.@href: https://api.elsevier.com/content/affiliation/affiliation_id/60011947
# abstracts-retrieval-response.authors.author.2.affiliation.1.@id: 60012718
# abstracts-retrieval-response.authors.author.2.affiliation.1.@href: https://api.elsevier.com/content/affiliation/affiliation_id/60012718
# abstracts-retrieval-response.authors.author.2.ce:surname: Wechprasit
# abstracts-retrieval-response.authors.author.2.@auid: 57208407732
# abstracts-retrieval-response.authors.author.2.author-url: https://api.elsevier.com/content/author/author_id/57208407732
# abstracts-retrieval-response.authors.author.2.ce:indexed-name: Wechprasit P.
# abstracts-retrieval-response.authors.author.3.ce:given-name: Tharin
# abstracts-retrieval-response.authors.author.3.preferred-name.ce:given-name: Tharin
# abstracts-retrieval-response.authors.author.3.preferred-name.ce:initials: T.
# abstracts-retrieval-response.authors.author.3.preferred-name.ce:surname: Boonprasertsakul
# abstracts-retrieval-response.authors.author.3.preferred-name.ce:indexed-name: Boonprasertsakul T.
# abstracts-retrieval-response.authors.author.3.@seq: 4
# abstracts-retrieval-response.authors.author.3.ce:initials: T.
# abstracts-retrieval-response.authors.author.3.@_fa: true
# abstracts-retrieval-response.authors.author.3.affiliation.0.@id: 60011947
# abstracts-retrieval-response.authors.author.3.affiliation.0.@href: https://api.elsevier.com/content/affiliation/affiliation_id/60011947
# abstracts-retrieval-response.authors.author.3.affiliation.1.@id: 60028190
# abstracts-retrieval-response.authors.author.3.affiliation.1.@href: https://api.elsevier.com/content/affiliation/affiliation_id/60028190
# abstracts-retrieval-response.authors.author.3.ce:surname: Boonprasertsakul
# abstracts-retrieval-response.authors.author.3.@auid: 58307243400
# abstracts-retrieval-response.authors.author.3.author-url: https://api.elsevier.com/content/author/author_id/58307243400
# abstracts-retrieval-response.authors.author.3.ce:indexed-name: Boonprasertsakul T.
# abstracts-retrieval-response.authors.author.4.ce:given-name: Wiboonluk
# abstracts-retrieval-response.authors.author.4.preferred-name.ce:given-name: Wiboonluk
# abstracts-retrieval-response.authors.author.4.preferred-name.ce:initials: W.
# abstracts-retrieval-response.authors.author.4.preferred-name.ce:surname: Pungrasmi
# abstracts-retrieval-response.authors.author.4.preferred-name.ce:indexed-name: Pungrasmi W.
# abstracts-retrieval-response.authors.author.4.@seq: 5
# abstracts-retrieval-response.authors.author.4.ce:initials: W.
# abstracts-retrieval-response.authors.author.4.@_fa: true
# abstracts-retrieval-response.authors.author.4.affiliation.0.@id: 60028190
# abstracts-retrieval-response.authors.author.4.affiliation.0.@href: https://api.elsevier.com/content/affiliation/affiliation_id/60028190
# abstracts-retrieval-response.authors.author.4.affiliation.1.@id: 60028190
# abstracts-retrieval-response.authors.author.4.affiliation.1.@href: https://api.elsevier.com/content/affiliation/affiliation_id/60028190
# abstracts-retrieval-response.authors.author.4.ce:surname: Pungrasmi
# abstracts-retrieval-response.authors.author.4.@auid: 23993014300
# abstracts-retrieval-response.authors.author.4.author-url: https://api.elsevier.com/content/author/author_id/23993014300
# abstracts-retrieval-response.authors.author.4.ce:indexed-name: Pungrasmi W.
# abstracts-retrieval-response.authors.author.5.ce:given-name: Kallaya
# abstracts-retrieval-response.authors.author.5.preferred-name.ce:given-name: Kallaya
# abstracts-retrieval-response.authors.author.5.preferred-name.ce:initials: K.
# abstracts-retrieval-response.authors.author.5.preferred-name.ce:surname: Sritunyalucksana
# abstracts-retrieval-response.authors.author.5.preferred-name.ce:indexed-name: Sritunyalucksana K.
# abstracts-retrieval-response.authors.author.5.@seq: 6
# abstracts-retrieval-response.authors.author.5.ce:initials: K.
# abstracts-retrieval-response.authors.author.5.@_fa: true
# abstracts-retrieval-response.authors.author.5.affiliation.0.@id: 60011947
# abstracts-retrieval-response.authors.author.5.affiliation.0.@href: https://api.elsevier.com/content/affiliation/affiliation_id/60011947
# abstracts-retrieval-response.authors.author.5.affiliation.1.@id: 60012718
# abstracts-retrieval-response.authors.author.5.affiliation.1.@href: https://api.elsevier.com/content/affiliation/affiliation_id/60012718
# abstracts-retrieval-response.authors.author.5.ce:surname: Sritunyalucksana
# abstracts-retrieval-response.authors.author.5.@auid: 6507431846
# abstracts-retrieval-response.authors.author.5.author-url: https://api.elsevier.com/content/author/author_id/6507431846
# abstracts-retrieval-response.authors.author.5.ce:indexed-name: Sritunyalucksana K.
# abstracts-retrieval-response.authors.author.6.ce:given-name: Anuphap
# abstracts-retrieval-response.authors.author.6.preferred-name.ce:given-name: Anuphap
# abstracts-retrieval-response.authors.author.6.preferred-name.ce:initials: A.
# abstracts-retrieval-response.authors.author.6.preferred-name.ce:surname: Prachumwat
# abstracts-retrieval-response.authors.author.6.preferred-name.ce:indexed-name: Prachumwat A.
# abstracts-retrieval-response.authors.author.6.@seq: 7
# abstracts-retrieval-response.authors.author.6.ce:initials: A.
# abstracts-retrieval-response.authors.author.6.@_fa: true
# abstracts-retrieval-response.authors.author.6.affiliation.0.@id: 60011947
# abstracts-retrieval-response.authors.author.6.affiliation.0.@href: https://api.elsevier.com/content/affiliation/affiliation_id/60011947
# abstracts-retrieval-response.authors.author.6.affiliation.1.@id: 60012718
# abstracts-retrieval-response.authors.author.6.affiliation.1.@href: https://api.elsevier.com/content/affiliation/affiliation_id/60012718
# abstracts-retrieval-response.authors.author.6.ce:surname: Prachumwat
# abstracts-retrieval-response.authors.author.6.@auid: 9939200600
# abstracts-retrieval-response.authors.author.6.author-url: https://api.elsevier.com/content/author/author_id/9939200600
# abstracts-retrieval-response.authors.author.6.ce:indexed-name: Prachumwat A.
# abstracts-retrieval-response.authors.author.7.ce:given-name: Sorawit
# abstracts-retrieval-response.authors.author.7.preferred-name.ce:given-name: Sorawit
# abstracts-retrieval-response.authors.author.7.preferred-name.ce:initials: S.
# abstracts-retrieval-response.authors.author.7.preferred-name.ce:surname: Powtongsook
# abstracts-retrieval-response.authors.author.7.preferred-name.ce:indexed-name: Powtongsook S.
# abstracts-retrieval-response.authors.author.7.@seq: 8
# abstracts-retrieval-response.authors.author.7.ce:initials: S.
# abstracts-retrieval-response.authors.author.7.@_fa: true
# abstracts-retrieval-response.authors.author.7.affiliation.0.@id: 60011947
# abstracts-retrieval-response.authors.author.7.affiliation.0.@href: https://api.elsevier.com/content/affiliation/affiliation_id/60011947
# abstracts-retrieval-response.authors.author.7.affiliation.1.@id: 60028190
# abstracts-retrieval-response.authors.author.7.affiliation.1.@href: https://api.elsevier.com/content/affiliation/affiliation_id/60028190
# abstracts-retrieval-response.authors.author.7.ce:surname: Powtongsook
# abstracts-retrieval-response.authors.author.7.@auid: 6507593766
# abstracts-retrieval-response.authors.author.7.author-url: https://api.elsevier.com/content/author/author_id/6507593766
# abstracts-retrieval-response.authors.author.7.ce:indexed-name: Powtongsook S.

# %%
def get_json_schema_and_data(json_data, current_path="", indent=0):
    """Recursively prints the schema and data of JSON with full path."""
    if isinstance(json_data, dict):
        for key, value in json_data.items():
            new_path = f"{current_path}.{key}" if current_path else key
            if isinstance(value, (dict, list)):
                print(' ' * indent + f"{new_path}: {type(value).__name__}")
                get_json_schema_and_data(value, new_path, indent + 2)
            else:
                print(' ' * indent + f"{new_path}: {type(value).__name__} = {value}")
    
    elif isinstance(json_data, list):
        if len(json_data) > 0:
            print(' ' * indent + f"{current_path}: List of {type(json_data[0]).__name__}")
            for idx, item in enumerate(json_data):
                get_json_schema_and_data(item, f"{current_path}[{idx}]", indent + 2)
        else:
            print(' ' * indent + f"{current_path}: Empty List")
    
    else:
        print(' ' * indent + f"{current_path}: {type(json_data).__name__} = {json_data}")

# Example usage
json_file_path = 'raw-data/2020/202000000.json'
with open(json_file_path, 'r', encoding='utf-8') as f:
    json_data = json.load(f)

print("JSON Schema and Data:")
get_json_schema_and_data(json_data)
# Out:
# JSON Schema and Data:
# abstracts-retrieval-response: dict
#   abstracts-retrieval-response.item: dict
#     abstracts-retrieval-response.item.ait:process-info: dict
#       abstracts-retrieval-response.item.ait:process-info.ait:status: dict
#         abstracts-retrieval-response.item.ait:process-info.ait:status.@state: str = update
#         abstracts-retrieval-response.item.ait:process-info.ait:status.@type: str = core
#         abstracts-retrieval-response.item.ait:process-info.ait:status.@stage: str = S300
#       abstracts-retrieval-response.item.ait:process-info.ait:date-delivered: dict
#         abstracts-retrieval-response.item.ait:process-info.ait:date-delivered.@day: str = 14
#         abstracts-retrieval-response.item.ait:process-info.ait:date-delivered.@timestamp: str = 2021-11-14T16:58:37.000037-05:00
#         abstracts-retrieval-response.item.ait:process-info.ait:date-delivered.@year: str = 2021
#         abstracts-retrieval-response.item.ait:process-info.ait:date-delivered.@month: str = 11
#       abstracts-retrieval-response.item.ait:process-info.ait:date-sort: dict
#         abstracts-retrieval-response.item.ait:process-info.ait:date-sort.@day: str = 30
#         abstracts-retrieval-response.item.ait:process-info.ait:date-sort.@year: str = 2020
#         abstracts-retrieval-response.item.ait:process-info.ait:date-sort.@month: str = 12
#     abstracts-retrieval-response.item.xocs:meta: dict
#       abstracts-retrieval-response.item.xocs:meta.xocs:funding-list: dict
#         abstracts-retrieval-response.item.xocs:meta.xocs:funding-list.@pui-match: str = primary
#         abstracts-retrieval-response.item.xocs:meta.xocs:funding-list.@has-funding-info: str = 1
#         abstracts-retrieval-response.item.xocs:meta.xocs:funding-list.xocs:funding: list
#           abstracts-retrieval-response.item.xocs:meta.xocs:funding-list.xocs:funding: List of dict
#             abstracts-retrieval-response.item.xocs:meta.xocs:funding-list.xocs:funding[0].xocs:funding-agency-matched-string: str = FWO-Vlaanderen
#             abstracts-retrieval-response.item.xocs:meta.xocs:funding-list.xocs:funding[0].xocs:funding-id: list
#               abstracts-retrieval-response.item.xocs:meta.xocs:funding-list.xocs:funding[0].xocs:funding-id: List of dict
#                 abstracts-retrieval-response.item.xocs:meta.xocs:funding-list.xocs:funding[0].xocs:funding-id[0].$: str = G006918N
#                 abstracts-retrieval-response.item.xocs:meta.xocs:funding-list.xocs:funding[0].xocs:funding-id[1].$: str = G044016N
#             abstracts-retrieval-response.item.xocs:meta.xocs:funding-list.xocs:funding[1].xocs:funding-agency-matched-string: str = Polish National Science Centre
#             abstracts-retrieval-response.item.xocs:meta.xocs:funding-list.xocs:funding[1].xocs:funding-id: str = 2017/26/A/ST2/00530
#             abstracts-retrieval-response.item.xocs:meta.xocs:funding-list.xocs:funding[2].xocs:funding-agency-matched-string: str = Chulalongkorn University
#             abstracts-retrieval-response.item.xocs:meta.xocs:funding-list.xocs:funding[2].xocs:funding-agency-acronym: str = CU
#             abstracts-retrieval-response.item.xocs:meta.xocs:funding-list.xocs:funding[2].xocs:funding-agency: str = Chulalongkorn University
#             abstracts-retrieval-response.item.xocs:meta.xocs:funding-list.xocs:funding[2].xocs:funding-agency-id: str = http://data.elsevier.com/vocabulary/SciValFunders/501100002873
#             abstracts-retrieval-response.item.xocs:meta.xocs:funding-list.xocs:funding[2].xocs:funding-agency-country: str = http://sws.geonames.org/1605651/
#             abstracts-retrieval-response.item.xocs:meta.xocs:funding-list.xocs:funding[3].xocs:funding-agency-matched-string: str = FWO
#             abstracts-retrieval-response.item.xocs:meta.xocs:funding-list.xocs:funding[3].xocs:funding-agency-acronym: str = FWO
#             abstracts-retrieval-response.item.xocs:meta.xocs:funding-list.xocs:funding[3].xocs:funding-agency: str = Fonds Wetenschappelijk Onderzoek
#             abstracts-retrieval-response.item.xocs:meta.xocs:funding-list.xocs:funding[3].xocs:funding-agency-id: str = http://data.elsevier.com/vocabulary/SciValFunders/501100003130
#             abstracts-retrieval-response.item.xocs:meta.xocs:funding-list.xocs:funding[3].xocs:funding-agency-country: str = http://sws.geonames.org/2802361/
#             abstracts-retrieval-response.item.xocs:meta.xocs:funding-list.xocs:funding[4].xocs:funding-agency-matched-string: str = Vrije Universiteit Brussel
#             abstracts-retrieval-response.item.xocs:meta.xocs:funding-list.xocs:funding[4].xocs:funding-agency-acronym: str = VUB
#             abstracts-retrieval-response.item.xocs:meta.xocs:funding-list.xocs:funding[4].xocs:funding-agency: str = Vrije Universiteit Brussel
#             abstracts-retrieval-response.item.xocs:meta.xocs:funding-list.xocs:funding[4].xocs:funding-agency-id: str = http://data.elsevier.com/vocabulary/SciValFunders/501100004418
#             abstracts-retrieval-response.item.xocs:meta.xocs:funding-list.xocs:funding[4].xocs:funding-agency-country: str = http://sws.geonames.org/2802361/
#             abstracts-retrieval-response.item.xocs:meta.xocs:funding-list.xocs:funding[5].xocs:funding-agency-matched-string: str = Jagiellonian University in Krakow
#             abstracts-retrieval-response.item.xocs:meta.xocs:funding-list.xocs:funding[5].xocs:funding-agency: str = Uniwersytet Jagielloński w Krakowie
#             abstracts-retrieval-response.item.xocs:meta.xocs:funding-list.xocs:funding[5].xocs:funding-agency-id: str = http://data.elsevier.com/vocabulary/SciValFunders/501100007088
#             abstracts-retrieval-response.item.xocs:meta.xocs:funding-list.xocs:funding[5].xocs:funding-agency-country: str = http://sws.geonames.org/798544/
#         abstracts-retrieval-response.item.xocs:meta.xocs:funding-list.xocs:funding-addon-generated-timestamp: str = 2021-06-04T16:48:38.492Z
#         abstracts-retrieval-response.item.xocs:meta.xocs:funding-list.xocs:funding-text: list
#           abstracts-retrieval-response.item.xocs:meta.xocs:funding-list.xocs:funding-text: List of dict
#             abstracts-retrieval-response.item.xocs:meta.xocs:funding-list.xocs:funding-text[0].$: str = We thank Ben Craps and Surbhi Khetrapal for collaboration on related subjects. This research has been supported by FWO-Vlaanderen (projects G044016N and G006918N ), by Vrije Universiteit Brussel through the Strategic Research Program “High-Energy Physics,” and by CUniverse research promotion project (CUAASC) at Chulalongkorn University . M. D. C. is supported by a PhD fellowship from the Research Foundation Flanders (FWO). O. E. has benefited from his stay at the Jagiellonian University in Krakow during which part of this work was developed. Support of the Polish National Science Centre through grant number 2017/26/A/ST2/00530 and personal hospitality of Piotr and Magda Bizoń are gratefully acknowledged.
#             abstracts-retrieval-response.item.xocs:meta.xocs:funding-list.xocs:funding-text[1].$: str = We thank Ben Craps and Surbhi Khetrapal for collaboration on related subjects. This research has been supported by FWO-Vlaanderen (projects G044016N and G006918N), by Vrije Universiteit Brussel through the Strategic Research Program ?High-Energy Physics,? and by CUniverse research promotion project (CUAASC) at Chulalongkorn University. M. D. C. is supported by a PhD fellowship from the Research Foundation Flanders (FWO). O. E. has benefited from his stay at the Jagiellonian University in Krakow during which part of this work was developed. Support of the Polish National Science Centre through grant number 2017/26/A/ST2/00530 and personal hospitality of Piotr and Magda Bizo? are gratefully acknowledged.
#         abstracts-retrieval-response.item.xocs:meta.xocs:funding-list.xocs:funding-addon-type: str = http://vtw.elsevier.com/data/voc/AddOnTypes/50.7/aggregated-refined
#     abstracts-retrieval-response.item.bibrecord: dict
#       abstracts-retrieval-response.item.bibrecord.head: dict
#         abstracts-retrieval-response.item.bibrecord.head.author-group: list
#           abstracts-retrieval-response.item.bibrecord.head.author-group: List of dict
#             abstracts-retrieval-response.item.bibrecord.head.author-group[0].affiliation: dict
#               abstracts-retrieval-response.item.bibrecord.head.author-group[0].affiliation.country: str = Belgium
#               abstracts-retrieval-response.item.bibrecord.head.author-group[0].affiliation.address-part: str = Pleinlaan 2
#               abstracts-retrieval-response.item.bibrecord.head.author-group[0].affiliation.postal-code: str = B-1050
#               abstracts-retrieval-response.item.bibrecord.head.author-group[0].affiliation.@afid: str = 60070009
#               abstracts-retrieval-response.item.bibrecord.head.author-group[0].affiliation.@country: str = bel
#               abstracts-retrieval-response.item.bibrecord.head.author-group[0].affiliation.city: str = Brussels
#               abstracts-retrieval-response.item.bibrecord.head.author-group[0].affiliation.organization: list
#                 abstracts-retrieval-response.item.bibrecord.head.author-group[0].affiliation.organization: List of dict
#                   abstracts-retrieval-response.item.bibrecord.head.author-group[0].affiliation.organization[0].$: str = Theoretische Natuurkunde
#                   abstracts-retrieval-response.item.bibrecord.head.author-group[0].affiliation.organization[1].$: str = Vrije Universiteit Brussel (VUB)
#                   abstracts-retrieval-response.item.bibrecord.head.author-group[0].affiliation.organization[2].$: str = The International Solvay Institutes
#               abstracts-retrieval-response.item.bibrecord.head.author-group[0].affiliation.affiliation-id: list
#                 abstracts-retrieval-response.item.bibrecord.head.author-group[0].affiliation.affiliation-id: List of dict
#                   abstracts-retrieval-response.item.bibrecord.head.author-group[0].affiliation.affiliation-id[0].@afid: str = 60070009
#                   abstracts-retrieval-response.item.bibrecord.head.author-group[0].affiliation.affiliation-id[1].@afid: str = 60026810
#               abstracts-retrieval-response.item.bibrecord.head.author-group[0].affiliation.@affiliation-instance-id: str = S0375960120307970-db902bfd8a55ae9a8fc257018608905e
#               abstracts-retrieval-response.item.bibrecord.head.author-group[0].affiliation.ce:source-text: str = Theoretische Natuurkunde, Vrije Universiteit Brussel (VUB) and The International Solvay Institutes, Pleinlaan 2, B-1050 Brussels, Belgium
#             abstracts-retrieval-response.item.bibrecord.head.author-group[0].author: list
#               abstracts-retrieval-response.item.bibrecord.head.author-group[0].author: List of dict
#                 abstracts-retrieval-response.item.bibrecord.head.author-group[0].author[0].ce:given-name: str = Marine
#                 abstracts-retrieval-response.item.bibrecord.head.author-group[0].author[0].preferred-name: dict
#                   abstracts-retrieval-response.item.bibrecord.head.author-group[0].author[0].preferred-name.ce:given-name: str = Marine
#                   abstracts-retrieval-response.item.bibrecord.head.author-group[0].author[0].preferred-name.ce:initials: str = M.
#                   abstracts-retrieval-response.item.bibrecord.head.author-group[0].author[0].preferred-name.ce:surname: str = De Clerck
#                   abstracts-retrieval-response.item.bibrecord.head.author-group[0].author[0].preferred-name.ce:indexed-name: str = De Clerck M.
#                 abstracts-retrieval-response.item.bibrecord.head.author-group[0].author[0].@author-instance-id: str = S0375960120307970-eae682f8a11ea3e8c0f3861a70e97124
#                 abstracts-retrieval-response.item.bibrecord.head.author-group[0].author[0].@seq: str = 1
#                 abstracts-retrieval-response.item.bibrecord.head.author-group[0].author[0].ce:initials: str = M.
#                 abstracts-retrieval-response.item.bibrecord.head.author-group[0].author[0].@_fa: str = true
#                 abstracts-retrieval-response.item.bibrecord.head.author-group[0].author[0].@type: str = auth
#                 abstracts-retrieval-response.item.bibrecord.head.author-group[0].author[0].ce:surname: str = De Clerck
#                 abstracts-retrieval-response.item.bibrecord.head.author-group[0].author[0].@auid: str = 57210392338
#                 abstracts-retrieval-response.item.bibrecord.head.author-group[0].author[0].@orcid: str = 0000-0001-5949-9924
#                 abstracts-retrieval-response.item.bibrecord.head.author-group[0].author[0].ce:indexed-name: str = De Clerck M.
#                 abstracts-retrieval-response.item.bibrecord.head.author-group[0].author[1].ce:given-name: str = Oleg
#                 abstracts-retrieval-response.item.bibrecord.head.author-group[0].author[1].preferred-name: dict
#                   abstracts-retrieval-response.item.bibrecord.head.author-group[0].author[1].preferred-name.ce:given-name: str = Oleg
#                   abstracts-retrieval-response.item.bibrecord.head.author-group[0].author[1].preferred-name.ce:initials: str = O.
#                   abstracts-retrieval-response.item.bibrecord.head.author-group[0].author[1].preferred-name.ce:surname: str = Evnin
#                   abstracts-retrieval-response.item.bibrecord.head.author-group[0].author[1].preferred-name.ce:indexed-name: str = Evnin O.
#                 abstracts-retrieval-response.item.bibrecord.head.author-group[0].author[1].@author-instance-id: str = S0375960120307970-6d6efc24e426d0cd39535e341b58c4b8
#                 abstracts-retrieval-response.item.bibrecord.head.author-group[0].author[1].@seq: str = 2
#                 abstracts-retrieval-response.item.bibrecord.head.author-group[0].author[1].ce:initials: str = O.
#                 abstracts-retrieval-response.item.bibrecord.head.author-group[0].author[1].@_fa: str = true
#                 abstracts-retrieval-response.item.bibrecord.head.author-group[0].author[1].@type: str = auth
#                 abstracts-retrieval-response.item.bibrecord.head.author-group[0].author[1].ce:surname: str = Evnin
#                 abstracts-retrieval-response.item.bibrecord.head.author-group[0].author[1].@auid: str = 15761759100
#                 abstracts-retrieval-response.item.bibrecord.head.author-group[0].author[1].@orcid: str = 0000-0001-5999-778X
#                 abstracts-retrieval-response.item.bibrecord.head.author-group[0].author[1].ce:indexed-name: str = Evnin O.
#             abstracts-retrieval-response.item.bibrecord.head.author-group[1].affiliation: dict
#               abstracts-retrieval-response.item.bibrecord.head.author-group[1].affiliation.country: str = Thailand
#               abstracts-retrieval-response.item.bibrecord.head.author-group[1].affiliation.address-part: str = Phayathai Rd.
#               abstracts-retrieval-response.item.bibrecord.head.author-group[1].affiliation.postal-code: str = 10330
#               abstracts-retrieval-response.item.bibrecord.head.author-group[1].affiliation.@afid: str = 60028190
#               abstracts-retrieval-response.item.bibrecord.head.author-group[1].affiliation.@country: str = tha
#               abstracts-retrieval-response.item.bibrecord.head.author-group[1].affiliation.city: str = Bangkok
#               abstracts-retrieval-response.item.bibrecord.head.author-group[1].affiliation.organization: list
#                 abstracts-retrieval-response.item.bibrecord.head.author-group[1].affiliation.organization: List of dict
#                   abstracts-retrieval-response.item.bibrecord.head.author-group[1].affiliation.organization[0].$: str = Department of Physics
#                   abstracts-retrieval-response.item.bibrecord.head.author-group[1].affiliation.organization[1].$: str = Faculty of Science
#                   abstracts-retrieval-response.item.bibrecord.head.author-group[1].affiliation.organization[2].$: str = Chulalongkorn University
#               abstracts-retrieval-response.item.bibrecord.head.author-group[1].affiliation.affiliation-id: dict
#                 abstracts-retrieval-response.item.bibrecord.head.author-group[1].affiliation.affiliation-id.@afid: str = 60028190
#                 abstracts-retrieval-response.item.bibrecord.head.author-group[1].affiliation.affiliation-id.@dptid: str = 108271278
#               abstracts-retrieval-response.item.bibrecord.head.author-group[1].affiliation.@affiliation-instance-id: str = S0375960120307970-147da4a73b56d8037918d684b23f58e6
#               abstracts-retrieval-response.item.bibrecord.head.author-group[1].affiliation.ce:source-text: str = Department of Physics, Faculty of Science, Chulalongkorn University, Phayathai Rd., Bangkok 10330, Thailand
#               abstracts-retrieval-response.item.bibrecord.head.author-group[1].affiliation.@dptid: str = 108271278
#             abstracts-retrieval-response.item.bibrecord.head.author-group[1].author: list
#               abstracts-retrieval-response.item.bibrecord.head.author-group[1].author: List of dict
#                 abstracts-retrieval-response.item.bibrecord.head.author-group[1].author[0].ce:given-name: str = Oleg
#                 abstracts-retrieval-response.item.bibrecord.head.author-group[1].author[0].preferred-name: dict
#                   abstracts-retrieval-response.item.bibrecord.head.author-group[1].author[0].preferred-name.ce:given-name: str = Oleg
#                   abstracts-retrieval-response.item.bibrecord.head.author-group[1].author[0].preferred-name.ce:initials: str = O.
#                   abstracts-retrieval-response.item.bibrecord.head.author-group[1].author[0].preferred-name.ce:surname: str = Evnin
#                   abstracts-retrieval-response.item.bibrecord.head.author-group[1].author[0].preferred-name.ce:indexed-name: str = Evnin O.
#                 abstracts-retrieval-response.item.bibrecord.head.author-group[1].author[0].@author-instance-id: str = S0375960120307970-6d6efc24e426d0cd39535e341b58c4b8
#                 abstracts-retrieval-response.item.bibrecord.head.author-group[1].author[0].@seq: str = 2
#                 abstracts-retrieval-response.item.bibrecord.head.author-group[1].author[0].ce:initials: str = O.
#                 abstracts-retrieval-response.item.bibrecord.head.author-group[1].author[0].@_fa: str = true
#                 abstracts-retrieval-response.item.bibrecord.head.author-group[1].author[0].@type: str = auth
#                 abstracts-retrieval-response.item.bibrecord.head.author-group[1].author[0].ce:surname: str = Evnin
#                 abstracts-retrieval-response.item.bibrecord.head.author-group[1].author[0].@auid: str = 15761759100
#                 abstracts-retrieval-response.item.bibrecord.head.author-group[1].author[0].@orcid: str = 0000-0001-5999-778X
#                 abstracts-retrieval-response.item.bibrecord.head.author-group[1].author[0].ce:indexed-name: str = Evnin O.
#         abstracts-retrieval-response.item.bibrecord.head.citation-title: str = Time-periodic quantum states of weakly interacting bosons in a harmonic trap
#         abstracts-retrieval-response.item.bibrecord.head.abstracts: str = © 2020 Elsevier B.V.We consider quantum bosons with contact interactions at the Lowest Landau Level (LLL) of a two-dimensional isotropic harmonic trap. At linear order in the coupling parameter g, we construct a large, explicit family of quantum states with energies of the form E0+gE1/4+O(g2), where E0 and E1 are integers. Any superposition of these states evolves periodically with a period of 8π/g until, at much longer time scales of order 1/g2, corrections to the energies of order g2 may become relevant. These quantum states provide a counterpart to the known time-periodic behaviors of the corresponding classical (mean field) theory.
#         abstracts-retrieval-response.item.bibrecord.head.correspondence: dict
#           abstracts-retrieval-response.item.bibrecord.head.correspondence.affiliation: dict
#             abstracts-retrieval-response.item.bibrecord.head.correspondence.affiliation.country: str = Belgium
#             abstracts-retrieval-response.item.bibrecord.head.correspondence.affiliation.address-part: str = Pleinlaan 2
#             abstracts-retrieval-response.item.bibrecord.head.correspondence.affiliation.postal-code: str = B-1050
#             abstracts-retrieval-response.item.bibrecord.head.correspondence.affiliation.@country: str = bel
#             abstracts-retrieval-response.item.bibrecord.head.correspondence.affiliation.city: str = Brussels
#             abstracts-retrieval-response.item.bibrecord.head.correspondence.affiliation.organization: list
#               abstracts-retrieval-response.item.bibrecord.head.correspondence.affiliation.organization: List of dict
#                 abstracts-retrieval-response.item.bibrecord.head.correspondence.affiliation.organization[0].$: str = Theoretische Natuurkunde
#                 abstracts-retrieval-response.item.bibrecord.head.correspondence.affiliation.organization[1].$: str = Vrije Universiteit Brussel (VUB)
#                 abstracts-retrieval-response.item.bibrecord.head.correspondence.affiliation.organization[2].$: str = The International Solvay Institutes
#           abstracts-retrieval-response.item.bibrecord.head.correspondence.person: dict
#             abstracts-retrieval-response.item.bibrecord.head.correspondence.person.ce:given-name: str = Marine
#             abstracts-retrieval-response.item.bibrecord.head.correspondence.person.ce:initials: str = M.
#             abstracts-retrieval-response.item.bibrecord.head.correspondence.person.ce:surname: str = De Clerck
#             abstracts-retrieval-response.item.bibrecord.head.correspondence.person.ce:indexed-name: str = De Clerck M.
#         abstracts-retrieval-response.item.bibrecord.head.citation-info: dict
#           abstracts-retrieval-response.item.bibrecord.head.citation-info.author-keywords: dict
#             abstracts-retrieval-response.item.bibrecord.head.citation-info.author-keywords.author-keyword: list
#               abstracts-retrieval-response.item.bibrecord.head.citation-info.author-keywords.author-keyword: List of dict
#                 abstracts-retrieval-response.item.bibrecord.head.citation-info.author-keywords.author-keyword[0].$: str = Bose-Einstein condensates
#                 abstracts-retrieval-response.item.bibrecord.head.citation-info.author-keywords.author-keyword[0].@xml:lang: str = eng
#                 abstracts-retrieval-response.item.bibrecord.head.citation-info.author-keywords.author-keyword[0].@original: str = y
#                 abstracts-retrieval-response.item.bibrecord.head.citation-info.author-keywords.author-keyword[1].$: str = Breathers
#                 abstracts-retrieval-response.item.bibrecord.head.citation-info.author-keywords.author-keyword[1].@xml:lang: str = eng
#                 abstracts-retrieval-response.item.bibrecord.head.citation-info.author-keywords.author-keyword[1].@original: str = y
#                 abstracts-retrieval-response.item.bibrecord.head.citation-info.author-keywords.author-keyword[2].$: str = Matter waves
#                 abstracts-retrieval-response.item.bibrecord.head.citation-info.author-keywords.author-keyword[2].@xml:lang: str = eng
#                 abstracts-retrieval-response.item.bibrecord.head.citation-info.author-keywords.author-keyword[2].@original: str = y
#                 abstracts-retrieval-response.item.bibrecord.head.citation-info.author-keywords.author-keyword[3].$: str = Nonlinear waves
#                 abstracts-retrieval-response.item.bibrecord.head.citation-info.author-keywords.author-keyword[3].@xml:lang: str = eng
#                 abstracts-retrieval-response.item.bibrecord.head.citation-info.author-keywords.author-keyword[3].@original: str = y
#           abstracts-retrieval-response.item.bibrecord.head.citation-info.citation-type: dict
#             abstracts-retrieval-response.item.bibrecord.head.citation-info.citation-type.@code: str = ar
#           abstracts-retrieval-response.item.bibrecord.head.citation-info.citation-language: dict
#             abstracts-retrieval-response.item.bibrecord.head.citation-info.citation-language.@language: str = English
#             abstracts-retrieval-response.item.bibrecord.head.citation-info.citation-language.@xml:lang: str = eng
#           abstracts-retrieval-response.item.bibrecord.head.citation-info.abstract-language: dict
#             abstracts-retrieval-response.item.bibrecord.head.citation-info.abstract-language.@language: str = English
#             abstracts-retrieval-response.item.bibrecord.head.citation-info.abstract-language.@xml:lang: str = eng
#         abstracts-retrieval-response.item.bibrecord.head.source: dict
#           abstracts-retrieval-response.item.bibrecord.head.source.website: dict
#             abstracts-retrieval-response.item.bibrecord.head.source.website.ce:e-address: dict
#               abstracts-retrieval-response.item.bibrecord.head.source.website.ce:e-address.$: str = https://www.journals.elsevier.com/physics-letters-a
#               abstracts-retrieval-response.item.bibrecord.head.source.website.ce:e-address.@type: str = email
#           abstracts-retrieval-response.item.bibrecord.head.source.translated-sourcetitle: dict
#             abstracts-retrieval-response.item.bibrecord.head.source.translated-sourcetitle.$: str = Physics Letters, Section A: General, Atomic and Solid State Physics
#             abstracts-retrieval-response.item.bibrecord.head.source.translated-sourcetitle.@xml:lang: str = eng
#           abstracts-retrieval-response.item.bibrecord.head.source.volisspag: dict
#             abstracts-retrieval-response.item.bibrecord.head.source.volisspag.voliss: dict
#               abstracts-retrieval-response.item.bibrecord.head.source.volisspag.voliss.@volume: str = 384
#               abstracts-retrieval-response.item.bibrecord.head.source.volisspag.voliss.@issue: str = 36
#           abstracts-retrieval-response.item.bibrecord.head.source.@type: str = j
#           abstracts-retrieval-response.item.bibrecord.head.source.sourcetitle: str = Physics Letters, Section A: General, Atomic and Solid State Physics
#           abstracts-retrieval-response.item.bibrecord.head.source.publicationdate: dict
#             abstracts-retrieval-response.item.bibrecord.head.source.publicationdate.month: str = 12
#             abstracts-retrieval-response.item.bibrecord.head.source.publicationdate.year: str = 2020
#             abstracts-retrieval-response.item.bibrecord.head.source.publicationdate.date-text: dict
#               abstracts-retrieval-response.item.bibrecord.head.source.publicationdate.date-text.@xfab-added: str = true
#               abstracts-retrieval-response.item.bibrecord.head.source.publicationdate.date-text.$: str = 30 December 2020
#             abstracts-retrieval-response.item.bibrecord.head.source.publicationdate.day: str = 30
#           abstracts-retrieval-response.item.bibrecord.head.source.codencode: str = PYLAA
#           abstracts-retrieval-response.item.bibrecord.head.source.sourcetitle-abbrev: str = Phys Lett Sect A Gen At Solid State Phys
#           abstracts-retrieval-response.item.bibrecord.head.source.@country: str = nld
#           abstracts-retrieval-response.item.bibrecord.head.source.issn: dict
#             abstracts-retrieval-response.item.bibrecord.head.source.issn.$: str = 03759601
#             abstracts-retrieval-response.item.bibrecord.head.source.issn.@type: str = print
#           abstracts-retrieval-response.item.bibrecord.head.source.publicationyear: dict
#             abstracts-retrieval-response.item.bibrecord.head.source.publicationyear.@first: str = 2020
#           abstracts-retrieval-response.item.bibrecord.head.source.publisher: dict
#             abstracts-retrieval-response.item.bibrecord.head.source.publisher.affiliation: dict
#               abstracts-retrieval-response.item.bibrecord.head.source.publisher.affiliation.@country: str = nld
#               abstracts-retrieval-response.item.bibrecord.head.source.publisher.affiliation.city: NoneType = None
#             abstracts-retrieval-response.item.bibrecord.head.source.publisher.publishername: str = Elsevier B.V.
#           abstracts-retrieval-response.item.bibrecord.head.source.article-number: str = 126930
#           abstracts-retrieval-response.item.bibrecord.head.source.@srcid: str = 29464
#         abstracts-retrieval-response.item.bibrecord.head.enhancement: dict
#           abstracts-retrieval-response.item.bibrecord.head.enhancement.classificationgroup: dict
#             abstracts-retrieval-response.item.bibrecord.head.enhancement.classificationgroup.classifications: list
#               abstracts-retrieval-response.item.bibrecord.head.enhancement.classificationgroup.classifications: List of dict
#                 abstracts-retrieval-response.item.bibrecord.head.enhancement.classificationgroup.classifications[0].@type: str = CPXCLASS
#                 abstracts-retrieval-response.item.bibrecord.head.enhancement.classificationgroup.classifications[0].classification: list
#                   abstracts-retrieval-response.item.bibrecord.head.enhancement.classificationgroup.classifications[0].classification: List of dict
#                     abstracts-retrieval-response.item.bibrecord.head.enhancement.classificationgroup.classifications[0].classification[0].classification-code: str = 931.3
#                     abstracts-retrieval-response.item.bibrecord.head.enhancement.classificationgroup.classifications[0].classification[0].classification-description: str = Atomic and Molecular Physics
#                     abstracts-retrieval-response.item.bibrecord.head.enhancement.classificationgroup.classifications[0].classification[1].classification-code: str = 931.4
#                     abstracts-retrieval-response.item.bibrecord.head.enhancement.classificationgroup.classifications[0].classification[1].classification-description: str = Quantum Theory
#                 abstracts-retrieval-response.item.bibrecord.head.enhancement.classificationgroup.classifications[1].@type: str = FLXCLASS
#                 abstracts-retrieval-response.item.bibrecord.head.enhancement.classificationgroup.classifications[1].classification: dict
#                   abstracts-retrieval-response.item.bibrecord.head.enhancement.classificationgroup.classifications[1].classification.classification-code: str = 902
#                   abstracts-retrieval-response.item.bibrecord.head.enhancement.classificationgroup.classifications[1].classification.classification-description: str = FLUIDEX; Related Topics
#                 abstracts-retrieval-response.item.bibrecord.head.enhancement.classificationgroup.classifications[2].@type: str = ASJC
#                 abstracts-retrieval-response.item.bibrecord.head.enhancement.classificationgroup.classifications[2].classification: str = 3100
#                 abstracts-retrieval-response.item.bibrecord.head.enhancement.classificationgroup.classifications[3].@type: str = SUBJABBR
#                 abstracts-retrieval-response.item.bibrecord.head.enhancement.classificationgroup.classifications[3].classification: str = PHYS
#         abstracts-retrieval-response.item.bibrecord.head.grantlist: dict
#           abstracts-retrieval-response.item.bibrecord.head.grantlist.@complete: str = y
#           abstracts-retrieval-response.item.bibrecord.head.grantlist.grant-text: dict
#             abstracts-retrieval-response.item.bibrecord.head.grantlist.grant-text.$: str = We thank Ben Craps and Surbhi Khetrapal for collaboration on related subjects. This research has been supported by FWO-Vlaanderen (projects G044016N and G006918N), by Vrije Universiteit Brussel through the Strategic Research Program “High-Energy Physics,” and by CUniverse research promotion project (CUAASC) at Chulalongkorn University. M. D. C. is supported by a PhD fellowship from the Research Foundation Flanders (FWO). O. E. has benefited from his stay at the Jagiellonian University in Krakow during which part of this work was developed. Support of the Polish National Science Centre through grant number 2017/26/A/ST2/00530 and personal hospitality of Piotr and Magda Bizoń are gratefully acknowledged.
#             abstracts-retrieval-response.item.bibrecord.head.grantlist.grant-text.@xml:lang: str = eng
#           abstracts-retrieval-response.item.bibrecord.head.grantlist.grant: list
#             abstracts-retrieval-response.item.bibrecord.head.grantlist.grant: List of dict
#               abstracts-retrieval-response.item.bibrecord.head.grantlist.grant[0].grant-acronym: str = CU
#               abstracts-retrieval-response.item.bibrecord.head.grantlist.grant[0].grant-agency: dict
#                 abstracts-retrieval-response.item.bibrecord.head.grantlist.grant[0].grant-agency.@iso-code: str = tha
#                 abstracts-retrieval-response.item.bibrecord.head.grantlist.grant[0].grant-agency.$: str = Chulalongkorn University
#               abstracts-retrieval-response.item.bibrecord.head.grantlist.grant[0].grant-agency-id: str = 501100002873
#               abstracts-retrieval-response.item.bibrecord.head.grantlist.grant[1].grant-acronym: str = FWO
#               abstracts-retrieval-response.item.bibrecord.head.grantlist.grant[1].grant-agency: dict
#                 abstracts-retrieval-response.item.bibrecord.head.grantlist.grant[1].grant-agency.@iso-code: str = bel
#                 abstracts-retrieval-response.item.bibrecord.head.grantlist.grant[1].grant-agency.$: str = Fonds Wetenschappelijk Onderzoek
#               abstracts-retrieval-response.item.bibrecord.head.grantlist.grant[1].grant-agency-id: str = 501100003130
#               abstracts-retrieval-response.item.bibrecord.head.grantlist.grant[2].grant-acronym: str = VUB
#               abstracts-retrieval-response.item.bibrecord.head.grantlist.grant[2].grant-agency: dict
#                 abstracts-retrieval-response.item.bibrecord.head.grantlist.grant[2].grant-agency.@iso-code: str = bel
#                 abstracts-retrieval-response.item.bibrecord.head.grantlist.grant[2].grant-agency.$: str = Vrije Universiteit Brussel
#               abstracts-retrieval-response.item.bibrecord.head.grantlist.grant[2].grant-agency-id: str = 501100004418
#               abstracts-retrieval-response.item.bibrecord.head.grantlist.grant[3].grant-id: str = 2017/26/A/ST2/00530
#               abstracts-retrieval-response.item.bibrecord.head.grantlist.grant[3].grant-acronym: str = NCN
#               abstracts-retrieval-response.item.bibrecord.head.grantlist.grant[3].grant-agency: dict
#                 abstracts-retrieval-response.item.bibrecord.head.grantlist.grant[3].grant-agency.@iso-code: str = pol
#                 abstracts-retrieval-response.item.bibrecord.head.grantlist.grant[3].grant-agency.$: str = Narodowe Centrum Nauki
#               abstracts-retrieval-response.item.bibrecord.head.grantlist.grant[3].grant-agency-id: str = 501100004281
#       abstracts-retrieval-response.item.bibrecord.item-info: dict
#         abstracts-retrieval-response.item.bibrecord.item-info.copyright: dict
#           abstracts-retrieval-response.item.bibrecord.item-info.copyright.$: str = Copyright 2020 Elsevier B.V., All rights reserved.
#           abstracts-retrieval-response.item.bibrecord.item-info.copyright.@type: str = Elsevier
#         abstracts-retrieval-response.item.bibrecord.item-info.dbcollection: list
#           abstracts-retrieval-response.item.bibrecord.item-info.dbcollection: List of dict
#             abstracts-retrieval-response.item.bibrecord.item-info.dbcollection[0].$: str = CPX
#             abstracts-retrieval-response.item.bibrecord.item-info.dbcollection[1].$: str = REAXYS
#             abstracts-retrieval-response.item.bibrecord.item-info.dbcollection[2].$: str = REAXYSCAR
#             abstracts-retrieval-response.item.bibrecord.item-info.dbcollection[3].$: str = SCOPUS
#             abstracts-retrieval-response.item.bibrecord.item-info.dbcollection[4].$: str = SNCHEM
#             abstracts-retrieval-response.item.bibrecord.item-info.dbcollection[5].$: str = Scopusbase
#         abstracts-retrieval-response.item.bibrecord.item-info.history: dict
#           abstracts-retrieval-response.item.bibrecord.item-info.history.date-created: dict
#             abstracts-retrieval-response.item.bibrecord.item-info.history.date-created.@day: str = 13
#             abstracts-retrieval-response.item.bibrecord.item-info.history.date-created.@timestamp: str = BST 09:02:31
#             abstracts-retrieval-response.item.bibrecord.item-info.history.date-created.@year: str = 2020
#             abstracts-retrieval-response.item.bibrecord.item-info.history.date-created.@month: str = 10
#         abstracts-retrieval-response.item.bibrecord.item-info.itemidlist: dict
#           abstracts-retrieval-response.item.bibrecord.item-info.itemidlist.itemid: list
#             abstracts-retrieval-response.item.bibrecord.item-info.itemidlist.itemid: List of dict
#               abstracts-retrieval-response.item.bibrecord.item-info.itemidlist.itemid[0].$: str = 2008005677
#               abstracts-retrieval-response.item.bibrecord.item-info.itemidlist.itemid[0].@idtype: str = PUI
#               abstracts-retrieval-response.item.bibrecord.item-info.itemidlist.itemid[1].$: str = 928883753
#               abstracts-retrieval-response.item.bibrecord.item-info.itemidlist.itemid[1].@idtype: str = CAR-ID
#               abstracts-retrieval-response.item.bibrecord.item-info.itemidlist.itemid[2].$: str = 20204109337507
#               abstracts-retrieval-response.item.bibrecord.item-info.itemidlist.itemid[2].@idtype: str = CPX
#               abstracts-retrieval-response.item.bibrecord.item-info.itemidlist.itemid[3].$: str = 2020241431
#               abstracts-retrieval-response.item.bibrecord.item-info.itemidlist.itemid[3].@idtype: str = REAXYS
#               abstracts-retrieval-response.item.bibrecord.item-info.itemidlist.itemid[4].$: str = 20202400913
#               abstracts-retrieval-response.item.bibrecord.item-info.itemidlist.itemid[4].@idtype: str = REAXYSCAR
#               abstracts-retrieval-response.item.bibrecord.item-info.itemidlist.itemid[5].$: str = 20203595263
#               abstracts-retrieval-response.item.bibrecord.item-info.itemidlist.itemid[5].@idtype: str = SCOPUS
#               abstracts-retrieval-response.item.bibrecord.item-info.itemidlist.itemid[6].$: str = 2020022763
#               abstracts-retrieval-response.item.bibrecord.item-info.itemidlist.itemid[6].@idtype: str = SNCHEM
#               abstracts-retrieval-response.item.bibrecord.item-info.itemidlist.itemid[7].$: str = 85092259283
#               abstracts-retrieval-response.item.bibrecord.item-info.itemidlist.itemid[7].@idtype: str = SCP
#               abstracts-retrieval-response.item.bibrecord.item-info.itemidlist.itemid[8].$: str = 85092259283
#               abstracts-retrieval-response.item.bibrecord.item-info.itemidlist.itemid[8].@idtype: str = SGR
#           abstracts-retrieval-response.item.bibrecord.item-info.itemidlist.ce:pii: str = S0375960120307970
#           abstracts-retrieval-response.item.bibrecord.item-info.itemidlist.ce:ern: str = pii:S0375960120307970
#           abstracts-retrieval-response.item.bibrecord.item-info.itemidlist.ce:doi: str = 10.1016/j.physleta.2020.126930
#       abstracts-retrieval-response.item.bibrecord.tail: dict
#         abstracts-retrieval-response.item.bibrecord.tail.bibliography: dict
#           abstracts-retrieval-response.item.bibrecord.tail.bibliography.@refcount: str = 40
#           abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference: list
#             abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference: List of dict
#               abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[0].ref-fulltext: str = Bloch, I., Dalibard, J., Zwerger, W., Many-body physics with ultracold gases. Rev. Mod. Phys., 80, 2008, 885 arXiv:0704.3011 [cond-mat.other].
#               abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[0].@id: str = 1
#               abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[0].ref-info: dict
#                 abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[0].ref-info.ref-publicationyear: dict
#                   abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[0].ref-info.ref-publicationyear.@first: str = 2008
#                 abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[0].ref-info.ref-title: dict
#                   abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[0].ref-info.ref-title.ref-titletext: str = Many-body physics with ultracold gases
#                 abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[0].ref-info.refd-itemidlist: dict
#                   abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[0].ref-info.refd-itemidlist.itemid: list
#                     abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[0].ref-info.refd-itemidlist.itemid: List of dict
#                       abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[0].ref-info.refd-itemidlist.itemid[0].$: str = br0010
#                       abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[0].ref-info.refd-itemidlist.itemid[0].@idtype: str = FRAGMENTID
#                       abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[0].ref-info.refd-itemidlist.itemid[1].$: str = 0704.3011
#                       abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[0].ref-info.refd-itemidlist.itemid[1].@idtype: str = ARXIV
#                       abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[0].ref-info.refd-itemidlist.itemid[2].$: str = 47749140681
#                       abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[0].ref-info.refd-itemidlist.itemid[2].@idtype: str = SGR
#                 abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[0].ref-info.ref-volisspag: dict
#                   abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[0].ref-info.ref-volisspag.voliss: dict
#                     abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[0].ref-info.ref-volisspag.voliss.@volume: str = 80
#                   abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[0].ref-info.ref-volisspag.pagerange: dict
#                     abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[0].ref-info.ref-volisspag.pagerange.@first: str = 885
#                 abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[0].ref-info.ref-authors: dict
#                   abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[0].ref-info.ref-authors.author: list
#                     abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[0].ref-info.ref-authors.author: List of dict
#                       abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[0].ref-info.ref-authors.author[0].@seq: str = 1
#                       abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[0].ref-info.ref-authors.author[0].ce:initials: str = I.
#                       abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[0].ref-info.ref-authors.author[0].@_fa: str = true
#                       abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[0].ref-info.ref-authors.author[0].ce:surname: str = Bloch
#                       abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[0].ref-info.ref-authors.author[0].ce:indexed-name: str = Bloch I.
#                       abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[0].ref-info.ref-authors.author[1].@seq: str = 2
#                       abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[0].ref-info.ref-authors.author[1].ce:initials: str = J.
#                       abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[0].ref-info.ref-authors.author[1].@_fa: str = true
#                       abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[0].ref-info.ref-authors.author[1].ce:surname: str = Dalibard
#                       abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[0].ref-info.ref-authors.author[1].ce:indexed-name: str = Dalibard J.
#                       abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[0].ref-info.ref-authors.author[2].@seq: str = 3
#                       abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[0].ref-info.ref-authors.author[2].ce:initials: str = W.
#                       abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[0].ref-info.ref-authors.author[2].@_fa: str = true
#                       abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[0].ref-info.ref-authors.author[2].ce:surname: str = Zwerger
#                       abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[0].ref-info.ref-authors.author[2].ce:indexed-name: str = Zwerger W.
#                 abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[0].ref-info.ref-sourcetitle: str = Rev. Mod. Phys.
#               abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[0].ce:source-text: str = I. Bloch, J. Dalibard and W. Zwerger, Many-body physics with ultracold gases, Rev. Mod. Phys. 80 (2008) 885 arXiv:0704.3011 [cond-mat.other].
#               abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[1].ref-fulltext: str = Pitaevskii, L.P., Rosch, A., Breathing modes and hidden symmetry of trapped atoms in 2d. Phys. Rev. A, 55, 1997, R835 arXiv:cond-mat/9608135.
#               abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[1].@id: str = 2
#               abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[1].ref-info: dict
#                 abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[1].ref-info.ref-publicationyear: dict
#                   abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[1].ref-info.ref-publicationyear.@first: str = 1997
#                 abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[1].ref-info.ref-title: dict
#                   abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[1].ref-info.ref-title.ref-titletext: str = Breathing modes and hidden symmetry of trapped atoms in 2d
#                 abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[1].ref-info.refd-itemidlist: dict
#                   abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[1].ref-info.refd-itemidlist.itemid: list
#                     abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[1].ref-info.refd-itemidlist.itemid: List of dict
#                       abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[1].ref-info.refd-itemidlist.itemid[0].$: str = br0020
#                       abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[1].ref-info.refd-itemidlist.itemid[0].@idtype: str = FRAGMENTID
#                       abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[1].ref-info.refd-itemidlist.itemid[1].$: str = cond-mat/9608135
#                       abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[1].ref-info.refd-itemidlist.itemid[1].@idtype: str = ARXIV
#                       abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[1].ref-info.refd-itemidlist.itemid[2].$: str = 0000953119
#                       abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[1].ref-info.refd-itemidlist.itemid[2].@idtype: str = SGR
#                 abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[1].ref-info.ref-volisspag: dict
# ...
#                     abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[39].ref-info.ref-volisspag.pagerange.@first: str = 181
#                 abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[39].ref-info.ref-authors: dict
#                   abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[39].ref-info.ref-authors.author: list
#                     abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[39].ref-info.ref-authors.author: List of dict
#                       abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[39].ref-info.ref-authors.author[0].@seq: str = 1
#                       abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[39].ref-info.ref-authors.author[0].ce:initials: str = D.
#                       abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[39].ref-info.ref-authors.author[0].@_fa: str = true
#                       abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[39].ref-info.ref-authors.author[0].ce:surname: str = Dai
#                       abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[39].ref-info.ref-authors.author[0].ce:indexed-name: str = Dai D.
#                       abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[39].ref-info.ref-authors.author[1].@seq: str = 2
#                       abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[39].ref-info.ref-authors.author[1].ce:initials: str = R.
#                       abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[39].ref-info.ref-authors.author[1].@_fa: str = true
#                       abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[39].ref-info.ref-authors.author[1].ce:surname: str = Wong
#                       abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[39].ref-info.ref-authors.author[1].ce:indexed-name: str = Wong R.
#                 abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[39].ref-info.ref-sourcetitle: str = Ramanujan J.
#               abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[39].ce:source-text: str = D. Dai and R. Wong, Global asymptotics for Laguerre polynomials with large negative parameter–a Riemann-Hilbert approach, Ramanujan J. 16 (2008) 181.
#   abstracts-retrieval-response.affiliation: list
#     abstracts-retrieval-response.affiliation: List of dict
#       abstracts-retrieval-response.affiliation[0].affiliation-city: str = Brussels
#       abstracts-retrieval-response.affiliation[0].@id: str = 60070009
#       abstracts-retrieval-response.affiliation[0].affilname: str = International Solvay Institute for Physics and Chemistry
#       abstracts-retrieval-response.affiliation[0].@href: str = https://api.elsevier.com/content/affiliation/affiliation_id/60070009
#       abstracts-retrieval-response.affiliation[0].affiliation-country: str = Belgium
#       abstracts-retrieval-response.affiliation[1].affiliation-city: str = Bangkok
#       abstracts-retrieval-response.affiliation[1].@id: str = 60028190
#       abstracts-retrieval-response.affiliation[1].affilname: str = Chulalongkorn University
#       abstracts-retrieval-response.affiliation[1].@href: str = https://api.elsevier.com/content/affiliation/affiliation_id/60028190
#       abstracts-retrieval-response.affiliation[1].affiliation-country: str = Thailand
#   abstracts-retrieval-response.coredata: dict
#     abstracts-retrieval-response.coredata.srctype: str = j
#     abstracts-retrieval-response.coredata.eid: str = 2-s2.0-85092259283
#     abstracts-retrieval-response.coredata.dc:description: str = We consider quantum bosons with contact interactions at the Lowest Landau Level (LLL) of a two-dimensional isotropic harmonic trap. At linear order in the coupling parameter g, we construct a large, explicit family of quantum states with energies of the form E0+gE1/4+O(g2), where E0 and E1 are integers. Any superposition of these states evolves periodically with a period of 8π/g until, at much longer time scales of order 1/g2, corrections to the energies of order g2 may become relevant. These quantum states provide a counterpart to the known time-periodic behaviors of the corresponding classical (mean field) theory.
#     abstracts-retrieval-response.coredata.prism:coverDate: str = 2020-12-30
#     abstracts-retrieval-response.coredata.prism:aggregationType: str = Journal
#     abstracts-retrieval-response.coredata.prism:url: str = https://api.elsevier.com/content/abstract/scopus_id/85092259283
#     abstracts-retrieval-response.coredata.dc:creator: dict
#       abstracts-retrieval-response.coredata.dc:creator.author: list
#         abstracts-retrieval-response.coredata.dc:creator.author: List of dict
#           abstracts-retrieval-response.coredata.dc:creator.author[0].ce:given-name: str = Marine
#           abstracts-retrieval-response.coredata.dc:creator.author[0].preferred-name: dict
#             abstracts-retrieval-response.coredata.dc:creator.author[0].preferred-name.ce:given-name: str = Marine
#             abstracts-retrieval-response.coredata.dc:creator.author[0].preferred-name.ce:initials: str = M.
#             abstracts-retrieval-response.coredata.dc:creator.author[0].preferred-name.ce:surname: str = De Clerck
#             abstracts-retrieval-response.coredata.dc:creator.author[0].preferred-name.ce:indexed-name: str = De Clerck M.
#           abstracts-retrieval-response.coredata.dc:creator.author[0].@seq: str = 1
#           abstracts-retrieval-response.coredata.dc:creator.author[0].ce:initials: str = M.
#           abstracts-retrieval-response.coredata.dc:creator.author[0].@_fa: str = true
#           abstracts-retrieval-response.coredata.dc:creator.author[0].affiliation: dict
#             abstracts-retrieval-response.coredata.dc:creator.author[0].affiliation.@id: str = 60070009
#             abstracts-retrieval-response.coredata.dc:creator.author[0].affiliation.@href: str = https://api.elsevier.com/content/affiliation/affiliation_id/60070009
#           abstracts-retrieval-response.coredata.dc:creator.author[0].ce:surname: str = De Clerck
#           abstracts-retrieval-response.coredata.dc:creator.author[0].@auid: str = 57210392338
#           abstracts-retrieval-response.coredata.dc:creator.author[0].author-url: str = https://api.elsevier.com/content/author/author_id/57210392338
#           abstracts-retrieval-response.coredata.dc:creator.author[0].ce:indexed-name: str = De Clerck M.
#     abstracts-retrieval-response.coredata.link: list
#       abstracts-retrieval-response.coredata.link: List of dict
#         abstracts-retrieval-response.coredata.link[0].@_fa: str = true
#         abstracts-retrieval-response.coredata.link[0].@rel: str = self
#         abstracts-retrieval-response.coredata.link[0].@href: str = https://api.elsevier.com/content/abstract/scopus_id/85092259283
#         abstracts-retrieval-response.coredata.link[1].@_fa: str = true
#         abstracts-retrieval-response.coredata.link[1].@rel: str = scopus
#         abstracts-retrieval-response.coredata.link[1].@href: str = https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85092259283&origin=inward
#         abstracts-retrieval-response.coredata.link[2].@_fa: str = true
#         abstracts-retrieval-response.coredata.link[2].@rel: str = scopus-citedby
#         abstracts-retrieval-response.coredata.link[2].@href: str = https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85092259283&origin=inward
#     abstracts-retrieval-response.coredata.source-id: str = 29464
#     abstracts-retrieval-response.coredata.pii: str = S0375960120307970
#     abstracts-retrieval-response.coredata.citedby-count: str = 6
#     abstracts-retrieval-response.coredata.prism:volume: str = 384
#     abstracts-retrieval-response.coredata.subtype: str = ar
#     abstracts-retrieval-response.coredata.dc:title: str = Time-periodic quantum states of weakly interacting bosons in a harmonic trap
#     abstracts-retrieval-response.coredata.openaccess: str = 1
#     abstracts-retrieval-response.coredata.prism:issn: str = 03759601
#     abstracts-retrieval-response.coredata.publishercopyright: str = © 2020 Elsevier B.V.
#     abstracts-retrieval-response.coredata.article-number: str = 126930
#     abstracts-retrieval-response.coredata.prism:issueIdentifier: str = 36
#     abstracts-retrieval-response.coredata.subtypeDescription: str = Article
#     abstracts-retrieval-response.coredata.prism:publicationName: str = Physics Letters, Section A: General, Atomic and Solid State Physics
#     abstracts-retrieval-response.coredata.openaccessFlag: str = true
#     abstracts-retrieval-response.coredata.prism:doi: str = 10.1016/j.physleta.2020.126930
#     abstracts-retrieval-response.coredata.dc:identifier: str = SCOPUS_ID:85092259283
#     abstracts-retrieval-response.coredata.dc:publisher: str = Elsevier B.V.
#   abstracts-retrieval-response.idxterms: dict
#     abstracts-retrieval-response.idxterms.mainterm: list
#       abstracts-retrieval-response.idxterms.mainterm: List of dict
#         abstracts-retrieval-response.idxterms.mainterm[0].$: str = Contact interaction
#         abstracts-retrieval-response.idxterms.mainterm[0].@weight: str = b
#         abstracts-retrieval-response.idxterms.mainterm[0].@candidate: str = n
#         abstracts-retrieval-response.idxterms.mainterm[1].$: str = Coupling parameters
#         abstracts-retrieval-response.idxterms.mainterm[1].@weight: str = b
#         abstracts-retrieval-response.idxterms.mainterm[1].@candidate: str = n
#         abstracts-retrieval-response.idxterms.mainterm[2].$: str = Harmonic trap
#         abstracts-retrieval-response.idxterms.mainterm[2].@weight: str = b
#         abstracts-retrieval-response.idxterms.mainterm[2].@candidate: str = n
#         abstracts-retrieval-response.idxterms.mainterm[3].$: str = Interacting bosons
#         abstracts-retrieval-response.idxterms.mainterm[3].@weight: str = b
#         abstracts-retrieval-response.idxterms.mainterm[3].@candidate: str = n
#         abstracts-retrieval-response.idxterms.mainterm[4].$: str = Landau levels
#         abstracts-retrieval-response.idxterms.mainterm[4].@weight: str = b
#         abstracts-retrieval-response.idxterms.mainterm[4].@candidate: str = n
#         abstracts-retrieval-response.idxterms.mainterm[5].$: str = Linear order
#         abstracts-retrieval-response.idxterms.mainterm[5].@weight: str = b
#         abstracts-retrieval-response.idxterms.mainterm[5].@candidate: str = n
#         abstracts-retrieval-response.idxterms.mainterm[6].$: str = Periodic behavior
#         abstracts-retrieval-response.idxterms.mainterm[6].@weight: str = b
#         abstracts-retrieval-response.idxterms.mainterm[6].@candidate: str = n
#         abstracts-retrieval-response.idxterms.mainterm[7].$: str = Quantum state
#         abstracts-retrieval-response.idxterms.mainterm[7].@weight: str = b
#         abstracts-retrieval-response.idxterms.mainterm[7].@candidate: str = n
#   abstracts-retrieval-response.language: dict
#     abstracts-retrieval-response.language.@xml:lang: str = eng
#   abstracts-retrieval-response.authkeywords: dict
#     abstracts-retrieval-response.authkeywords.author-keyword: list
#       abstracts-retrieval-response.authkeywords.author-keyword: List of dict
#         abstracts-retrieval-response.authkeywords.author-keyword[0].@_fa: str = true
#         abstracts-retrieval-response.authkeywords.author-keyword[0].$: str = Bose-Einstein condensates
#         abstracts-retrieval-response.authkeywords.author-keyword[1].@_fa: str = true
#         abstracts-retrieval-response.authkeywords.author-keyword[1].$: str = Breathers
#         abstracts-retrieval-response.authkeywords.author-keyword[2].@_fa: str = true
#         abstracts-retrieval-response.authkeywords.author-keyword[2].$: str = Matter waves
#         abstracts-retrieval-response.authkeywords.author-keyword[3].@_fa: str = true
#         abstracts-retrieval-response.authkeywords.author-keyword[3].$: str = Nonlinear waves
#   abstracts-retrieval-response.subject-areas: dict
#     abstracts-retrieval-response.subject-areas.subject-area: list
#       abstracts-retrieval-response.subject-areas.subject-area: List of dict
#         abstracts-retrieval-response.subject-areas.subject-area[0].@_fa: str = true
#         abstracts-retrieval-response.subject-areas.subject-area[0].$: str = Physics and Astronomy (all)
#         abstracts-retrieval-response.subject-areas.subject-area[0].@code: str = 3100
#         abstracts-retrieval-response.subject-areas.subject-area[0].@abbrev: str = PHYS
#   abstracts-retrieval-response.authors: dict
#     abstracts-retrieval-response.authors.author: list
#       abstracts-retrieval-response.authors.author: List of dict
#         abstracts-retrieval-response.authors.author[0].ce:given-name: str = Marine
#         abstracts-retrieval-response.authors.author[0].preferred-name: dict
#           abstracts-retrieval-response.authors.author[0].preferred-name.ce:given-name: str = Marine
#           abstracts-retrieval-response.authors.author[0].preferred-name.ce:initials: str = M.
#           abstracts-retrieval-response.authors.author[0].preferred-name.ce:surname: str = De Clerck
#           abstracts-retrieval-response.authors.author[0].preferred-name.ce:indexed-name: str = De Clerck M.
#         abstracts-retrieval-response.authors.author[0].@seq: str = 1
#         abstracts-retrieval-response.authors.author[0].ce:initials: str = M.
#         abstracts-retrieval-response.authors.author[0].@_fa: str = true
#         abstracts-retrieval-response.authors.author[0].affiliation: dict
#           abstracts-retrieval-response.authors.author[0].affiliation.@id: str = 60070009
#           abstracts-retrieval-response.authors.author[0].affiliation.@href: str = https://api.elsevier.com/content/affiliation/affiliation_id/60070009
#         abstracts-retrieval-response.authors.author[0].ce:surname: str = De Clerck
#         abstracts-retrieval-response.authors.author[0].@auid: str = 57210392338
#         abstracts-retrieval-response.authors.author[0].author-url: str = https://api.elsevier.com/content/author/author_id/57210392338
#         abstracts-retrieval-response.authors.author[0].ce:indexed-name: str = De Clerck M.
#         abstracts-retrieval-response.authors.author[1].ce:given-name: str = Oleg
#         abstracts-retrieval-response.authors.author[1].preferred-name: dict
#           abstracts-retrieval-response.authors.author[1].preferred-name.ce:given-name: str = Oleg
#           abstracts-retrieval-response.authors.author[1].preferred-name.ce:initials: str = O.
#           abstracts-retrieval-response.authors.author[1].preferred-name.ce:surname: str = Evnin
#           abstracts-retrieval-response.authors.author[1].preferred-name.ce:indexed-name: str = Evnin O.
#         abstracts-retrieval-response.authors.author[1].@seq: str = 2
#         abstracts-retrieval-response.authors.author[1].ce:initials: str = O.
#         abstracts-retrieval-response.authors.author[1].@_fa: str = true
#         abstracts-retrieval-response.authors.author[1].affiliation: list
#           abstracts-retrieval-response.authors.author[1].affiliation: List of dict
#             abstracts-retrieval-response.authors.author[1].affiliation[0].@id: str = 60070009
#             abstracts-retrieval-response.authors.author[1].affiliation[0].@href: str = https://api.elsevier.com/content/affiliation/affiliation_id/60070009
#             abstracts-retrieval-response.authors.author[1].affiliation[1].@id: str = 60028190
#             abstracts-retrieval-response.authors.author[1].affiliation[1].@href: str = https://api.elsevier.com/content/affiliation/affiliation_id/60028190
#         abstracts-retrieval-response.authors.author[1].ce:surname: str = Evnin
#         abstracts-retrieval-response.authors.author[1].@auid: str = 15761759100
#         abstracts-retrieval-response.authors.author[1].author-url: str = https://api.elsevier.com/content/author/author_id/15761759100
#         abstracts-retrieval-response.authors.author[1].ce:indexed-name: str = Evnin O.

# %% [markdown]
# ## Get classification of enhancement

# %%
def extract_classifications(json_file):
    global enhancement_count_error_files, enhancement_count_files
    with open(json_file, 'r', encoding='utf-8') as f:
        data = json.load(f)
    
    classifications = data.get('abstracts-retrieval-response', {}).get('item', {}).get('bibrecord', {}).get('head', {}).get('enhancement', {}).get('classificationgroup', {}).get('classifications', [])
    
    records = []
    for classification in classifications:
        classification_type = classification.get('@type', '')
        classification_data = classification.get('classification', {})
        
        if isinstance(classification_data, list):
            for cls in classification_data:
                record = {
                    'file': Path(json_file).name,
                    'type': classification_type,
                    'classification': cls.get('$', ''),
                    'classification_code': cls.get('classification-code', ''),
                    'classification_description': cls.get('classification-description', ''),
                }
                records.append(record)
        elif isinstance(classification_data, dict):
            record = {
                'file': Path(json_file).name,
                'type': classification_type,
                'classification': classification_data.get('$', classification_data.get('classification', '')),
                'classification_code': classification_data.get('classification-code', ''),
                'classification_description': classification_data.get('classification-description', ''),
            }
            records.append(record)
        else:
            # Handle cases where 'classification' is neither dict nor list
            record = {
                'file': Path(json_file).name,
                'type': classification_type,
                'classification': classification.get('classification', ''),
                'classification_code': classification.get('classification-code', ''),
                'classification_description': classification.get('classification-description', ''),
            }
            records.append(record)
    
    return records

def process_json_folders(root_folder_path):
    global enhancement_count_error_files, enhancement_count_files
    all_records = []
    root_path = Path(root_folder_path)
    
    for json_file in root_path.rglob('*.json'):
        try:
            enhancement_count_files += 1
            records = extract_classifications(json_file)
            all_records.extend(records)
        except Exception as e:
            print(f"Error processing {json_file}: {e}")
            enhancement_count_error_files += 1
    
    if all_records:
        df = pd.DataFrame(all_records)
        df.to_csv('classification_enhancement/classifications_separated.csv', index=False, encoding='utf-8')
        print(f"Classifications saved to classifications_separated.csv")
        print(f"Records processed with errors: {enhancement_count_error_files} from {enhancement_count_files} files")
        print(f"Approximate error: {enhancement_count_error_files / enhancement_count_files * 100:.2f}%")
    else:
        print("No records found to save.")

# Process JSON folders
enhancement_count_files = 0
enhancement_count_error_files = 0
process_json_folders(raw_data_root_path)
# Out:
# Classifications saved to classifications_separated.csv
# Records processed with errors: 0 from 20216 files
# Approximate error: 0.00%

# %% [markdown]
# ### Narrowing down the classifications

# %%
df_classifications = pd.read_csv('classification_enhancement/classifications_separated.csv')
df_classifications.describe(include='all')
# Out:
#                   file    type classification classification_code  \
# count           145669  145669          85921               59748
# unique           20216       8            348                1735
# top     202202738.json    ASJC           MEDI                 902
# freq                29   50064           5639                4290
#
#        classification_description
# count                       59748
# unique                       1751
# top       FLUIDEX; Related Topics
# freq                         4290

# %%
shape_df_classifications = df_classifications.shape
columns_df_classifications = df_classifications.columns
print('Shape:', shape_df_classifications)
print('Columns:', columns_df_classifications)
# Out:
# Shape: (145669, 5)
# Columns: Index(['file', 'type', 'classification', 'classification_code',
#        'classification_description'],
#       dtype='object')

# %%
df_classifications.head(5)
# Out:
#              file      type classification classification_code  \
# 0  201800000.json      ASJC           2700                 NaN
# 1  201800000.json  SUBJABBR           MEDI                 NaN
# 2  201800001.json      ASJC           2208                 NaN
# 3  201800001.json      ASJC           2504                 NaN
# 4  201800001.json  CPXCLASS            NaN                 402
#
#   classification_description
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4       Buildings and Towers

# %% [markdown]
# ### Classification Description

# %%
df_classifications_by_descriptions = df_classifications.drop(columns=['type','file','classification_code'])
df_classifications_by_descriptions.head(5)
# Out:
#   classification classification_description
# 0           2700                        NaN
# 1           MEDI                        NaN
# 2           2208                        NaN
# 3           2504                        NaN
# 4            NaN       Buildings and Towers

# %%
df_classifications_by_descriptions['classification_description'].fillna(df_classifications_by_descriptions['classification'], inplace=True)
df_classifications_by_descriptions.head(5)
# Out:
# C:\Users\Yiwahpsp\AppData\Local\Temp\ipykernel_60804\3666764428.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_classifications_by_descriptions['classification_description'].fillna(df_classifications_by_descriptions['classification'], inplace=True)
#   classification classification_description
# 0           2700                       2700
# 1           MEDI                       MEDI
# 2           2208                       2208
# 3           2504                       2504
# 4            NaN       Buildings and Towers

# %%
df_classifications_by_descriptions['classification_description'].isnull().sum()
df_classifications_by_descriptions.drop(columns=['classification'], inplace=True)

# %%
df_classifications_by_descriptions.head(5)
# Out:
#   classification_description
# 0                       2700
# 1                       MEDI
# 2                       2208
# 3                       2504
# 4       Buildings and Towers

# %%
df_classifications_by_descriptions['classification_description'] = df_classifications_by_descriptions['classification_description'].apply(lambda x: '; '.join(x.split('; ')[:1]))
df_classifications_by_descriptions = df_classifications_by_descriptions.groupby(['classification_description']).size().reset_index(name='Count')
df_classifications_by_descriptions.head(5)
# Out:
#   classification_description  Count
# 0                       1000   1088
# 1                       1100    229
# 2                       1101    123
# 3                       1102    137
# 4                       1103    362

# %%
df_classifications_by_descriptions.sort_values(by='Count', ascending=False, inplace=True)
df_classifications_by_descriptions.head(10)
# Out:
#                  classification_description  Count
# 838                                    MEDI   5639
# 659                                 FLUIDEX   4290
# 564                                    ENGI   2994
# 554                   Drug Literature Index   2752
# 393                                    BIOC   2436
# 465  Clinical and Experimental Biochemistry   2316
# 427                                    CHEM   2161
# 990                                    PHYS   2072
# 836                                    MATE   1988
# 323                                    AGRI   1901

# %%
shape_df_classifications_by_descriptions = df_classifications_by_descriptions.shape
columns_df_classifications_by_descriptions = df_classifications_by_descriptions.columns
print('Shape:', shape_df_classifications_by_descriptions)
print('Columns:', columns_df_classifications_by_descriptions)
# Out:
# Shape: (1314, 2)
# Columns: Index(['classification_description', 'Count'], dtype='object')

# %%
df_classifications_by_descriptions.to_csv('classification_enhancement/classifications_by_description.csv', index=False, encoding='utf-8')

# %% [markdown]
# ### Classification type

# %%
df_classifications_groupby_type = df_classifications.drop(columns=['classification_code','classification_description','classification'])
df_classifications_groupby_type.describe(include='all')
# Out:
#                   file    type
# count           145669  145669
# unique           20216       8
# top     202202738.json    ASJC
# freq                29   50064

# %%
df_classifications_groupby_type = df_classifications_groupby_type.groupby('type').count().reset_index()
df_classifications_groupby_type.rename(columns={df_classifications_groupby_type.columns[1]: 'count'}, inplace=True)
df_classifications_groupby_type.drop_duplicates(inplace=True)
df_classifications_groupby_type.sort_values(by='count', inplace=True)
df_classifications_groupby_type.head(5)
# Out:
#              type  count
# 4  ENCOMPASSCLASS   1075
# 6        GEOCLASS   1828
# 1       CABSCLASS   3224
# 5        FLXCLASS   5935
# 3         EMCLASS  18629

# %%
df_classifications_groupby_type.drop_duplicates(inplace=True)

# %%
shape_df_classifications_groupby_type = df_classifications_groupby_type.shape
columns_df_classifications_groupby_type = df_classifications_groupby_type.columns
print('Shape:', shape_df_classifications_groupby_type)
print('Columns:', columns_df_classifications_groupby_type)
# Out:
# Shape: (8, 2)
# Columns: Index(['type', 'count'], dtype='object')

# %%
df_classifications_groupby_type.to_csv('classification_enhancement/classifications_by_type.csv', index=False, encoding='utf-8')

# %% [markdown]
# ### Classification type and descriptions

# %%
df_classifications_by_type_and_descriptions = df_classifications.drop(columns=['file','classification_code'])
df_classifications_by_type_and_descriptions.describe(include='all')
# Out:
#           type classification classification_description
# count   145669          85921                      59748
# unique       8            348                       1751
# top       ASJC           MEDI    FLUIDEX; Related Topics
# freq     50064           5639                       4290

# %%
df_classifications_by_type_and_descriptions['classification_description'].fillna(df_classifications_by_type_and_descriptions['classification'], inplace=True)
df_classifications_by_type_and_descriptions.head(5)
# Out:
# C:\Users\Yiwahpsp\AppData\Local\Temp\ipykernel_60804\33182461.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_classifications_by_type_and_descriptions['classification_description'].fillna(df_classifications_by_type_and_descriptions['classification'], inplace=True)
#        type classification classification_description
# 0      ASJC           2700                       2700
# 1  SUBJABBR           MEDI                       MEDI
# 2      ASJC           2208                       2208
# 3      ASJC           2504                       2504
# 4  CPXCLASS            NaN       Buildings and Towers

# %%
df_classifications_by_type_and_descriptions['classification_description'].isnull().sum()
df_classifications_by_type_and_descriptions.drop(columns=['classification'], inplace=True)
df_classifications_by_type_and_descriptions.head(5)
# Out:
#        type classification_description
# 0      ASJC                       2700
# 1  SUBJABBR                       MEDI
# 2      ASJC                       2208
# 3      ASJC                       2504
# 4  CPXCLASS       Buildings and Towers

# %%
df_classifications_by_type_and_descriptions['classification_description'] = df_classifications_by_type_and_descriptions['classification_description'].apply(lambda x: '; '.join(x.split('; ')[:1]))
df_classifications_by_type_and_descriptions.head(10)
# Out:
#        type                         classification_description
# 0      ASJC                                               2700
# 1  SUBJABBR                                               MEDI
# 2      ASJC                                               2208
# 3      ASJC                                               2504
# 4  CPXCLASS                               Buildings and Towers
# 5  CPXCLASS      Semiconductor Devices and Integrated Circuits
# 6  CPXCLASS  Electronic Equipment, Radar, Radio and Television
# 7  CPXCLASS                   Television Systems and Equipment
# 8  CPXCLASS  Computer Software, Data Handling and Applications
# 9  CPXCLASS                                   Organic Polymers

# %%
df_classifications_by_type_and_descriptions = df_classifications_by_type_and_descriptions.groupby(['type', 'classification_description']).size().reset_index(name='Count')
df_classifications_by_type_and_descriptions.sort_values(by='Count', ascending=False, inplace=True)
df_classifications_by_type_and_descriptions.head(10)
# Out:
#           type              classification_description  Count
# 1312  SUBJABBR                                    MEDI   5639
# 1014  FLXCLASS                                 FLUIDEX   4290
# 1306  SUBJABBR                                    ENGI   2994
# 971    EMCLASS                   Drug Literature Index   2752
# 1296  SUBJABBR                                    BIOC   2436
# 966    EMCLASS  Clinical and Experimental Biochemistry   2316
# 1299  SUBJABBR                                    CHEM   2161
# 1317  SUBJABBR                                    PHYS   2072
# 1310  SUBJABBR                                    MATE   1988
# 1294  SUBJABBR                                    AGRI   1901

# %%
shape_df_classifications_by_type_and_descriptions = df_classifications_by_type_and_descriptions.shape
columns_df_classifications_by_type_and_descriptions = df_classifications_by_type_and_descriptions.columns
print('Shape:', shape_df_classifications_by_type_and_descriptions)
print('Columns:', columns_df_classifications_by_type_and_descriptions)
# Out:
# Shape: (1321, 3)
# Columns: Index(['type', 'classification_description', 'Count'], dtype='object')

# %%
df_classifications_by_type_and_descriptions.to_csv('classification_enhancement/classifications_by_type_and_description.csv', index=False, encoding='utf-8')

# %% [markdown]
# ## Get authkeywords

# %%
def extract_author_keywords(json_file):
    """Extract author keywords from JSON file"""
    global author_keywords_count_files, author_keywords_count_error_files
    with open(json_file, 'r', encoding='utf-8') as f:
        data = json.load(f)
    
    records = []
    
    # Check if path exists and has data
    auth_data = data.get('abstracts-retrieval-response', {})
    keywords_data = auth_data.get('authkeywords')
    
    if keywords_data is not None:
        # Process keywords only if data exists
        keywords_list = keywords_data.get('author-keyword', [])
        
        if isinstance(keywords_list, dict):
            keywords_list = [keywords_list]
        
        for keyword in keywords_list:
            record = {
                'file': Path(json_file).name,
                'auth_keyword': keyword.get('$', '')
            }
            records.append(record)
    else:
        print(f"No authkeywords found in {json_file}")
        author_keywords_count_error_files += 1
    
    return records
def process_json_folders(root_folder_path):
    """Process all JSON files in root folder and subfolders."""
    global author_keywords_count_files, author_keywords_count_error_files
    all_records = []
    root_path = Path(root_folder_path)
    
    # Create output directory if it doesn't exist
    output_dir = Path('author_keywords')
    output_dir.mkdir(exist_ok=True)
    
    # Process each JSON file
    for json_file in root_path.rglob('*.json'):
        try:
            author_keywords_count_files += 1
            records = extract_author_keywords(json_file)
            all_records.extend(records)  # Add records to the main list
        except Exception as e:
            print(f"Error processing {json_file}: {e}")
            author_keywords_count_error_files += 1
    
    if all_records:
        # Convert to DataFrame
        df = pd.DataFrame(all_records)
        # Save to CSV
        output_csv_path = output_dir / 'author_keywords_separate.csv'
        df.to_csv(output_csv_path, index=False, encoding='utf-8')
        print(f"Author keywords saved to {output_csv_path}")
        print(f"Total records processed: {len(all_records)}")
        print(f"Records processed with errors: {author_keywords_count_error_files} from {author_keywords_count_files}")
    else:
        print("No records found to save.")

# Usage
author_keywords_count_error_files = 0
author_keywords_count_files = 0
# No authkeywords found in raw-data\2023\202302588.json
# No authkeywords found in raw-data\2023\202302589.json
# No authkeywords found in raw-data\2023\202302590.json
# No authkeywords found in raw-data\2023\202302591.json
# No authkeywords found in raw-data\2023\202302592.json
# No authkeywords found in raw-data\2023\202302593.json
# No authkeywords found in raw-data\2023\202302594.json
# No authkeywords found in raw-data\2023\202302595.json
# No authkeywords found in raw-data\2023\202302596.json
# No authkeywords found in raw-data\2023\202302597.json
# No authkeywords found in raw-data\2023\202302598.json
# No authkeywords found in raw-data\2023\202302624.json
# No authkeywords found in raw-data\2023\202302626.json
# No authkeywords found in raw-data\2023\202302627.json
# No authkeywords found in raw-data\2023\202302628.json
# No authkeywords found in raw-data\2023\202302629.json
# No authkeywords found in raw-data\2023\202302678.json
# No authkeywords found in raw-data\2023\202302685.json
# No authkeywords found in raw-data\2023\202302687.json
# No authkeywords found in raw-data\2023\202302688.json
# No authkeywords found in raw-data\2023\202302694.json
# No authkeywords found in raw-data\2023\202302696.json
# No authkeywords found in raw-data\2023\202302699.json
# No authkeywords found in raw-data\2023\202302702.json
# No authkeywords found in raw-data\2023\202302703.json
# No authkeywords found in raw-data\2023\202302729.json
# No authkeywords found in raw-data\2023\202302732.json
# No authkeywords found in raw-data\2023\202302737.json
# No authkeywords found in raw-data\2023\202302742.json
# No authkeywords found in raw-data\2023\202302761.json
# No authkeywords found in raw-data\2023\202302774.json
# No authkeywords found in raw-data\2023\202302775.json
# No authkeywords found in raw-data\2023\202302776.json
# No authkeywords found in raw-data\2023\202302777.json
# No authkeywords found in raw-data\2023\202302778.json
# No authkeywords found in raw-data\2023\202302779.json
# No authkeywords found in raw-data\2023\202302780.json
# No authkeywords found in raw-data\2023\202302807.json
# No authkeywords found in raw-data\2023\202302826.json
# No authkeywords found in raw-data\2023\202302830.json
# No authkeywords found in raw-data\2023\202302869.json
# Author keywords saved to author_keywords\author_keywords_separate.csv
# Total records processed: 83074
# Records processed with errors: 3762 from 20216

# %% [markdown]
# - Total records processed: 83074
# - Records processed with errors: 3762 from 20216 files. Approximate 18.61 %

# %%
df_author_keywords = pd.read_csv('author_keywords/author_keywords_separate.csv')
df_author_keywords.describe(include='all')
# Out:
#                   file auth_keyword
# count            83074        83073
# unique           16454        51856
# top     202300390.json     Thailand
# freq                30          746

# %%
df_author_keywords.shape
# Out:
# (83073, 2)

# %%
df_author_keywords.dropna(inplace=True)

# %%
author_keywords_groupby_keys = (df_author_keywords.groupby('auth_keyword').size().reset_index(name='Count').sort_values(by='Count', ascending=False))
author_keywords_groupby_keys.head(10)
# Out:
#                                  auth_keyword  Count
# 33471                                Thailand    746
# 4800                                 COVID-19    282
# 14706  Hadron-Hadron scattering (experiments)    155
# 16845                            Inflammation    130
# 29238                              SARS-CoV-2    115
# 14555                                     HIV    114
# 4687                                      CMS     98
# 24119                        Oxidative stress     83
# 2491                                     Asia     81
# 19691                        Machine learning     78

# %%
author_keywords_groupby_keys.to_csv('author_keywords/author_keywords_groupby_keys.csv', index=False, encoding='utf-8')

# %% [markdown]
# ## Get Links from core data

# %%
def extract_links(json_file):
    """Extract links from JSON file"""
    global link_count_files, link_count_error_files
    with open(json_file, 'r', encoding='utf-8') as f:
        data = json.load(f)
    
    records = []
    
    # Navigate to links section
    title = (data.get('abstracts-retrieval-response', {})
            .get('coredata', {})
            .get('dc:title',{}))
    links = (data.get('abstracts-retrieval-response', {})
            .get('coredata', {})
            .get('link', []))
    
    # Process each link
    for link in links:
        record = {
            'file': title,
            'fa': link.get('@_fa', ''),
            'rel_type': link.get('@rel', ''),
            'href': link.get('@href', '')
        }
        records.append(record)
    
    return records

def process_json_folders(root_folder_path):
    """Process all JSON files in root folder and subfolders"""
    global link_count_files, link_count_error_files
    all_records = []
    root_path = Path(root_folder_path)
    
    # Create output directory
    Path('links').mkdir(exist_ok=True)
    
    # Process each JSON file
    for json_file in root_path.rglob('*.json'):
        try:
            link_count_files += 1
            records = extract_links(json_file)
            all_records.extend(records)
        except Exception as e:
            print(f"Error processing {json_file}: {e}")
    
    if all_records:
        df = pd.DataFrame(all_records)
        output_file = 'links/links_separate.csv'
        df.to_csv(output_file, index=False, encoding='utf-8')
        print(f"Processed {len(all_records)} links to {output_file}")
        print(f"Records processed with errors: {link_count_error_files} from {link_count_files} files")
        print(f"Approximate error: {link_count_error_files / link_count_files * 100:.2f}%")
    else:
        print("No links found")
        link_count_error_files += 1

# Usage
link_count_files = 0
link_count_error_files = 0
process_json_folders(raw_data_root_path)
# Out:
# Processed 60648 links to links/links_separate.csv
# Records processed with errors: 0 from 20216 files
# Approximate error: 0.00%

# %%
df_links = pd.read_csv('links/links_separate.csv')
df_links.describe(include='all')
# Out:
#            file     fa rel_type  \
# count     60648  60648    60648
# unique    20141      1        3
# top     Preface   True     self
# freq         54  60648    20216
#
#                                                      href
# count                                               60648
# unique                                              60648
# top     https://api.elsevier.com/content/abstract/scop...
# freq                                                    1

# %%
df_links.drop(columns=['fa'], inplace=True)

# %%
shape_df_links = df_links.shape
columns_df_links = df_links.columns
print('Shape:', shape_df_links)
print('Columns:', columns_df_links)
# Out:
# Shape: (60648, 3)
# Columns: Index(['file', 'rel_type', 'href'], dtype='object')

# %%
df_links = df_links.drop_duplicates()
df_links.head(10)
# Out:
#                                                 file        rel_type  \
# 0  Public health and international epidemiology f...            self
# 1  Public health and international epidemiology f...          scopus
# 2  Public health and international epidemiology f...  scopus-citedby
# 3  Flexible Printed Active Antenna for Digital Te...            self
# 4  Flexible Printed Active Antenna for Digital Te...          scopus
# 5  Flexible Printed Active Antenna for Digital Te...  scopus-citedby
# 6  Parametric study of hydrogen production via so...            self
# 7  Parametric study of hydrogen production via so...          scopus
# 8  Parametric study of hydrogen production via so...  scopus-citedby
# 9  Superhydrophobic coating from fluoroalkylsilan...            self
#
#                                                 href
# 0  https://api.elsevier.com/content/abstract/scop...
# 1  https://www.scopus.com/inward/record.uri?partn...
# 2  https://www.scopus.com/inward/citedby.uri?part...
# 3  https://api.elsevier.com/content/abstract/scop...
# 4  https://www.scopus.com/inward/record.uri?partn...
# 5  https://www.scopus.com/inward/citedby.uri?part...
# 6  https://api.elsevier.com/content/abstract/scop...
# 7  https://www.scopus.com/inward/record.uri?partn...
# 8  https://www.scopus.com/inward/citedby.uri?part...
# 9  https://api.elsevier.com/content/abstract/scop...

# %%
df_links_self = df_links[df_links['rel_type'] == 'self']
df_links_scopus = df_links[df_links['rel_type'] == 'scopus']
df_links_scopus_citedby = df_links[df_links['rel_type'] == 'scopus-citedby']

# %%
df_links_self.head(10)
df_links_self.drop(columns=['rel_type'], inplace=True)
df_links_self.to_csv('links/links_self.csv', index=False, encoding='utf-8')
# Out:
# C:\Users\Yiwahpsp\AppData\Local\Temp\ipykernel_60804\2492409931.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_links_self.drop(columns=['rel_type'], inplace=True)

# %%
df_links_scopus.head(10)
df_links_scopus.drop(columns=['rel_type'], inplace=True)
df_links_scopus.to_csv('links/links_scopus.csv', index=False, encoding='utf-8')
# Out:
# C:\Users\Yiwahpsp\AppData\Local\Temp\ipykernel_60804\341617280.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_links_scopus.drop(columns=['rel_type'], inplace=True)

# %%
df_links_scopus_citedby.head(10)
df_links_scopus_citedby.drop(columns=['rel_type'], inplace=True)
df_links_scopus_citedby.to_csv('links/links_scopus_citedby.csv', index=False, encoding='utf-8')
# Out:
# C:\Users\Yiwahpsp\AppData\Local\Temp\ipykernel_60804\2911478330.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_links_scopus_citedby.drop(columns=['rel_type'], inplace=True)

# %% [markdown]
# ## Get subject areas

# %%
def extract_subject_areas(json_file):
    """Extract subject areas from JSON file"""
    global subject_areas_count_files, sum_subject_areas_count_error_files
    records = []
    
    try:
        # Read JSON file
        with open(json_file, 'r', encoding='utf-8') as f:
            try:
                data = json.load(f)
            except json.JSONDecodeError as e:
                print(f"Error decoding JSON from {json_file}: {e}")
                return records
    except FileNotFoundError:
        print(f"File not found: {json_file}")
        return records
    except Exception as e:
        print(f"Error reading file {json_file}: {e}")
        return records
    
    # Navigate to required data
    try:
        title = (data.get('abstracts-retrieval-response', {})
                .get('coredata', {})
                .get('dc:title', ''))
        
        subject_areas = (data.get('abstracts-retrieval-response', {})
                        .get('subject-areas', {})
                        .get('subject-area', []))
        
        # Validate data
        if not title:
            print(f"No title found in {json_file}")
        
        # Handle single subject area case
        if isinstance(subject_areas, dict):
            subject_areas = [subject_areas]
        elif not subject_areas:
            print(f"No subject areas found in {json_file}")
            return records
        
        # Process each subject area
        for subject in subject_areas:
            if not isinstance(subject, dict):
                continue
                
            record = {
                'file': Path(json_file).name,
                'title': title,
                'Subject_Name': subject.get('$', ''),
            }
            records.append(record)
            
    except Exception as e:
        print(f"Error processing data from {json_file}: {e}")
        
    return records

def process_json_folders(root_folder_path):
    """Process all JSON files in root folder and subfolders"""
    global subject_areas_count_files, sum_subject_areas_count_error_files
    all_records = []
    root_path = Path(root_folder_path)
    
    # Create output directory
    Path('subject_areas').mkdir(exist_ok=True)
    
    # Process each JSON file
    for json_file in root_path.rglob('*.json'):
        try:
            subject_areas_count_files += 1
            records = extract_subject_areas(json_file)
            all_records.extend(records)
        except Exception as e:
            sum_subject_areas_count_error_files += 1
            print(f"Error processing {json_file}: {e}")
    
    if all_records:
        df = pd.DataFrame(all_records)
        output_file = 'subject_areas/subject_areas_separate.csv'
        df.to_csv(output_file, index=False, encoding='utf-8')
        print(f"Processed {len(all_records)} subject areas to {output_file}")
        print(f"Records processed with errors: {sum_subject_areas_count_error_files} from {subject_areas_count_files} files")
        print(f"Approximate error: {sum_subject_areas_count_error_files / subject_areas_count_files * 100:.2f}%")
    else:
        print("No subject areas found")

subject_areas_count_files = 0
sum_subject_areas_count_error_files = 0
process_json_folders(raw_data_root_path)
# Out:
# No title found in raw-data\2019\201902385.json
# Processed 50064 subject areas to subject_areas/subject_areas_separate.csv
# Records processed with errors: 0 from 20216 files
# Approximate error: 0.00%

# %%
df_subject_areas = pd.read_csv('subject_areas/subject_areas_separate.csv')
df_subject_areas.describe(include='all')
# Out:
#                   file    title       Subject_Name
# count            50064    50062              50064
# unique           20216    20140                321
# top     202001606.json  Preface  Multidisciplinary
# freq                12       44               1088

# %%
shape_df_subject_areas = df_subject_areas.shape
columns_df_subject_areas = df_subject_areas.columns
print('Shape:', shape_df_subject_areas)
print('Columns:', columns_df_subject_areas)
# Out:
# Shape: (50064, 3)
# Columns: Index(['file', 'title', 'Subject_Name'], dtype='object')

# %%
df_subject_areas.head(5)
# Out:
#              file                                              title  \
# 0  201800000.json  Public health and international epidemiology f...
# 1  201800001.json  Flexible Printed Active Antenna for Digital Te...
# 2  201800001.json  Flexible Printed Active Antenna for Digital Te...
# 3  201800002.json  Parametric study of hydrogen production via so...
# 4  201800002.json  Parametric study of hydrogen production via so...
#
#                                  Subject_Name
# 0                              Medicine (all)
# 1       Electrical and Electronic Engineering
# 2  Electronic, Optical and Magnetic Materials
# 3                             Chemistry (all)
# 4                  Chemical Engineering (all)

# %%
list_subject_areas = df_subject_areas['Subject_Name'].value_counts()
list_subject_areas.sort_values(ascending=False, inplace=True)
list_subject_areas.head(10)
list_subject_areas.to_csv('subject_areas/subject_areas_list.csv', index=True, encoding='utf-8')

# %%
list_subject_areas.shape
# Out:
# (321,)

# %% [markdown]
# ## Get references

# %%
def extract_references_summary(json_file):
    """Extract references and return as list per file"""
    try:
        with open(json_file, 'r', encoding='utf-8') as f:
            data = json.load(f)

        abs_resp = data.get('abstracts-retrieval-response', {})
        references = (abs_resp.get('item', {})
                     .get('bibrecord', {})
                     .get('tail', {})
                     .get('bibliography', {})
                     .get('reference'))
        
        if references is None:
            return {
                'file': Path(json_file).name,
                'references': []
            }
            
        if isinstance(references, dict):
            references = [references]
            
        ref_titles = []
        for ref in references:
            if isinstance(ref, dict):
                ref_title = ref.get('ref-info', {}).get('ref-sourcetitle')
                if ref_title:
                    ref_titles.append(ref_title)
        
        return {
            'file': Path(json_file).name,
            'references': ref_titles
        }
                    
    except Exception as e:
        print(f"Error processing {json_file}: {e}")
        return {
            'file': Path(json_file).name,
            'references': []
        }

def process_json_folders_summary(root_folder_path):
    """Process files and create summary DataFrame"""
    all_records = []
    root_path = Path(root_folder_path)
    
    for json_file in root_path.rglob('*.json'):
        record = extract_references_summary(json_file)
        all_records.append(record)
    
    if all_records:
        df = pd.DataFrame(all_records)
        # Convert references list to string for CSV storage
        df['references'] = df['references'].apply(lambda x: '|'.join(x) if x else '')
        
        output_file = 'references_summary.csv'
        df.to_csv(output_file, index=False)
        print(f"Processed {len(df)} files to {output_file}")
        return df
    
    return pd.DataFrame(columns=['file', 'references'])

# Usage
root_folder_path = 'raw-data'
summary_df = process_json_folders_summary(root_folder_path)
# Out:
# Error processing raw-data\2018\201800036.json: 'NoneType' object has no attribute 'get'
# Error processing raw-data\2018\201
json: 'NoneType' object has no attribute 'get'
# Error processing raw-data\2023\202300164.json: 'NoneType' object has no attribute 'get'
# Error processing raw-data\2023\202300197.json: 'NoneType' object has no attribute 'get'
# Error processing raw-data\2023\202300235.json: 'NoneType' object has no attribute 'get'
# Error processing raw-data\2023\202300256.json: 'NoneType' object has no attribute 'get'
# Error processing raw-data\2023\202300297.json: 'NoneType' object has no attribute 'get'
# Error processing raw-data\2023\202300298.json: 'NoneType' object has no attribute 'get'
# Error processing raw-data\2023\202300307.json: 'NoneType' object has no attribute 'get'
# Error processing raw-data\2023\202300310.json: 'NoneType' object has no attribute 'get'
# Error processing raw-data\2023\202300311.json: 'NoneType' object has no attribute 'get'
# Error processing raw-data\2023\202300314.json: 'NoneType' object has no attribute 'get'
# Error processing raw-data\2023\202300315.json: 'NoneType' object has no attribute 'get'
# Error processing raw-data\2023\202300316.json: 'NoneType' object has no attribute 'get'
# Error processing raw-data\2023\202300324.json: 'NoneType' object has no attribute 'get'
# Error processing raw-data\2023\202300415.json: 'NoneType' object has no attribute 'get'
# Error processing raw-data\2023\202300420.json: 'NoneType' object has no attribute 'get'
# Error processing raw-data\2023\202300424.json: 'NoneType' object has no attribute 'get'
# Error processing raw-data\2023\202300425.json: 'NoneType' object has no attribute 'get'
# Error processing raw-data\2023\202300437.json: 'NoneType' object has no attribute 'get'
# Error processing raw-data\2023\202300439.json: 'NoneType' object has no attribute 'get'
# Error processing raw-data\2023\202300445.json: 'NoneType' object has no attribute 'get'
# Error processing raw-data\2023\202300470.json: 'NoneType' object has no attribute 'get'
# Error processing raw-data\2023\202300484.json: 'NoneType' object has no attribute 'get'
# Error processing raw-data\2023\202300522.json: 'NoneType' object has no attribute 'get'
# Error processing raw-data\2023\202300583.json: 'NoneType' object has no attribute 'get'
# Error processing raw-data\2023\202300585.json: 'NoneType' object has no attribute 'get'
# Error processing raw-data\2023\202300586.json: 'NoneType' object has no attribute 'get'
# Error processing raw-data\2023\202300620.json: 'NoneType' object has no attribute 'get'
# Error processing raw-data\2023\202300693.json: 'NoneType' object has no attribute 'get'
# Error processing raw-data\2023\202300695.json: 'NoneType' object has no attribute 'get'
# Error processing raw-data\2023\202300740.json: 'NoneType' object has no attribute 'get'
# Error processing raw-data\2023\202300757.json: 'NoneType' object has no attribute 'get'
# Error processing raw-data\2023\202300811.json: 'NoneType' object has no attribute 'get'
# Error processing raw-data\2023\202300832.json: 'NoneType' object has no attribute 'get'
# Error processing raw-data\2023\202300857.json: 'NoneType' object has no attribute 'get'
# Error processing raw-data\2023\202300904.json: 'NoneType' object has no attribute 'get'
# Error processing raw-data\2023\202300969.json: 'NoneType' object has no attribute 'get'
# Error processing raw-data\2023\202301006.json: 'NoneType' object has no attribute 'get'
# Error processing raw-data\2023\202301057.json: 'NoneType' object has no attribute 'get'
# Error processing raw-data\2023\202301058.json: 'NoneType' object has no attribute 'get'
# Error processing raw-data\2023\202301133.json: 'NoneType' object has no attribute 'get'
# Error processing raw-data\2023\202301305.json: 'NoneType' object has no attribute 'get'
# Error processing raw-data\2023\202301330.json: 'NoneType' object has no attribute 'get'
# Error processing raw-data\2023\202301380.json: 'NoneType' object has no attribute 'get'
# Error processing raw-data\2023\202301387.json: 'NoneType' object has no attribute 'get'
# Error processing raw-data\2023\202301408.json: 'NoneType' object has no attribute 'get'
# Error processing raw-data\2023\202301420.json: 'NoneType' object has no attribute 'get'
# Error processing raw-data\2023\202301421.json: 'NoneType' object has no attribute 'get'
# Error processing raw-data\2023\202301443.json: 'NoneType' object has no attribute 'get'
# Error processing raw-data\2023\202301626.json: 'NoneType' object has no attribute 'get'
# Error processing raw-data\2023\202301639.json: 'NoneType' object has no attribute 'get'
# Error processing raw-data\2023\202301649.json: 'NoneType' object has no attribute 'get'
# Error processing raw-data\2023\202301653.json: 'NoneType' object has no attribute 'get'
# Error processing raw-data\2023\202301704.json: 'NoneType' object has no attribute 'get'
# Error processing raw-data\2023\202301817.json: 'NoneType' object has no attribute 'get'
# Error processing raw-data\2023\202301825.json: 'NoneType' object has no attribute 'get'
# Error processing raw-data\2023\202301828.json: 'NoneType' object has no attribute 'get'
# Error processing raw-data\2023\202301848.json: 'NoneType' object has no attribute 'get'
# Error processing raw-data\2023\202301863.json: 'NoneType' object has no attribute 'get'
# Error processing raw-data\2023\202301912.json: 'NoneType' object has no attribute 'get'
# Error processing raw-data\2023\202301930.json: 'NoneType' object has no attribute 'get'
# Error processing raw-data\2023\202301938.json: 'NoneType' object has no attribute 'get'
# Error processing raw-data\2023\202301956.json: 'NoneType' object has no attribute 'get'
# Error processing raw-data\2023\202301976.json: 'NoneType' object has no attribute 'get'
# Error processing raw-data\2023\202301978.json: 'NoneType' object has no attribute 'get'
# Error processing raw-data\2023\202302000.json: 'NoneType' object has no attribute 'get'
# Error processing raw-data\2023\202302025.json: 'NoneType' object has no attribute 'get'
# Error processing raw-data\2023\202302034.json: 'NoneType' object has no attribute 'get'
# Error processing raw-data\2023\202302107.json: 'NoneType' object has no attribute 'get'
# Error processing raw-data\2023\202302127.json: 'NoneType' object has no attribute 'get'
# Error processing raw-data\2023\202302170.json: 'NoneType' object has no attribute 'get'
# Error processing raw-data\2023\202302223.json: 'NoneType' object has no attribute 'get'
# Error processing raw-data\2023\202302248.json: 'NoneType' object has no attribute 'get'
# Error processing raw-data\2023\202302303.json: 'NoneType' object has no attribute 'get'
# Error processing raw-data\2023\202302321.json: 'NoneType' object has no attribute 'get'
# Error processing raw-data\2023\202302386.json: 'NoneType' object has no attribute 'get'
# Error processing raw-data\2023\202302412.json: 'NoneType' object has no attribute 'get'
# Error processing raw-data\2023\202302474.json: 'NoneType' object has no attribute 'get'
# Error processing raw-data\2023\202302548.json: 'NoneType' object has no attribute 'get'
# Error processing raw-data\2023\202302775.json: 'NoneType' object has no attribute 'get'
# Error processing raw-data\2023\202302808.json: 'NoneType' object has no attribute 'get'
# Error processing raw-data\2023\202302812.json: 'NoneType' object has no attribute 'get'
# Processed 20216 files to references_summary.csv

# %%
df_references = pd.read_csv('references/references_separate.csv')
df_references.describe(include='all')
# Out:
#                   file                                              title  \
# count           886277                                             886234
# unique           20204                                              20128
# top     202103556.json  Guidelines for the use and interpretation of a...
# freq              4084                                               4084
#
#        reference
# count     885866
# unique    177448
# top         JHEP
# freq        6345

# %%
shape_df_references = df_references.shape
columns_df_references = df_references.columns
print('Shape:', shape_df_references)
print('Columns:', columns_df_references)
# Out:
# Shape: (886277, 2)
# Columns: Index(['file', 'reference'], dtype='object')

# %%
df_references.head(5)
# Out:
#              file                                     reference
# 0  201800000.json                                      Science.
# 1  201800000.json                   The future of public health
# 2  201800000.json  International encyclopedia of public health.
# 3  201800000.json                Encyclopedia of public health.
# 4  201800000.json                   Definition of Public health

# %%
df_references.drop(columns=['title'], inplace=True)

# %%
pivot_df_references = (
    df_references.pivot_table(
        index=["file"],
        values="reference",
        aggfunc=lambda x: list(x.dropna().astype(str))  # Combine references into a list, handle NaN values
    )
    .reset_index()
)

pivot_df_references.to_csv("references/references_pivot.csv", index=False, encoding='utf-8')

# %% [markdown]
# ## Get title

# %%
def extract_title_summary(json_file):
    """Extract references and return as list per file"""
    try:
        with open(json_file, 'r', encoding='utf-8') as f:
            data = json.load(f)

        abs_resp = data.get('abstracts-retrieval-response', {})
        title = abs_resp.get('coredata', {}).get('dc:title', np.nan)
        publish_name = abs_resp.get('coredata', {}).get('prism:publicationName', np.nan)
            
        return {
            'file': Path(json_file).name,
            'title': title,
            'publish_name': publish_name,
        }
                    
    except Exception as e:
        print(f"Error processing {json_file}: {e}")
        return {
            'file': Path(json_file).name,
            'title': np.nan,
            'publish_name': np.nan,
        }

def process_json_folders_summary(root_folder_path):
    """Process files and create summary DataFrame"""
    all_records = []
    root_path = Path(root_folder_path)
    
    for json_file in root_path.rglob('*.json'):
        record = extract_title_summary(json_file)
        all_records.append(record)
    
    if all_records:
        df = pd.DataFrame(all_records)
        output_file = 'title_publish/title_publish_name_separate.csv'
        df.to_csv(output_file, index=False)
        print(f"Processed {len(df)} files to {output_file}")
        return df
    
    return pd.DataFrame(columns=['file', 'title', 'publish_name'])

# Usage
root_folder_path = 'raw-data'
summary_df = process_json_folders_summary(root_folder_path)
# Out:
# Processed 20216 files to title_publish/title_publish_name_separate.csv
